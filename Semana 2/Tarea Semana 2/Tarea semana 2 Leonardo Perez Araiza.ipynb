# %% [markdown]
# # Tarea semana 2: Fundamentos de python
# ## Nombre: Leonardo Perez Araiza

# %% [markdown]
# ### Ejercicio 1
# Las matemáticas financieras, resumidas en una frase, las podríamos definir como la rama de las matemáticas que estudia los flujos de dinero a través del tiempo. Básicamente se presupone que el dinero tiene menos valor en el futuro que en el presente, ya sea por un tema inflacionario o por la preferencia natural de las personas a priorizar el consumo presente.
#
# El valor futuro es el valor alcanzado por un determinado capital al final del período determinado (para el ejemplo usaremos la fórmula del interés compuesto). Para calcularlo se utiliza la siguiente fórmula
#
# VF=VA* ( 1+i )n
#
# El valor presente de una inversión es cuando calculamos el valor actual que tendrá una determinada cantidad que recibiremos o pagaremos en un futuro. Para calcularlo se utiliza la siguiente fórmula
#
# VA=VF( 1+i )n
#
# Donde
#  VF es el valor futuro,
#  VA es el valor actual o inicial de la inversión,
#  i es el tipo de interés y
#  n es número de años de la inversión.
#
# Crear una función que reciba como entrada un capital, un tipo de interés y un número de años, y muestre por pantalla el valor futuro de la inversión cada año del periodo indicado.
#
# Crear una función que reciba como entrada un capital, un tipo de interés y un número de años, y muestre por pantalla el valor actual del capital cada año del periodo indicado.

# %%
def futuro (v,i,a):
    val = []
    for n in range(a):
        val.append(v*(1+i)**(n+1))
    return val
def actual (vf,i,a):
    val = []
    for n in range(a):
        val.append(vf/(1+i)**(n+1))
    return val
while 1:
    print ("Que valor deseas calcular?\nA.Valor futuro\nB.Valor actual")
    op = str.lower(input())
    if op == 'a':
        cap = float(input("Capital inicial: "))
        inte = float(input("Interes compuesto: "))
        ans = int(input("Numero de años: "))
        vf = futuro(cap,inte,ans)
        print ("Define un periodo de años a mostrar")
        ai = int(input("Año inicial: "))
        af = int(input("Año final: "))
        per = af - ai + 1
        for x in range(per):
            print ("El valor futuro en el año",ai+x,"es:",vf[ai+x-1])
        break
    elif op == 'b':
        cap = float(input("Valor futuro: "))
        inte = float(input("Interes compuesto: "))
        ans = int(input("Numero de años: "))
        va = actual(cap,inte,ans)
        print ("Define un periodo de años a mostrar")
        ai = int(input("Año inicial: "))
        af = int(input("Año final: "))
        per = af - ai
        for x in range(per):
            print ("El valor actual en el año",af-1-x,"es:",va[ans-af+x])
        print ("La inversion inicial es:",va[ans-1]) 
        break
    else:
        print ("OPCION INVALIDA")
        continue

# %% [markdown]
# Explicacion: En este ejercicio la mayor complicacion que tuve fue idear como hacer una especie de menu para que un usuario interactuara y me decidi por un while que siempre estuviera ejecutandose hasta que de hiciera alguno de los dos calculos. Para la funcion 'Valor actual' quise dejar el valor de la inversion inicial ya que seria el "año cero" y si lo vemos de esa manera el valor futuro sera el que se alcance despues de que se cumplan los años especificados, segun lo interprete yo.

# %% [markdown]
# ### Ejercicio 2
# El archivo cotización.csv (archivo adjunto ) contiene las cotizaciones de empresas con las siguientes columnas:
# Nombre (nombre de la empresa),
# Final (precio de la acción al cierre de bolsa),
# Máximo (precio máximo de la acción durante la jornada),
# Mínimo (precio mínimo de la acción durante la jornada),
# Volumen (Volumen al cierre de bolsa),
# Efectivo (capitalización al cierre en miles de euros).
#
# Construir una función reciba el fichero de cotizaciones y devuelva un diccionario con los datos del fichero por columnas.
# Construir una función que reciba el diccionario devuelto por la función anterior y cree un fichero en formato csv con el mínimo, el máximo y la media de cada columna.

# %%
def capcol(col,lis):
    dato = list()
    for linea in lis:
        dato.append(linea[col])
    return dato
def recibefichero (nombre):
    import csv
    general = {}
    columna = 0
    with open(nombre, newline='') as archivo:
        lector = csv.reader(archivo,delimiter=";")
        lista = list(lector)
        for n in lista[0]:
            general[n] = capcol(columna,lista)
            columna +=1
    return general
def isnumeric(s):
    try:
        float(s)
        return True
    except ValueError:
        return False
def escribecsv(dic):
    dic1 = {}
    for col in d1:
        suma = 0
        nlista = list()
        for cadena in d1[col]:
            new = cadena.replace(",",".")
            flag = isnumeric(new)
            if flag:
                new = float(new)
                nlista.append(new)
                suma = suma+new
            else:
                continue
        try:
            maxi = max(nlista)
        except ValueError:
            continue
        try:
            mini = min(nlista)
        except ValueError:
            continue
        try:
            media = suma/len(nlista)
        except ValueError:
            continue
        dic1[col] = (col,maxi,mini,media)
    with open('calculos.csv','w',newline='') as archivo_csv:
        escritor_csv = csv.writer(archivo_csv)
        escritor_csv.writerow(['Columna','Máximo','Mínimo','Media']) 
        for n in dic1:
            escritor_csv.writerow(dic1[n]) 

d1 = recibefichero ("cotizacion.csv")
print (d1)
escribecsv (d1)

# %% [markdown]
# Explicacion: En este ejercicio me di cuenta que debia de convertir los valores que habia recibido al leer el archivo csv porque del modo en que lo hice mis datos numericos estaban en formato string, asi que tuve que hacer una funcion para determinar si cada cadena podia convertirse a un valor flotante y de esa manera ir separando mis datos numericos de las palabras, esa fue la mayor complicacion que tuve ya que no estoy muy familiarizado con las funciones de python.

# %% [markdown]
# ### Ejercicio 3
# Escribir un programa para gestionar un listado telefónico con los nombres y los teléfonos de los clientes de una empresa.
# El programa debe crear el archivo TXT con la lista si no existe.
# El programa debe  tener una función para consultar el teléfono de un cliente e imprimirlo en pantalla.
# El programa debe  tener una función para  añadir el teléfono de un nuevo cliente al archivo TXT.
# El programa debe tener una función que permita visualizar todo el listado telefónico
# El programa debe tener una función que guarde esta lista en un archivo CSV.

# %%
archivo = open("listadotelefonico.txt", "w")
archivo.write("Nombre Telefono\nHugo 5526014616\nLucía 5515474463\nSofía 5512723596\nMartina 5591282027\nJulia 3310860183\nPaula 5512726760\nEmma 5550034635\nDaniela 5550033936\nKarla 5592149997\nAlba 5592254068\nNoa 7298837183\nAlma 5593622941\nSara 2881032371\nCarmen 5582838930\nVega 8111002037\nLara 8111002239\nMia 5515450691\nMateo 5594051283\nMartín 5556471980\nLucas 3336886166\nLeo 5590209323\nDaniel 3324704121\nAlejandro 3495960000\nManuel 4437360036\nPablo 4171411924\nÁlvaro 4929800621\nAdrián 5589422736\nEnzo 8141708387\nMario 5574553470\nDiego 5589416290\nDavid 5590358637\nOliver 5593386137\nMarcos 5593623824\nThiago 5593620260\nMiriam 8124747599")
archivo.close()
def consulta(listado,nombre):
    archivo = open(listado, "r")
    lineas = archivo.readlines()
    archivo.close()
    lista = list()
    nlist = list()
    for dato in lineas:
        lista.append(dato.split(" "))
    for dato in lista:
        nlist = nlist + dato
    x = 0
    for dato in nlist:
        x +=1
        if dato == nombre:
            print ("El numero telefonico de",nombre,"es",nlist[x])
            break
        elif x == len(nlist):
            print ("Usuario no encontrado")
        else:
            continue
def anade(listado):
    archivo = open(listado, "r")
    lineas = archivo.readlines()
    archivo.close()
    cadena = str()
    for linea in lineas:
        cadena = cadena + linea
    nom = input("Escribe el nombre del nuevo ususario ")
    tel = input("Escribe el telefono del nuevo usuario ")
    archivo = open(listado, "w")
    archivo.write(f"{cadena}\n{nom} {tel}")
    archivo.close()
def visualiza(listado):
    archivo = open(listado, "r")
    lineas = archivo.readlines()
    archivo.close()
    for linea in lineas:
        print(linea)
def guardacsv (listado):
    import csv
    archivo = open(listado, "r")
    lineas = archivo.readlines()
    archivo.close()
    lista = list()
    nlist = list()
    for dato in lineas:
        lista.append(dato.replace(" ",","))
    with open('dirtel.csv','w',newline='') as archivo_csv:
        escritor_csv = csv.writer(archivo_csv)
        escritor_csv.writerow(lista) 

while 1:
    n = int(input("Selecciona una opcion del menu\n1.Consultar telefono por nombre\n2.Añadir un telefono a la lista\n3.Visualizar todo el listado telefonico\n4.Guardar la lista en archivo csv\n5.Salir\n"))
    if n == 1:
        nom = input("Escribe el nombre del usuario del cual deseas saber su telefono ")     
        consulta ("listadotelefonico.txt",nom)
    if n == 2:
        anade ("listadotelefonico.txt")
    if n == 3:
        visualiza("listadotelefonico.txt")
    if n == 4:
        guardacsv("listadotelefonico.txt")
    if n == 5:
        break
    else:
        continue

# %% [markdown]
# Explicacion: Al igual que el primer ejercicio dedidi hacer un "menu" usando un while. Para el listado telefonico guarde todos los valores (nombres y telefonos) en una sola cadena pero no me arriesgue a poner apellidos o personas con mas de un nombre porque no me sentia muy seguro de como trabajar y manipular los datos para trabajar con ellos, asi que mi programa esta pensado solo para contemplar un nombre y su numero telefonico correspondiente.

# %% [markdown]
# ## Ejercicio 4
# El archivo calificaciones.csv (archivo adjunto ) contiene las calificaciones de un curso. Durante el curso se realizaron dos exámenes parciales de teoría y un examen de prácticas. Escribir un programa que contenga las siguientes funciones:
#
# Una función que reciba el archivo de calificaciones y devuelva una lista de diccionarios, donde cada diccionario contiene la información de los exámenes y la asistencia de un alumno. La lista tiene que estar ordenada por apellidos.
# Una función que reciba una lista de diccionarios como la que devuelve la función anterior y añada a cada diccionario una nueva llave con la nota final del curso.  Teniendo en cuenta los siguientes criterios de evaluación
# Practicas 10 %
# Practica Final 30%
# Promedio de Parciales 1 y 2  20%
# Promedio de Exámenes 1 y 2 40%
# Una función que reciba una lista de diccionarios como la que devuelve la función anterior y devuelva dos listas, una con los alumnos aprobados y otra con los alumnos reprobados. Para aprobar el curso toma en cuenta lo siguiente :
# La asistencia tiene que ser mayor o igual que el 75%
# La nota final debe ser mayor o igual a 8.0

# %%
def enlista(lista,i):
    nlista = list()
    for n in lista:
        try: 
            nlista.append(n[i])
        except:
            continue
    return nlista  

def acomoda(lista,a): 
    splista = list()
    nlista = list()
    i =0
    for n in lista:
        splista = lista[i].split(" ")
        nlista.append(splista[a])
        i +=1
    return nlista

def listadic(listado):
    import csv
    with open(listado, newline='') as archivo:
        lector = csv.reader(archivo,delimiter=",")
        lista = list(lector)
    apelista = list()
    asilista = list()
    exa1lista = list()
    exa2lista = list()
    nasilista = list()
    nexa1lista = list()
    nexa2lista = list()
    newlista = list()
    for n in lista:
        apelista.append(n[0])
    apelista.remove('Apellidos')
    apelista.remove('calificaciones')
    asilista = enlista (lista,2)
    asilista.remove('Asistencia')
    exa1lista = enlista(lista,5)
    exa1lista.remove('Examen1')
    exa2lista = enlista(lista,6)
    exa2lista.remove('Examen2')
    nlista = list()
    i = 0
    for n in apelista:
        x = 0
        while x < 3:
            cadena = apelista[i]+" "+asilista[i]+" "+exa1lista[i]+" "+exa2lista[i]
            x +=1
        nlista.append(cadena)
        i +=1
    nlista.sort()
    apelista.sort()
    nasilista = acomoda(nlista,-3)
    nexa1lista = acomoda(nlista,-2)
    nexa2lista = acomoda(nlista,-1)
    dicn = {}
    i =0
    for n in apelista:
        dicn = {'Alumno':apelista[i],'Asistencia':nasilista[i],'Examen 1':nexa1lista[i],'Examen 2':nexa2lista[i]}
        i +=1
        newlista.append(dicn)
    return newlista

def notafinal(listadic):
    import csv
    ape1lista = list()
    with open("calificaciones.csv", newline='') as archivo:
        lector = csv.reader(archivo,delimiter=",")
        lista = list(lector)
    for n in lista:
        ape1lista.append(n[0])
    ape1lista.remove('Apellidos')
    ape1lista.remove('calificaciones')
    pfinal = list()
    pfinal = enlista(lista,-1)
    pfinal.remove('Practica Final')
    pfinal.remove('calificaciones')
    par1 = list()
    par1 = enlista(lista,3)
    par1.remove('Parcial1')
    par2 = list()
    par2 = enlista(lista,4)
    par2.remove('Parcial2')
    pract = list()
    pract = enlista(lista,-2)
    pract.remove('Practicas')
    parpro = list()
    i = 0
    for n in par1:
        parpro.append((float(par1[i])+float(par2[i]))/2*0.2)
        i +=1
    pfinalp = list()
    i = 0
    for n in pfinal:
        pfinalp.append(float(pfinal[i])*0.3)
        i +=1
    practp = list()
    i = 0
    for n in pract:
        practp.append(float(pract[i])*0.1)
        i +=1
    i = 0
    nlista = list()
    for n in parpro:
        x = 0
        while x < 3:
            cadena = ape1lista[i]+" "+str(parpro[i]+pfinalp[i]+practp[i])
            x +=1
        nlista.append(cadena)
        i +=1
    nlista.sort()
    nlista = acomoda(nlista,-1)
    exapro = list()
    for n in listadic:
        exapro.append((float(n['Examen 1'])+float(n['Examen 2']))/2*0.4)
    final = list()
    i =0
    for n in nlista:
        final.append(float(nlista[i])+float(exapro[i]))
        i +=1
    i = 0
    for n in listadic:
        n['Nota final'] = final[i]
        i +=1
    return listadic
def alumnosapro(listadic):
    notafinal = list()
    asistencia = list()
    for n in listadic:
        notafinal.append(n['Nota final'])
    cadena = str()
    for n in listadic:
        cadena = (n['Asistencia'])
        cadena = int(cadena[0:2])
        asistencia.append(cadena)
    alumnosaprobados = list()
    alumnosreprobados = list()
    i = 0
    for n in listadic:
        if notafinal[i]>=8 and asistencia[i]>=75:
            alumnosaprobados.append(n['Alumno'])
        else:
            alumnosreprobados.append(n['Alumno'])
        i +=1
    print (f'Lista de aprobados: ',alumnosaprobados)
    print (f'Lista de reprobados: ',alumnosreprobados)
    return

newlista = listadic("calificaciones.csv")
lista = notafinal(newlista)
alumnosapro(lista)

# %% [markdown]
# Explicacion: En este eejercicio me senti mas comodo usandolos diccionarios, listas y cadenas de datos, me sirvio para darme cuenta que es muchisimo (en mi caso) programar para manipular los datos comodamente, capturarlos, acomodarlos darles otro formato y asi consecutuvamente. Para la primera funcion guarde los datos por columna en una lista (una lista por columna) pero me di cuenta de que tambien capturaba los encabezados asi que para eso fui eliminando uno por uno despues de capturar la lista, para ordenar los datos alfabeticamente arme una nueva lista de cadenas para que cada cadena contuviera los datos de los examenes, asistenacia y el nombre al inicio de cada una para poder acomodarlas por orden alfabetico, una vez ordenados los separe y los reparti en el diccionario. Lo que me hubiera gustado hacer es tal vez no usar tantas variables, pero me sirvio para darle seguimiento a cada lista y poder manejarla mejor. Una vez que pude echar a andar la primera funcion las oras dos fueron mucho mas faciles, era simplemente ir asegurandose de convertir las cadenas a datos con los que se pudiera hacer calculos y comparaciones (int y float)
