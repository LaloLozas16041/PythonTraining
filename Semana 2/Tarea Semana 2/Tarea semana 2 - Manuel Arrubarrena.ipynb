# %% [markdown]
# # Tarea semana 2: Fundamentos de python
#
# ## Nombre: Manuel Alejandro Arrubarrena Tame

# %% [markdown]
# ### Ejercicio 1:
# Las matemáticas financieras, resumidas en una frase, las podríamos definir como la rama de las matemáticas que estudia los flujos de dinero a través del tiempo. Básicamente se presupone que el dinero tiene menos valor en el futuro que en el presente, ya sea por un tema inflacionario o por la preferencia natural de las personas a priorizar el consumo presente.
#
# El valor futuro es el valor alcanzado por un determinado capital al final del período determinado (para el ejemplo usaremos la fórmula del interés compuesto). Para calcularlo se utiliza la siguiente fórmula
# VF=VA* ( 1+i )n
#
# El valor presente de una inversión es cuando calculamos el valor actual que tendrá una determinada cantidad que recibiremos o pagaremos en un futuro. Para calcularlo se utiliza la siguiente fórmula
#
# VA=VF( 1+i )n
#
# Donde
#  VF es el valor futuro,
#  VA es el valor actual o inicial de la inversión,
#  i es el tipo de interés y
#  n es número de años de la inversión.
#
# Crear una función que reciba como entrada un capital, un tipo de interés y un número de años, y muestre por pantalla el valor futuro de la inversión cada año del periodo indicado.
# Crear una función que reciba como entrada un capital, un tipo de interés y un número de años, y muestre por pantalla el valor actual del capital cada año del periodo indicado.

# %%
print('Dame un capital')
capital = float(input())
print('dame un tipo de interés')
interes = float(input())
print('dame un número de años')
aos = int(input())

def val_pres(capi, inter, ao):
    dic = {}
    count = 1
    for x in range(1,(ao+1)) :
        pr = capi / ((1+inter) ** x)
        dic[x] = pr
        count += 1
    return dic
print('valor presente por año:', val_pres(capital,interes,aos))

def val_fut(cap, intere, aosi):
    dic2 = {}
    count2 = 1
    for yi in range(1,(aosi+1)) :
        pri = cap * ((intere + 1)** yi)
        dic2[yi] = pri
        count2 +=1
    return dic2
print('valor futuro por año:', val_fut(capital,interes,aos))

# %% [markdown]
# ### Explicacion
# estuve un poco confundido, pensé que era lidiar con funciones circulares, pero ya después entendí, lo que hice fue crear un diccionario para poder imprimir por año, hubiera preferido un for fuera de función para hacer las impresiones por línea.

# %% [markdown]
# ### Ejercicio 2
# El archivo cotización.csv (archivo adjunto ) contiene las cotizaciones de empresas con las siguientes columnas:
# Nombre (nombre de la empresa),
# Final (precio de la acción al cierre de bolsa),
# Máximo (precio máximo de la acción durante la jornada),
# Mínimo (precio mínimo de la acción durante la jornada),
# Volumen (Volumen al cierre de bolsa),
# Efectivo (capitalización al cierre en miles de euros).
#
# Construir una función reciba el fichero de cotizaciones y devuelva un diccionario con los datos del fichero por columnas.
# Construir una función que reciba el diccionario devuelto por la función anterior y cree un fichero en formato csv con el mínimo, el máximo y la media de cada columna.

# %%
import pandas as pd #if f[key].dtype.kind in 'biufc':
locarch ='C:/Users/User/Desktop/ArchivosEjerAletia'
nombre ='/cotizacion.csv'
destino = "/salida.txt"

def abrir_ar(filesource, name):
    try:
        df = pd.read_csv(filesource + name, sep= ';')
        df = df.replace(',','.', regex=True)
        df['Volumen'] = df['Volumen'].str.replace('.','')
        g={}
        for col in list(df.columns):
            g[col] = df[col]
    except:
        print("No existe archivo con nombre", nombre)
    return g
g1 = abrir_ar(locarch, nombre)
del g1['Nombre']
#print(df)
def calcu(diccionario, filesou, nami):
    archivo = open(filesou + nami, "w")
    t = []
    for key in diccionario:
        t = diccionario[key]
    #    print(t)
        maxi = max(t)
        mini = min(t)
        medi = str(pd.to_numeric(t).mean()) 
        archivo.write('columna '+ str(key) + ' minimo ' + str(mini) + ' maximo ' + str(maxi) + ' media ' + str(medi) + '\n')
    archivo.close()
    #df2 = pd.read_table(locarch + nami)
    return print('done')
calcu(g1, locarch, destino)

# %% [markdown]
# ### Explicacion
# el ejercicio estuvo muy pesado pues tuve que jugar con los datos para poder armar las transformaciones

# %% [markdown]
# ### Ejercicio 3:
# Escribir un programa para gestionar un listado telefónico con los nombres y los teléfonos de los clientes de una empresa.
# El programa debe crear el archivo TXT con la lista si no existe
# El programa debe  tener una función para consultar el teléfono de un cliente e imprimirlo en pantalla.
# El programa debe  tener una función para  añadir el teléfono de un nuevo cliente al archivo TXT.
# El programa debe tener una función que permita visualizar todo el listado telefónico
# El programa debe tener una función que guarde esta lista en un archivo CSV.

# %%
import pandas as pd
locarch ='C:/Users/User/Desktop/ArchivosEjerAletia'
destino = "/salida2.txt"
lista = {'Juan Perez' : 3312335, 'Chucho Ramirez' : 66244813, 'Pepe Gonzalez' : 665455668}
def lista_chek(source, name, lista):
    try:
        archivo = open(source + name, "r")
        archivo.close()
    except:
        archivo = open(source + name, "w")
        ### VALORES DE KEYS
        keyName = list(lista.keys())
        u = 0
        for key in lista:
            #t = lista[key]
            n = keyName[u]
            archivo.write(str(n) + ", " + str(lista[key]) + '\n')
            u += 1
        archivo.close()
    return print('revisado')

#lista_chek(locarch, destino, lista)

def consulta_tel(source, arch, cliente):
    
    df2 = pd.read_csv(source + arch, header=None)
    namese = list(df2[0])
    teles = list(df2[1])
    rest = dict(zip(namese, teles))
    try:
        teli = rest[cliente]
    except:
        teli = 'El cliente no existe'
    return teli

#consulta_tel(locarch, destino, 'Juan Perez')

def agrega(source, arch, cliente, telef):
    try:
        df = pd.read_csv(source + arch, header=None)
        namesei = list(df[0])
        telesi = list(df[1])
        namesei.append(cliente)
        telesi.append(telef)
        reste = dict(zip(namesei, telesi))
        archiv = open(source + arch, "w")
        keNames = list(reste.keys())
        ui = 0
        for ke in reste:
            #t = lista[key]
            ni = keNames[ui]
            archiv.write(str(ni) + ", " + str(reste[ke]) + '\n')
            ui += 1
        archiv.close()
    except:
        o = 'no hay nada ahí'
        archiv.close()
    return print('Agregado')
#agrega(locarch, destino, 'Pepito Gutierrez', 33554412)

def ensena(source, arch):
    try:
        df3 = pd.read_csv(source + arch, header=None)
    except:
        df3 = 'Archivo inexistente o vacio'
    return df3
#ensena(locarch, destino)

def a_csv(source, name):
    df = pd.read_csv(source + name, header=None)
    namesei = list(df[0])
    telesi = list(df[1])
    reste = dict(zip(namesei, telesi))
    archiv = open(source + arch, "w")
    keNames = list(reste.keys())
    ui = 0
    for ke in reste:
            #t = lista[key]
        ni = keNames[ui]
        archiv.write(str(ni) + ", " + str(reste[ke]) + '\n')
        ui += 1
    archiv.close()
    return print('liston')

# %% [markdown]
# ### Explicacion
# Estuvo complicado el manejo de archivos, pero al final pude definir funciones y que fuera escribiendo con unos for lo que quería

# %% [markdown]
# ### Ejercicio 4:
# El archivo calificaciones.csv (archivo adjunto ) contiene las calificaciones de un curso. Durante el curso se realizaron dos exámenes parciales de teoría y un examen de prácticas. Escribir un programa que contenga las siguientes funciones:
#
# Una función que reciba el archivo de calificaciones y devuelva una lista de diccionarios, donde cada diccionario contiene la información de los exámenes y la asistencia de un alumno. La lista tiene que estar ordenada por apellidos.
# Una función que reciba una lista de diccionarios como la que devuelve la función anterior y añada a cada diccionario una nueva llave con la nota final del curso.  Teniendo en cuenta los siguientes criterios de evaluación
# Practicas 10 %
# Practica Final 30%
# Promedio de Parciales 1 y 2  20%
# Promedio de Exámenes 1 y 2 40%
# Una función que reciba una lista de diccionarios como la que devuelve la función anterior y devuelva dos listas, una con los alumnos aprobados y otra con los alumnos suspensos. Para aprobar el curso
# La asistencia tiene que ser mayor o igual que el 75%
# La nota final debe ser mayor o igual a 8.0

# %%
import pandas as pd #if f[key].dtype.kind in 'biufc':
locarch ='C:/Users/User/Desktop/ArchivosEjerAletia'
nombre ='/calificaciones2.csv'
#destino = "/salida.txt"
#dfe = dfe.drop(dfe.index[0])

def abrir_arc(filesource, name):
    try:
        dfe = pd.read_csv(filesource + name)
        dfe.columns = dfe.iloc[0]
        dfe = dfe[1:]
        dfe = dfe.sort_values(by=['Apellidos'], ascending=True)
        rows = dfe.shape[0]
        listd =[]
        for uot in range(0, rows):
            dic = {'Nombre' : dfe.iloc[uot,1], 'Apellidos' : dfe.iloc[uot,0], 'Asistencia' : dfe.iloc[uot,2], 'Examen1' : dfe.iloc[uot,5], 'Examen2' : dfe.iloc[uot,6]}
            listd.append(dic)
    except:
        print("No existe archivo con nombre", name)
    return listd

#abrir_arc(locarch, nombre)

def notas_final(filesource, name):
    try:
        dfe = pd.read_csv(filesource + name)
        dfe.columns = dfe.iloc[0]
        dfe = dfe[1:]
        dfe = dfe.sort_values(by=['Apellidos'], ascending=True)
        rows = dfe.shape[0]
        listd =[]
        notas = 0
        for uot in range(0, rows):
            notas = (float(dfe.iloc[uot,7])*0.1) + (float(dfe.iloc[uot,8])*0.3) + (((float(dfe.iloc[uot,3]) + float(dfe.iloc[uot,4]))/2)*0.2) + (((float(dfe.iloc[uot,5]) + float(dfe.iloc[uot,6]))/2)*0.4)
            notas = round(notas, 2)
            dic = {'Nombre' : dfe.iloc[uot,1], 'Apellidos' : dfe.iloc[uot,0], 'Asistencia' : dfe.iloc[uot,2], 'Examen1' : dfe.iloc[uot,5], 'Examen2' : dfe.iloc[uot,6], 'Nota final' : notas}
            listd.append(dic)
    except:
        print("No existe archivo con nombre", name)
    return listd

#notas_final(locarch, nombre)

def aprobados(filesource, name, calif):
    try:
        dfe = pd.read_csv(filesource + name)
        dfe.columns = dfe.iloc[0]
        dfe = dfe[1:]
        dfe = dfe.sort_values(by=['Apellidos'], ascending=True)
        rows = dfe.shape[0]
        listd =[]
        notas = 0
        for uot in range(0, rows):
            notas = (float(dfe.iloc[uot,7])*0.1) + (float(dfe.iloc[uot,8])*0.3) + (((float(dfe.iloc[uot,3]) + float(dfe.iloc[uot,4]))/2)*0.2) + (((float(dfe.iloc[uot,5]) + float(dfe.iloc[uot,6]))/2)*0.4)
            notas = round(notas, 2)
            dic = {'Nombre' : dfe.iloc[uot,1], 'Apellidos' : dfe.iloc[uot,0], 'Asistencia' : dfe.iloc[uot,2], 'Examen1' : dfe.iloc[uot,5], 'Examen2' : dfe.iloc[uot,6], 'Nota final' : notas}
            listd.append(dic)

        listr = []
        for uop in range(0, rows):
            notas = (float(dfe.iloc[uop,7])*0.1) + (float(dfe.iloc[uop,8])*0.3) + (((float(dfe.iloc[uop,3]) + float(dfe.iloc[uop,4]))/2)*0.2) + (((float(dfe.iloc[uop,5]) + float(dfe.iloc[uop,6]))/2)*0.4)
            notas = round(notas, 2)
            listr.append(notas)
        dfe['Notas'] = listr
        ##  pasan = dfe[['Apellidos', 'Nombre']][dfe.Asistencia >= '75%']

        pasan = dfe[['Apellidos', 'Nombre', 'Asistencia']][dfe['Notas'] > float(calif)]
        pasan2 = pasan[['Apellidos', 'Nombre']][pasan['Asistencia'] >= '75%']
        pasan3 = pasan[['Apellidos', 'Nombre']][pasan['Asistencia'] == '100%']
        frames = [pasan2, pasan3]
        pasan4 = pd.concat(frames)
        dfNomb = dfe[['Apellidos', 'Nombre']]
        npasan= pd.concat([dfNomb,pasan4]).drop_duplicates(keep=False)
        
        print('Pasan los alunmos: ', pasan4)
        print('----------------')
        print('No pasan los alumnos: ', npasan)
    except:
        print('El archivo no existe')
    return #pasan4, npasan
    
#aprobados(locarch, nombre, 3)

# %% [markdown]
# ### Explicacion
# Estuvo retador el hacer todo en funciones, pero al final pude usar las diferentes condiciones que pedía el ejercicio. Tuve que ver como jugar con los formatos y declarar mas objetos de los que hubiera pensado
