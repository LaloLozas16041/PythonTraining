# %% [markdown]
# # TAREA SEMANA 2 : FUNDAMENTOS DE PYTHON

# %% [markdown]
# ## Nombre: Jair Fernando García Macias

# %% [markdown]
# ### Ejercicio 1

# %% [markdown]
# Las matemáticas financieras, resumidas en una frase, las podríamos definir como la rama de las matemáticas que estudia los flujos de dinero a través del tiempo. Básicamente se presupone que el dinero tiene menos valor en el futuro que en el presente, ya sea por un tema inflacionario o por la preferencia natural de las personas a priorizar el consumo presente.
#
# El valor futuro es el valor alcanzado por un determinado capital al final del período determinado (para el ejemplo usaremos la fórmula del interés compuesto). Para calcularlo se utiliza la siguiente fórmula
# VF=VA* ( 1+i )n
#
# El valor presente de una inversión es cuando calculamos el valor actual que tendrá una determinada cantidad que recibiremos o pagaremos en un futuro. Para calcularlo se utiliza la siguiente fórmula
#
# VA=VF( 1+i )n
#
# Donde
#  VF es el valor futuro,
#  VA es el valor actual o inicial de la inversión,
#  i es el tipo de interés y
#  n es número de años de la inversión.
#
# A. Crear una función que reciba como entrada un capital, un tipo de interés y un número de años, y muestre por pantalla el valor futuro de la inversión cada año del periodo indicado.
# B. Crear una función que reciba como entrada un capital, un tipo de interés y un número de años, y muestre por pantalla el valor actual del capital cada año del periodo indicado.

# %%
def valor_futuro(capital, interes, años):
    valorFuturo = capital * ((1 + interes) ** años)
    return valorFuturo

def valor_actual(capital, interes, años):
    valorActual = valor_futuro(capital, interes, años) / ((1 + interes) ** años)
    return valorActual

capital = float(input('Ingresa capital: '))
interes = float(input('Ingresa el interés anual: '))
años = float(input('Ingresa el tiempo (años) que estará invertido el capital: '))

print(f'El valor futuro de la inversión es: {valor_futuro(capital, interes, años)}')
print(f'El valor actual de la inversión es: {valor_actual(capital, interes, años)}')
# Out:
# Ingresa capital: 10000
# Ingresa el interés anual: 0.12
# Ingresa el tiempo (años) que estará invertido el capital: 10
# El valor futuro de la inversión es: 31058.48208344212
# El valor actual de la inversión es: 10000.0

# %% [markdown]
# #### Explicación:
# No tuve inconvenientes al realizar este ejercicio, ya que en clase vimos un ejercicio muy similar.

# %% [markdown]
# ### Ejercicio 2

# %% [markdown]
# El archivo cotización.csv (archivo adjunto ) contiene las cotizaciones de empresas con las siguientes columnas:
# Nombre (nombre de la empresa),
# Final (precio de la acción al cierre de bolsa),
# Máximo (precio máximo de la acción durante la jornada),
# Mínimo (precio mínimo de la acción durante la jornada),
# Volumen (Volumen al cierre de bolsa),
# Efectivo (capitalización al cierre en miles de euros).
#
# A. Construir una función reciba el fichero de cotizaciones y devuelva un diccionario con los datos del fichero por columnas.
#
# B. Construir una función que reciba el diccionario devuelto por la función anterior y cree un fichero en formato csv con el mínimo, el máximo y la media de cada columna.

# %%
import csv

ruta = '''C:\\Users\\gdljairg\\Downloads\\'''
file_name = 'cotizacion.csv'

def open_txt(filename,folder):
    dicc = {}
    lista_temp = []
    lista = []
    try:
        f = open(folder+filename, 'r', encoding="utf-8")
        texto = f.readlines()

        filas = len(texto) - 1
        columnas = len(texto[0].split(',')) - 1
        i = 0
        while i <= columnas:
            indice = texto[0].split(',')[i].replace('\n','')
            j = 1
            while j <= filas:
                valor = texto[j].split(',')[i].replace('"','')
                if valor.count('.') > 1:
                    valor = valor.replace('.','')
                try:
                    valor_temp = valor
                    lista_temp.append(float(valor))
                except:
                    lista_temp.append(valor)
                if j == filas:
                    dicc[indice] = lista_temp
                    lista_temp = []
                j += 1
            i += 1

        return dicc

    except:
        print(f'El archivo {filename} no puede ser leido o no se encuentra')
        return ''

def crear_fichero(diccionario):
    # Cálculo de minimo, máximo y media
    nuevo_file = []
    i = 0
    for dato in diccionario:
        if i > 0:
            minimo = 0
            maximo = 0
            media = 0
            suma = 0
            j = 0
            for dat in diccionario[dato]:
                if j == 0:
                    minimo = dat
                    maximo = dat
                if dat < minimo:
                    minimo = dat
                if dat > maximo:
                    maximo = dat
                suma += dat
                j += 1
            media = suma / len(diccionario[dato])
            lista_temp = [dato, minimo, maximo, media]
            nuevo_file.append(lista_temp)
        i += 1
    # Fin de Cálculo de minimo, máximo y media

    # Reacomodo de la lista calculada para escribir lo que se pide
    r = 0
    c = 0
    linea_temp = []
    nueva_lista = []
    while r < 4:
        linea_temp.append(nuevo_file[c][r])
        c += 1
        if c > 4:
            r += 1
            c = 0
            nueva_lista.append(linea_temp)
            linea_temp = []
    # Fin de Reacomodo de la lista calculada para escribir lo que se pide

    # Escribir nuevo archivo
    with open(ruta + 'nuevo_file.csv', 'w', newline='') as archivo_csv:
        escritor_csv = csv.writer(archivo_csv)
        for linea in nueva_lista:
            escritor_csv.writerow(linea)
    # Fin de Escribir nuevo archivo

crear_fichero(open_txt(file_name, ruta))

# %% [markdown]
# #### Explicación:
# Tuve un poco de complicaciones para limpiar la información y para arreglarmelas en recorrer cada elemento del archivo y así realizar los cálculos solicitados. Sólo en la función que regresa el mínimo, máximo y la media, omití la columna que no contenía valores numéricos considerando que no se pueden determinar los cálculos mencionados.

# %% [markdown]
# ### Ejercicio 3

# %% [markdown]
# Escribir un programa para gestionar un listado telefónico con los nombres y los teléfonos de los clientes de una empresa.
#
# El programa debe crear el archivo TXT con la lista si no existe.
#
# El programa debe  tener una función para consultar el teléfono de un cliente e imprimirlo en pantalla.
#
# El programa debe  tener una función para  añadir el teléfono de un nuevo cliente al archivo TXT.
#
# El programa debe tener una función que permita visualizar todo el listado telefónico.
#
# El programa debe tener una función que guarde esta lista en un archivo CSV.

# %%
def crear_archivo(diccionario, ruta, file):
    archivo = open(ruta + file, 'w')
    if 'txt' in file:
        archivo.write('NOMBRE - TELEFONO\n')
    else:
        archivo.write('NOMBRE,TELEFONO\n')
    for elemento in diccionario:
        if 'txt' in file:
            fila = f'{elemento} - {diccionario[elemento]}\n'
        else:
            fila = f'{elemento},{diccionario[elemento]}\n'
        archivo.write(fila)
    archivo.close()

def consulta_cliente(ruta, txt_file, nombre):
    archivo = open(ruta + txt_file, 'r')
    lineas = archivo.readlines()
    archivo.close()
    lista = []
    telefono = 0
    for telefonos in lineas:
        lista.append(telefonos.split(' - '))
    for elemento in lista:
        if elemento[0] == nombre:
            telefono = elemento[1].replace('\n','')
    if telefono != 0:
        print(f'El número de teléfono de {nombre} es: {telefono}')
    else:
        print('El nombre buscado no se encuentra en el listado')

def agregar_empleado(nombre, telefono):
    global empleados, ruta, txt_file
    empleados[nombre] = telefono
    crear_archivo(empleados, ruta, txt_file)

def mostrar_listado(diccionario_default, ruta, file):
    try:
        listado = lista_empleados()
    except:
        crear_archivo(diccionario_default, ruta, file)
        listado = lista_empleados()
    for elemento in listado:
        print(elemento)

def lista_empleados():
    archivo = open(ruta + txt_file, 'r')
    lineas = archivo.readlines()
    archivo.close()
    listado = []
    for linea in lineas:
        listado.append(linea.replace('\n', '').split(' - '))
    return listado

empleados = {
    'Joe': 3315288345,
    'May': 3378654309,
    'Julio': 3322876543,
    'Marco': 5534489321,
    'Mauricio': 3389674587
}

ruta = '''C:\\Users\\gdljairg\\Downloads\\'''

txt_file = 'empleados.txt'
csv_file = 'empleados.csv'

seleccion = int(input('Seleccione la opción deseada: '
                  '\n 1. Consultar número de teléfono de algún cliente.'
                  '\n 2. Agregar nuevo contacto.'
                  '\n 3. Visualizar contactos.'
                  '\n 4. Crear archivo en csv.\n'))

if seleccion == 1:
    consulta_cliente(ruta, txt_file, input('Ingresa el nombre del cliente que quieres consultar: '))
elif seleccion == 2:
    nuevo_empleado = input('Ingresa el nombre del nuevo empleado: ')
    nuevo_empleado_tel = int(input('Ingresa el número de teléfono del empleado: '))
    agregar_empleado(nuevo_empleado, nuevo_empleado_tel)
elif seleccion == 3:
    mostrar_listado(empleados, ruta, txt_file)
elif seleccion == 4:
    crear_archivo(empleados, ruta, csv_file)
else:
    print('No seleccionaste una opción válida')

# %% [markdown]
# #### Explicación:
# Sólo tuve un poco de complicaciones para manipular el diccionario. Para contrarestar las dificultados realizo varias impresiones de pantalla durante la manipulación del diccionario (prueba y error).

# %% [markdown]
# ### Ejercicio 4

# %% [markdown]
# El archivo calificaciones.csv (archivo adjunto ) contiene las calificaciones de un curso. Durante el curso se realizaron dos exámenes parciales de teoría y un examen de prácticas. Escribir un programa que contenga las siguientes funciones:
#
# A. Una función que reciba el archivo de calificaciones y devuelva una lista de diccionarios, donde cada diccionario contiene la información de los exámenes y la asistencia de un alumno. La lista tiene que estar ordenada por apellidos.
#
# B. Una función que reciba una lista de diccionarios como la que devuelve la función anterior y añada a cada diccionario una nueva llave con la nota final del curso.  Teniendo en cuenta los siguientes criterios de evaluación:
#
# a) Practicas 10 %
#
# b) Practica Final 30%
#
# c) Promedio de Parciales 1 y 2  20%
#
# d) Promedio de Exámenes 1 y 2 40%
#
# C. Una función que reciba una lista de diccionarios como la que devuelve la función anterior y devuelva dos listas, una con los alumnos aprobados y otra con los alumnos reprobados. Para aprobar el curso toma en cuenta lo siguiente :
#
# a) La asistencia tiene que ser mayor o igual que el 75%
#
# b) La nota final debe ser mayor o igual a 8.0

# %%
def lista_ordenada(ruta, archivo):
    archivo = open(ruta + archivo, 'r', encoding="utf-8")
    lineas = archivo.readlines()
    archivo.close()
    lineas.sort()
    lista = []
    persona = {}
    for lin in lineas:
        j = 0
        numeros = []
        titulos = []
        lista_temp = lin.split(',')
        if lista_temp[0] != 'calificaciones' and lista_temp[0] != 'Apellidos':
            '''if lista_temp[0] == 'Apellidos':
                for elemento in lista_temp:
                    titulos.append(elemento.replace('\n',''))
                lista.insert(0, titulos)
            else:'''
            for elemento in lista_temp:
                if j == 0:
                    apellido = elemento
                elif j == 1:
                    nombre = elemento
                else:
                    try:
                        numeros.append(float(elemento.replace('\n','')))
                    except:
                        if '%' in elemento:
                            numeros.append(float(elemento.replace('\n', '').replace('%',''))/100)
                        else:
                            numeros.append(elemento.replace('\n', ''))
                j += 1
            persona[f'{apellido} {nombre}'] = numeros
            lista.append(persona)
            persona = {}
    return lista

def calificaciones(listado):
    for alumno in listado:
        for nombre in alumno:
            practicas = alumno[nombre][5] * 0.1
            practica_final = alumno[nombre][6] * 0.3
            promedio_parciales_1_y_2 = ((alumno[nombre][1] + alumno[nombre][2]) / 2) * 0.2
            promedio_examenes_1_y_2 = ((alumno[nombre][3] + alumno[nombre][4]) / 2) * 0.4
            resultado = practicas + practica_final + promedio_parciales_1_y_2 + promedio_examenes_1_y_2
            alumno[nombre].append(round(resultado,2))
    return listado

def reprobados(listado):
    aprobados = []
    reprobados = []
    for alumno in listado:
        for nombre in alumno:
            if alumno[nombre][0] >= 0.75 and alumno[nombre][7] >= 8:
                aprobados.append(nombre)
            else:
                reprobados.append(nombre)
    print('APROBADOS'.center(100, '-'))
    for aprobado in aprobados:
        print(aprobado)
    print('REPROBADOS'.center(100,'-'))
    for reprobado in reprobados:
        print(reprobado)

ruta = '''C:\\Users\\gdljairg\\Downloads\\'''
archivo = 'calificaciones.csv'
calificacion = calificaciones(lista_ordenada(ruta, archivo))
reprobados(calificacion)

# %% [markdown]
# #### Explicación:
# No tuve ninguna complicación para realizar el ejercicio...a menos que, haya realizado mal algún cálculo; ya que en el archivo proporcionado y considerando las reglas mencionadas, ninguno de los estudiantes aprobó.
