# %% [markdown]
# **Perdon , perdon por la demora instructora Carolina, espero aun me valga algo la tarea , apenas la logre terminar :P**

# %% [markdown]
# ######TAREA SEMANA 2 : FUNDAMENTOS DE PYTHON
# #####Nombre: Lopez Gonzalez Pedro Ivan

# %% [markdown]
# ######Ejercicio 1 :
# Las matemáticas financieras, resumidas en una frase, las podríamos definir como la rama de las matemáticas que estudia los flujos de dinero a través del tiempo. Básicamente se presupone que el dinero tiene menos valor en el futuro que en el presente, ya sea por un tema inflacionario o por la preferencia natural de las personas a priorizar el consumo presente.
#
# El valor futuro es el valor alcanzado por un determinado capital al final del período determinado (para el ejemplo usaremos la fórmula del interés compuesto). Para calcularlo se utiliza la siguiente fórmula
# VF=VA* ( 1+i )n
#
# El valor presente de una inversión es cuando calculamos el valor actual que tendrá una determinada cantidad que recibiremos o pagaremos en un futuro. Para calcularlo se utiliza la siguiente fórmula
#
# VA=VF( 1+i )n
#
# Donde
#  VF es el valor futuro,
#  VA es el valor actual o inicial de la inversión,
#  i es el tipo de interés y
#  n es número de años de la inversión.
#
# Crear una función que reciba como entrada un capital, un tipo de interés y un número de años, y muestre por pantalla el valor futuro de la inversión cada año del periodo indicado.
# Crear una función que reciba como entrada un capital, un tipo de interés y un número de años, y muestre por pantalla el valor actual del capital cada año del periodo indicado.

# %%
def valorFuturo(capital_inicial = 0.0, interes = 0.0, numero_anios = 0):
  for anio in range(1,numero_anios + 1):
    print(f"Año {anio}, Cantidad: {round(capital_inicial*(1+interes/100)**anio,2)}")

def valorActual(capital_futuro = 0.0, interes = 0.0, numero_anios = 0):
  for anio in range(1,numero_anios + 1):
    print(f"Año {anio}, Cantidad: {round(capital_futuro/(1+interes)**anio,2)}")


print("IMPRESION DEL VALOR FUTURO")
capital_inicial = float(input("Ingrese el monto inicial: "))
interes = float(input("Ingrese la tasa de interes en %:"))
numero_anios = int(input("Ingrese el numero de periodos en años: "))

print("\n\nLa tabla de evolucion del capital es:\n")
valorFuturo(capital_inicial,interes,numero_anios)

print("\n\nIMPRESION DEL VALOR ACTUAL")
capital_futuro = float(input("Ingrese el monto futuro: "))
interes = float(input("Ingrese la tasa de interes en %:"))
numero_anios = int(input("Ingrese el numero de periodos en años: "))

print("\n\nLa tabla de evolucion del capital es:\n")
valorActual(capital_inicial,interes,numero_anios)
# Out:
# IMPRESION DEL VALOR FUTURO
# Ingrese el monto inicial: 100
# Ingrese la tasa de interes en %:10
# Ingrese el numero de periodos en años: 5
#
#
# La tabla de evolucion del capital es:
#
# Año 1, Cantidad: 110.0
# Año 2, Cantidad: 121.0
# Año 3, Cantidad: 133.1
# Año 4, Cantidad: 146.41
# Año 5, Cantidad: 161.05
# IMPRESION DEL VALOR ACTUAL
# Ingrese el monto futuro: 1000
# Ingrese la tasa de interes en %:10
# Ingrese el numero de periodos en años: 5
#
#
# La tabla de evolucion del capital es:
#
# Año 1, Cantidad: 9.09
# Año 2, Cantidad: 0.83
# Año 3, Cantidad: 0.08
# Año 4, Cantidad: 0.01
# Año 5, Cantidad: 0.0

# %% [markdown]
# ###EXPLICACION:
#   En este ejercicio no se presento problema alguno.

# %% [markdown]
# ######Ejercicio 2 : El archivo cotización.csv (archivo adjunto ) contiene las cotizaciones de empresas con las siguientes columnas:
# Nombre (nombre de la empresa),
# Final (precio de la acción al cierre de bolsa),
# Máximo (precio máximo de la acción durante la jornada),
# Mínimo (precio mínimo de la acción durante la jornada),
# Volumen (Volumen al cierre de bolsa),
# Efectivo (capitalización al cierre en miles de euros).
#
# Construir una función reciba el fichero de cotizaciones y devuelva un diccionario con los datos del fichero por columnas.
# Construir una función que reciba el diccionario devuelto por la función anterior y cree un fichero en formato csv con el mínimo, el máximo y la media de cada columna.

# %%
import csv
import numpy as np

archivo = 'cotizacion.csv'

def dicCotizaciones(archivo):
  with open(archivo,newline='') as archivo_csv:
     dict_valores={}
     lector =csv.reader(archivo_csv)
     #print(type(lector))
     #print(lector)
     lineas = list(lector)
     lista_elementos=[]
     contador = 0
     #print("Las lineas son ",lineas)
     for fila in lineas:
       fila = str(fila).split(";")
       
       if contador:
       # print(f"la fila[0] es: ",type(fila[0])," y la fila[1] es ",type(fila[1:]))
        fila[0] = fila[0].replace("['","")
        #print("la longitud del arreglo de columnas es ",len(fila[1:]) )
        for i in range(len(fila[1:])):
          #print(f"el tipo de fila[{i+1}] es:",fila[i+1])
         
          if i+1 == 4:
            fila[i+1]=fila[i+1].replace(".","")
          else:
            fila[i+1]=fila[i+1].replace("', '",".")
            fila[i+1]=fila[i+1].replace("']","")
          #print(f"el tipo de fila[{i+1}] es:",fila[i+1])

        
        #print("los elementos con coma son",fila[1:4])

        #print(f"la fila[0] es: ",type(fila[0])," y la fila[1] es ",type(fila[1:]))
        dict_valores[fila[0]]=fila[1:]

       contador += 1
       #dict_valores=dict_valores.pop(0)
      


        #lista_fila.append(fila)
   
  return dict_valores

def archivo_csv(dict_valores={}):
  n=len(dict_valores.values())
  #print("El diccionario tiene: ",n," y es del tipo ",type(dict_valores.values()))

  columnas= list(dict_valores.values())
  suma_columna_final = 0.0
  lista_columna_final=[]
  lista_columna_maximo=[]
  lista_columna_minimo=[]
  lista_columna_volumen=[]
  lista_columna_efectivo=[]
  
  for elemento in range(n) :
     #print("La columna final es:",columnas[elemento][0])
     #print("La columna maximo es:",columnas[elemento][1])
     lista_columna_final.append(float(columnas[elemento][0]))
     lista_columna_maximo.append(float(columnas[elemento][1]))
     lista_columna_minimo.append(float(columnas[elemento][2]))
     lista_columna_volumen.append(float(columnas[elemento][3]))
     lista_columna_efectivo.append(float(columnas[elemento][4]))
     #suma_columna_final += float(columnas[elemento][0])
     #suma_columna_final += float(columnas[elemento][0])
  
  max_columna_final=np.max(np.array(lista_columna_final))
  min_columna_final=np.min(np.array(lista_columna_final))
  media_columna_final=np.average(np.array(lista_columna_final))
  print("columna FINAL -> media: ",media_columna_final," maximo valor: ",max_columna_final,"minimo valor: ",min_columna_final)


  max_columna_maximo=np.max(np.array(lista_columna_maximo))
  min_columna_maximo=np.min(np.array(lista_columna_maximo))
  media_columna_maximo=np.average(np.array(lista_columna_maximo))
  print("columna MAXIMO -> media: ",media_columna_maximo," maximo valor: ",max_columna_maximo,"minimo valor: ",min_columna_maximo)

  max_columna_minimo=np.max(np.array(lista_columna_minimo))
  min_columna_minimo=np.min(np.array(lista_columna_minimo))
  media_columna_minimo=np.average(np.array(lista_columna_minimo))
  print("columna MINIMO -> media: ",media_columna_minimo," maximo valor: ",max_columna_minimo,"minimo valor: ",min_columna_minimo)

  max_columna_volumen=np.max(np.array(lista_columna_volumen))
  min_columna_volumen=np.min(np.array(lista_columna_volumen))
  media_columna_volumen=np.average(np.array(lista_columna_volumen))
  print("columna VOLUMEN -> media: ",media_columna_volumen," maximo valor: ",max_columna_volumen,"minimo valor: ",min_columna_volumen)


  max_columna_efectivo=np.max(np.array(lista_columna_efectivo))
  min_columna_efectivo=np.min(np.array(lista_columna_efectivo))
  media_columna_efectivo=np.average(np.array(lista_columna_efectivo))
  print("columna EFECTIVO -> media: ",media_columna_efectivo," maximo valor: ",max_columna_efectivo,"minimo valor: ",min_columna_efectivo)
  #lista_columnas=['FINAL','MAXIMO','MINIMO','VOLUMEN','EFECTIVO']
 
 
  with open("columnas.csv",'w') as archivo:
   archivo.write("COLUMNA,MAXIMO,MINIMO,MEDIA")
   archivo.write("\n")
   archivo.write('MAXIMO,'+ str(max_columna_maximo)+','+str(min_columna_maximo)+','+str(media_columna_maximo))
   archivo.write('\n')
   archivo.write('MINIMO,'+ str(max_columna_minimo)+','+str(min_columna_minimo)+','+str(media_columna_minimo))
   archivo.write('\n')
   archivo.write('VOLUMEN,' + str(max_columna_volumen)+','+str(min_columna_volumen)+','+str(media_columna_volumen))
   archivo.write('\n')
   archivo.write('EFECTIVO,' + str(max_columna_efectivo)+','+str(min_columna_efectivo)+','+str(media_columna_efectivo))
   archivo.write('\n')
   archivo.write('FINAL,' + str(max_columna_final)+','+str(min_columna_final)+','+str(media_columna_final))
   archivo.write('\n')
   
   # columna_final=[]
  #print("Los elementos de la columna maximo son:",lista_columna_maximo)
  #print("el promedio de la columna final es:", suma_columna_final/n)
  return
  
diccionario = dicCotizaciones(archivo)
        
print("El diccionario creado es: ",diccionario)
archivo_csv(dicCotizaciones(archivo))
# Out:
# El diccionario creado es:  {'ACCIONA': ['95.95', '96.75', '94.4', '84962', '8166.11'], 'ACERINOX': ['8668', '8672', '8468', '88599', '7633.81'], 'ACS': ['37.28', '37.66', '37.22', '655982', '24517.29'], 'AENA': ['167.1', '167.5', '166.1', '133738', '22336.10'], 'AMADEUS': ['69.96', '70.64', '69.56', '640476', '44795.47'], 'ARCELORMIT.': ['14152', '14318', '14.08', '702841', '9989.65'], 'BA.SABADELL': ['1.0165', '1033', '1.0165', '12358512', '12637.65'], 'BA.SANTANDER': ['4.02', '4.0675', '4.01', '36129692', '145765.44'], 'BANKIA': ['2249', '2262', '2224', '3024454', '6803.54'], 'BANKINTER': ['6.56', '6604', '6522', '1375976', '9030.20'], 'BBVA': ['5024', '5.05', '4969', '26447612', '132560.15'], 'CAIXABANK': ['2763', '2806', '2762', '13031097', '36239.22'], 'CELLNEX': ['30.17', '30.7', '30.17', '857237', '25965.29'], 'CIE AUTOMOT.': ['23.44', '23.74', '23.4', '99506', '2343.09'], 'ENAGAS': ['25.6', '25.66', '25.07', '84254', '21524.77'], 'ENCE': ['3882', '3974', '3846', '2099698', '8
# ...

# %%
# !ls
# !cat columnas.csv
# Out:
# agenda.txt  columnas.csv  datos.csv  drive  sample_data
# COLUMNA,MAXIMO,MINIMO,MEDIA
# MAXIMO,19875.0,4.0675,3170.113357142857
# MINIMO,19675.0,1.0165,3136.5104714285717
# VOLUMEN,36129692.0,1221.0,4252278.514285714
# EFECTIVO,145765.44,2343.09,31767.778
# FINAL,19705.0,1.0165,2796.7687571428573

# %% [markdown]
# ###EXPLICACION:
#   Estuve batallando mucho en aprender a referenciar a cada uno de los elementos ya sea de listas o diccionarios.

# %% [markdown]
# ######Ejercicio 3
# Escribir un programa para gestionar un listado telefónico con los nombres y los teléfonos de los clientes de una empresa.
# El programa debe crear el archivo TXT con la lista si no existe
# El programa debe  tener una función para consultar el teléfono de un cliente e imprimirlo en pantalla.
# El programa debe  tener una función para  añadir el teléfono de un nuevo cliente al archivo TXT.
# El programa debe tener una función que permita visualizar todo el listado telefónico
# El programa debe tener una función que guarde esta lista en un archivo CSV.

# %%
def mostrar_menu(opciones):
    print('Seleccione una opción:')
    for clave in sorted(opciones):
        print(f' {clave}) {opciones[clave][0]}')


def leer_opcion(opciones):
    while (a := input('Opción: ')) not in opciones:
        print('Opción incorrecta, vuelva a intentarlo.')
    return a


def ejecutar_opcion(opcion, opciones):
    opciones[opcion][1]()


def generar_menu(opciones, opcion_salida):
    opcion = None
    while opcion != opcion_salida:
        mostrar_menu(opciones)
        opcion = leer_opcion(opciones)
        ejecutar_opcion(opcion, opciones)
        print()


def menu_principal():
    opciones = {
        '1': ('Mostrar archivo', mostrarArchivo),
        '2': ('Agregar entrada', agregarEntrada),
        '3': ('Borrar Archivo', borrarArchivo),
        '4': ('Vaciar Archivo', vaciarDatos),
        '5': ('Salir', salir)
    }

    generar_menu(opciones, '5')


def mostrarArchivo():
    print("--------------------------------")
    print("Los datos guardados en el archivo son:\n")
    #comprobarArchivo(archivo)
    with open (archivo,'r') as agenda:
      contenido =list(agenda.readlines())
      print(contenido)
    print("--------------------------------")

      


def agregarEntrada():
    print("--------------------------------")
    print("AGREGAR NUEVA ENTRADA\n")
    with open ("agenda.txt",'a') as agenda:
      agenda.write(input("Ingrese el nombre del cliente a continuacion del telefono, por ejemplo: Mario Lopez   2321233132: "))
      agenda.write('\n')
    print("--------------------------------")

def borrarArchivo():
    print("--------------------------------")
    print("BORRADO DE ARCHIVO")
    os.system("rm agenda.txt")
    print("Se ha borrado el archivo",archivo)
    print("--------------------------------")
  
def vaciarDatos():
    print("--------------------------------")
    print("VACIADO DE DATOS")
    with open (archivo,'r') as agenda:
     contenido =list(agenda.readlines())
     
     with open("datos.csv",'w') as csv:
      for dato in range(len(contenido)):
        if contenido[dato] == contenido[-1]:
         contenido[dato] = contenido[dato].removesuffix('\n')
        else:  
         contenido[dato] = contenido[dato].removesuffix('\n')+','
        csv.write(contenido[dato])
     print("Se han vaciado los datos a datos.csv")
     print("--------------------------------")
       


def salir():
    print('Saliendo')

#####################################################################
import os
#import os.path


archivo = 'agenda.txt'
def comprobarArchivo(archivo):
 check_file = os.path.isfile(archivo)

 if check_file:
   print("El archivo",archivo," ya existe\n\n")
 else:
  try:
    with open('agenda.txt', 'w') as agenda: 
     pass 
    print("El archivo para crear la agenda ha sido creado\n\n")
  except:
    print("No ha sido posible crear el archivo.")

comprobarArchivo(archivo)
menu_principal()
# Out:
# El archivo agenda.txt  ya existe
#
#
# Seleccione una opción:
#  1) Mostrar archivo
#  2) Agregar entrada
#  3) Borrar Archivo
#  4) Vaciar Archivo
#  5) Salir
# --------------------------------
# Los datos guardados en el archivo son:
#
# ['hohn wick 23423423424\n', 'marcia aledaes 34234234\n', 'sdfdf 45353453453\n']
# --------------------------------
#
# Seleccione una opción:
#  1) Mostrar archivo
#  2) Agregar entrada
#  3) Borrar Archivo
#  4) Vaciar Archivo
#  5) Salir
# --------------------------------
# AGREGAR NUEVA ENTRADA
#
# --------------------------------
#
# Seleccione una opción:
#  1) Mostrar archivo
#  2) Agregar entrada
#  3) Borrar Archivo
#  4) Vaciar Archivo
#  5) Salir
# --------------------------------
# Los datos guardados en el archivo son:
#
# ['hohn wick 23423423424\n', 'marcia aledaes 34234234\n', 'sdfdf 45353453453\n', 'monica flores 242342342342\n']
# --------------------------------
#
# Seleccione una opción:
#  1) Mostrar archivo
# ...

# %%
# !pwd
# !ls
# !cat datos.csv
# Out:
# /content
# agenda.txt  datos.csv  drive  sample_data
# hohn wick 23423423424,marcia aledaes 34234234,sdfdf 45353453453

# %% [markdown]
# ###EXPLICACION:
# tuve algunos problemas al manejar con precision los argumentos al crear archivos , necesito estudiar mas al respecto

# %% [markdown]
# ######Ejercicio 4 : El archivo calificaciones.csv (archivo adjunto ) contiene las calificaciones de un curso. Durante el curso se realizaron dos exámenes parciales de teoría y un examen de prácticas. Escribir un programa que contenga las siguientes funciones:
#
# Una función que reciba el archivo de calificaciones y devuelva una lista de diccionarios, donde cada diccionario contiene la información de los exámenes y la asistencia de un alumno. La lista tiene que estar ordenada por apellidos.
# Una función que reciba una lista de diccionarios como la que devuelve la función anterior y añada a cada diccionario una nueva llave con la nota final del curso.  Teniendo en cuenta los siguientes criterios de evaluación
# Practicas 10 %
# Practica Final 30%
# Promedio de Parciales 1 y 2  20%
# Promedio de Exámenes 1 y 2 40%
# Una función que reciba una lista de diccionarios como la que devuelve la función anterior y devuelva dos listas, una con los alumnos aprobados y otra con los alumnos reprobados. Para aprobar el curso toma en cuenta lo siguiente :
# La asistencia tiene que ser mayor o igual que el 75%
# La nota final debe ser mayor o igual a 8.0

# %%
import csv
import numpy as np

archivo = 'calificaciones.csv'

def lista_alumnos(archivo):
  with open(archivo,newline='') as archivo_csv:
     dict_valores={}
     lector =csv.reader(archivo_csv)
     #print(type(lector))
     #print(lector)
     lineas = list(lector)
     #print(lineas)
     
     lista_diccionarios = []

     for contador in range(len(lineas)):

      if contador >= 2:
       #lista_diccionario]
       lineas[contador-2] = lineas[contador]
       lineas[contador-2][0]= lineas[contador-2][0]+' '+lineas[contador-2][1]
       #print(type(lineas[contador-2][1]))
       lineas[contador-2].pop(1)
       
       #print(lineas[contador])
      contador+=1
     for linea in lineas:
        dict_valores[linea[0]]=linea[1:]
  
     
     #print(type(lineas[0][0]))
     
     llaves_dict=[]
     llaves_dict = list(dict_valores.keys())
     llaves_dict.sort()
     dict_valores = {i:dict_valores[i] for i in llaves_dict}
     lista_diccionarios =list(dict_valores.items())
     return lista_diccionarios

def calculoNotaFinal(lista_diccionarios={}):     
     #print(len(lista_diccionarios))
     for i in range(len(lista_diccionarios)):
       practicas = float(lista_diccionarios[i][1][5])*.1
       #print(practicas)
       practica_final = float(lista_diccionarios[i][1][6])*.3
      # print(practica_final)
       prom_parciales = (float(lista_diccionarios[i][1][1])+float(lista_diccionarios[i][1][2]))/2*.2
       #print(prom_parciales)
       prom_examenes = (float(lista_diccionarios[i][1][3])+float(lista_diccionarios[i][1][4]))/2*.4
       #print(prom_examenes)
       nota_final = practicas + practica_final  + prom_parciales + prom_examenes
       #print(lista_diccionarios[i][1])
       lista_diccionarios[i][1].append(str(round(nota_final,2)))
       #print(lista_diccionarios[i][1])
       
     return lista_diccionarios
     #lista_diccionarios[15][1][7] = str(9.5)
       #print("salto\n\n")
       
     #print(lista_diccionarios)
     #float(lista_diccionarios[i][1][0].removesuffix("%"))>75
def listasAprobadosReprobados(lista_diccionarios={}):   
     alumnos_reprobados = []
     alumnos_aprobados = []
     #print(float(lista_diccionarios[i][1][0].removesuffix("%")))
     #print(lista_diccionarios[0][0])

     for i in range(len(lista_diccionarios)):
        if float(lista_diccionarios[i][1][7]) >= 8.0 and float(lista_diccionarios[i][1][0].removesuffix("%"))>75:
          alumnos_aprobados.append(lista_diccionarios[i][0])
        else:
          alumnos_reprobados.append(lista_diccionarios[i][0])


    # print("Los alumnos aprobados son:\n",alumnos_aprobados,"\n") 
    #print("Los alumnos reprobados son:\n",alumnos_reprobados,"\n",len(alumnos_reprobados))
     return alumnos_aprobados,alumnos_reprobados 

    
alumnos=lista_alumnos(archivo)
print("La lista de los alumnos ordenada alfabeticamente es:")
for i in range(len(alumnos)):
  print(alumnos[i][0])
print("\n\n")
alumnos=calculoNotaFinal(alumnos)
print("La lista de los alumnos con su nota final y asistencia es:\n")
print ("{:<30} {:<13} {:<10}".format('NOMBRE','ASISTENCIA','NOTA FINAL'))
for i in range(len(alumnos)):
 print("{:<30} {:<13} {:<10}".format(alumnos[i][0],alumnos[i][1][0],alumnos[i][1][7]))

aprobados,reprobados = listasAprobadosReprobados(alumnos)

print("\n\nLos alumnos aprobados son:\n\t")
if aprobados == []:
   print("\tNingun alumno aprobo.\n\n")
else:
   for i in range(len(alumnos)):
    print(aprobados[i],"\n")
   print("\n\n")


print("\nLos alumnos reprobados son:\n\t")
if reprobados == []:
   print("\tNingun alumno reprobo.\n\n")
else:
   for i in range(len(alumnos)):
    print("\t",reprobados[i])
   print("\n\n")
# Out:
# La lista de los alumnos ordenada alfabeticamente es:
# Anido Bonet David
# Bueno Cerdeira Patricia
# Casariego García Raúl
# Curbelo Sánchez Jorge
# Díaz Souto Sofía
# García Perez Yaiza
# Lorenzo García Jaime
# Martínez Lucas Cecilia
# Mora Peñaloza Sandra
# Moreno Angulo Antonio
# Morillo Escudero Ana
# Muñoz Gómez Carolina
# Ramirez de la Puente Raquel
# Riego Pizarro Carlos
# Rodríguez de Blas Ignacio
# Sánchez Jordán María
#
#
#
# La lista de los alumnos con su nota final y asistencia es:
#
# NOMBRE                         ASISTENCIA    NOTA FINAL
# Anido Bonet David              90%           1.83
# Bueno Cerdeira Patricia        95%           2.48
# Casariego García Raúl          98%           4.1
# Curbelo Sánchez Jorge          75%           4.05
# Díaz Souto Sofía               82%           2.25
# García Perez Yaiza             85%           2.55
# Lorenzo García Jaime           100%          2.55
# Martínez Lucas Cecilia         86%           1.73
# ...

# %% [markdown]
# ###EXPLICACION:
#   Aqui ya tenia la practica del ejercicio 2 por lo que ya no batalle tanto en referenciar a los elemntos  de cada lista/diccionario y hacer operaciones sobre ellos.
