# %% [markdown]
# TAREA SEMANA 2: FUNDAMENTOS DE PYTHON

# %% [markdown]
# Nombre: Raúl Eduardo Toache Thomas

# %% [markdown]
# Ejercicio 1:
# A. Crear una función que reciba como entrada un capital, un tipo de interés y un número de años, y muestre por pantalla el valor futuro de la inversión cada año del periodo indicado.
# B. Crear una función que reciba como entrada un capital, un tipo de interés y un número de años, y muestre por pantalla el valor actual del capital cada año del periodo indicado.

# %%
def valor_futuro(capital, interes, tiempo):
    for i in range(1, tiempo + 1):
        valorf= capital * ((1 + interes) ** i)
        print("El valor futuro para el año", i, "es de", valorf)

def valor_actual(capital, interes, tiempo):
    for i in range(1, tiempo + 1):
        valora = capital/(1 + interes) ** i
        print("El valor actual para el año", i, "es de", valora)

valor_futuro(10000, 0.1, 10)
print("- " * 30)
valor_actual(10000, 0.1, 10)
# Out:
# El valor futuro para el año 1 es de 11000.0
# El valor futuro para el año 2 es de 12100.000000000002
# El valor futuro para el año 3 es de 13310.000000000004
# El valor futuro para el año 4 es de 14641.000000000004
# El valor futuro para el año 5 es de 16105.100000000006
# El valor futuro para el año 6 es de 17715.610000000008
# El valor futuro para el año 7 es de 19487.171000000013
# El valor futuro para el año 8 es de 21435.888100000015
# El valor futuro para el año 9 es de 23579.47691000002
# El valor futuro para el año 10 es de 25937.424601000024
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# El valor actual para el año 1 es de 9090.90909090909
# El valor actual para el año 2 es de 8264.462809917353
# El valor actual para el año 3 es de 7513.148009015776
# El valor actual para el año 4 es de 6830.134553650705
# El valor actual para el año 5 es de 6209.213230591549
# El valor actual para el año 6 es de 5644.739300537772
# ...

# %% [markdown]
# Explicación: Es un ejercicio muy directo, pide una función para cada formula y simplemente hay que correr la formula dentro de un ciclo for para obtener la proyección completa que se solicita.

# %% [markdown]
# Ejercicio 2: A. Construir una función reciba el fichero de cotizaciones y devuelva un diccionario con los datos del fichero por columnas. B. Construir una función que reciba el diccionario devuelto por la función anterior y cree un fichero en formato csv con el mínimo, el máximo y la media de cada columna.

# %%
import csv

def mostrar_dict(nombre_fichero):
    d={}
    with open("cotizacion.csv","r") as csvf:
        content = csv.reader(csvf, delimiter=";")
        for row in content:
            if not row[0] in d:
                d[row[0]]=[]
            for value in row[1:]:
                d[row[0]].append(value);
        d = cleaner(d)
    return d

def cleaner(cont):
    new_dict = {}
    contador = 0
    contador_de_claves = 0
    new_list = []
    new_value = ""
    listofkeys = []
    for i in cont.keys():
        listofkeys.append(i)
    for y in cont.values():
        for i in range(0, len(y)):
            if i == 3:
                y[i] = y[i].replace('.', ',')
            else:
                y[i] = y[i].replace(',', '.')
            new_list.append(y[i])
            contador += 1
            if contador == 5:
                new_dict[listofkeys[contador_de_claves]] = new_list
                new_list = []
                contador_de_claves += 1
                contador = 0
    return new_dict

def crear_formato(dict):
    new_dict = {}
    lista_valores = []
    lista_min = []
    minval = 0
    lista_max = []
    maxval = 0
    lista_media = []
    suma = 0
    listofkeys = []
    for i in dict.keys():
        listofkeys.append(i)
    listofkeys.append("Minimo")
    listofkeys.append("Maximo")
    listofkeys.append("Media")
    for values in dict.values():
        lista_valores.append(values)
    for x in range(0, 5):
        for y in range(1, len(lista_valores)):
            if y == 1:
                minval = float(lista_valores[y][x].replace(',', ''))
                maxval = float(lista_valores[y][x].replace(',', ''))
                suma = float(lista_valores[y][x].replace(',', ''))
            else:
                if minval > float(lista_valores[y][x].replace(',', '')):
                    minval = float(lista_valores[y][x].replace(',', ''))
                if maxval < float(lista_valores[y][x].replace(',', '')):
                    maxval = float(lista_valores[y][x].replace(',', ''))
                suma = suma + float(lista_valores[y][x].replace(',', ''))
        lista_min.append(str(minval))
        minval = 0
        lista_max.append(str(maxval))
        maxval = 0
        lista_media.append(str(suma/(len(lista_valores)+1)))
    lista_valores.append(lista_min)
    lista_valores.append(lista_max)
    lista_valores.append(lista_media)
    for i in range(0, len(lista_valores)):
        new_dict[listofkeys[i]] = lista_valores[i]
    with open('cotizaciones1.csv', 'w', newline='') as file:
        writer = csv.writer(file)
        field = []
        for z in range(0, len(lista_valores)):
            field.append(listofkeys[z])
            for x in range(0, 5):
                field.append(lista_valores[z][x])
            writer.writerow(field)
            field = []
    return new_dict

    
crear_formato(mostrar_dict("cotizacion.csv"))
# Out:
# ['Nombre', 'Final', 'MÃ¡ximo', 'MÃ\xadnimo', 'Volumen', 'Efectivo']
# ['ACCIONA', '95.95', '96.75', '94.4', '84,962', '8166.11']
# ['ACERINOX', '8668', '8672', '8468', '885,99', '7633.81']
# ['ACS', '37.28', '37.66', '37.22', '655,982', '24517.29']
# ['AENA', '167.1', '167.5', '166.1', '133,738', '22336.10']
# ['AMADEUS', '69.96', '70.64', '69.56', '640,476', '44795.47']
# ['ARCELORMIT.', '14152', '14318', '14.08', '702,841', '9989.65']
# ['BA.SABADELL', '1.0165', '1033', '1.0165', '12,358,512', '12637.65']
# ['BA.SANTANDER', '4.02', '4.0675', '4.01', '36,129,692', '145765.44']
# ['BANKIA', '2249', '2262', '2224', '3,024,454', '6803.54']
# ['BANKINTER', '6.56', '6604', '6522', '1,375,976', '9030.20']
# ['BBVA', '5024', '5.05', '4969', '26,447,612', '132560.15']
# ['CAIXABANK', '2763', '2806', '2762', '13,031,097', '36239.22']
# ['CELLNEX', '30.17', '30.7', '30.17', '857,237', '25965.29']
# ['CIE AUTOMOT.', '23.44', '23.74', '23.4', '99,506', '2343.09']
# ...

# %% [markdown]
# Explicación: El más dificil problema de programación que recuerde haber resuelto, más que nada porque no se me ocurrio usar replace hasta despues de muchas horas en el mismo problema, cuando Carolina me recomendo hacer uso de esa funcion. Este problema tambien me ayudo a mejorar mi entendimiento de diccionarios y listas ya que esos siempre han sido un tanto complicados para mi en cualquier lenguaje.

# %% [markdown]
# Ejercicio 3: Escribir un programa para gestionar un listado telefónico con los nombres y los teléfonos de los clientes de una empresa.
# El programa debe crear el archivo TXT con la lista si no existe
# El programa debe  tener una función para consultar el teléfono de un cliente e imprimirlo en pantalla.
# El programa debe  tener una función para  añadir el teléfono de un nuevo cliente al archivo TXT.
# El programa debe tener una función que permita visualizar todo el listado telefónico
# El programa debe tener una función que guarde esta lista en un archivo CSV.

# %%
file = open("TelefonosClientes.txt", "a+")
file.close()
import csv

def nuevo_tel(nombre, telefono):
    file = open("TelefonosClientes.txt", "a+")
    contacto = nombre + ": " + telefono + "\n"
    file.write(contacto)
    file.close()
    
def consulta_telefono(nombre):
    file = open("TelefonosClientes.txt", "r")
    lista = file.readlines()
    encontrado = False
    for x in range(0, len(lista)):
        for y in range(0, len(lista[x])):
            if lista[x][y] == ":":
                if lista[x][:y] == nombre:
                    encontrado = True
                    print(lista[x])
    if encontrado == False:
        print("No se encontro al cliente.")
    file.close()
    
def visualizar_archivo():
    file = open("TelefonosClientes.txt", "r")
    lista = file.readlines()
    for i in range(0, len(lista)):
        print(lista[i])
    file.close()
    
def crear_csv():
    file = open("TelefonosClientes.txt", "r")
    lista = file.readlines()
    nueva_lista = []
    row = []
    for x in range(0, len(lista)):
        for y in range(0, len(lista[x])):
            if (lista[x][y] == ":") or (lista[x][y] == ","):
                row.append(lista[x][:y])
                row.append(lista[x][y+1:].replace("\n", ""))
                nueva_lista.append(row)
                row = []
    #print(nueva_lista)
    with open('TelefonosClientes.csv', mode='w') as csv_file:
        contact_writer = csv.writer(csv_file, delimiter=',',quoting=csv.QUOTE_MINIMAL)
        for i in range(0, len(nueva_lista)):
            contact_writer.writerow(nueva_lista[i])
            print(nueva_lista[i])
    file.close()
        

#nuevo_tel("Jim Halpert", "555-3212")
#nuevo_tel("Pam Beasly", "555-4565")
#nuevo_tel("Michael Scott", "555-8525")
#nuevo_tel("Dwight Schrute", "555-7535")
#nuevo_tel("Angela Martin", "555-9515")

#visualizar_archivo()

#consulta_telefono("Michael Scot")

#crear_csv()
# Out:
# ['Jim Halpert', '555-3212']
# ['Pam Beasly', '555-4565']
# ['Michael Scott', '555-8525']
# ['Dwight Schrute', '555-7535']
# ['Angela Martin', '555-9515']
# ['Jim Halpert', ' 555-3212']
# ['Pam Beasly', ' 555-4565']
# ['Michael Scott', ' 555-8525']
# ['Dwight Schrute', ' 555-7535']
# ['Angela Martin', ' 555-9515']

# %% [markdown]
# Explicación: En este ejercicio tuve algunas complicaciones porque abria el archivo con el atributo "a+" de forma global desde el inicio pensando que con eso no seria necesario estar cerrando y abriendo en cada función pero eso no me funciono y termine abriendo y cerrando los archivos de acuerdo a cada función. En los comentarios del final se puede ver los datos con los que hice pruebas. El ultimo error que me encontre fue que en el archivo csv aparecia al final de todos los numeros telefonicos "\n" y las comillas para cerrar el texto las ponia en la siguiente fila por lo que use la función replace donde era necesario.

# %% [markdown]
# Ejercicio 4
# El archivo calificaciones.csv (archivo adjunto ) contiene las calificaciones de un curso. Durante el curso se realizaron dos exámenes parciales de teoría y un examen de prácticas. Escribir un programa que contenga las siguientes funciones:
#
# Una función que reciba el archivo de calificaciones y devuelva una lista de diccionarios, donde cada diccionario contiene la información de los exámenes y la asistencia de un alumno. La lista tiene que estar ordenada por apellidos.
# Una función que reciba una lista de diccionarios como la que devuelve la función anterior y añada a cada diccionario una nueva llave con la nota final del curso.  Teniendo en cuenta los siguientes criterios de evaluación
# Practicas 10 %
# Practica Final 30%
# Promedio de Parciales 1 y 2  20%
# Promedio de Exámenes 1 y 2 40%
# Una función que reciba una lista de diccionarios como la que devuelve la función anterior y devuelva dos listas, una con los alumnos aprobados y otra con los alumnos suspensos. Para aprobar el curso
# La asistencia tiene que ser mayor o igual que el 75%
# La nota final debe ser mayor o igual a 8.0

# %%
import csv

def funcion_a():
    l=[]
    d={}
    listofkeys=[]
    listofdicts=[]
    with open("calificaciones.csv","r") as file:
        csv_reader = csv.reader(file)
        list_of_csv = list(csv_reader)
        list_of_csv.pop(0)
        for i in range(0, len(list_of_csv[0])):
            listofkeys.append(list_of_csv[0][i])
        list_of_csv.pop(0)
        list_of_csv.sort()
        for i in range(0, len(list_of_csv)):
            for x in range(0, len(list_of_csv[i])):
                d[listofkeys[x]] = list_of_csv[i][x]
            listofdicts.append(d)
            d={}
    return listofdicts

def funcion_b(listofdicts):
    for i in range(0, len(listofdicts)):
        promparciales = (float(listofdicts[i]["Parcial1"]) + float(listofdicts[i]["Parcial2"])) / 2.0
        promexamenes = (float(listofdicts[i]["Examen1"]) + float(listofdicts[i]["Examen2"])) / 2.0
        notafinal = (promparciales * 0.2) + (promexamenes * 0.4) + (float(listofdicts[i]["Practicas"]) * 0.1) + (float(listofdicts[i]["Practica Final"]) * 0.3)
        listofdicts[i]["Nota Final"] = notafinal
    return listofdicts
    

def funcion_c(listofdicts):
    aprobados = []
    reprobados = []
    for i in range(0, len(listofdicts)):
        if (float(listofdicts[i]["Nota Final"]) >= 8.0) and (float(listofdicts[i]["Asistencia"][:2]) >= 75):
            aprobados.append(listofdicts[i])
        else:
            reprobados.append(listofdicts[i])
    return aprobados, reprobados
    
funcion_c(funcion_b(funcion_a()))
# Out:
# ([],
#  [{'Apellidos': 'Anido Bonet',
#    'Nombre': 'David',
#    'Asistencia': '90%',
#    'Parcial1': '5.5',
#    'Parcial2': '2.75',
#    'Examen1': '0',
#    'Examen2': '5',
#    'Practicas': '0',
#    'Practica Final': '0',
#    'Nota Final': 1.8250000000000002},
#   {'Apellidos': 'Bueno Cerdeira',
#    'Nombre': 'Patricia',
#    'Asistencia': '95%',
#    'Parcial1': '9.5',
#    'Parcial2': '9',
#    'Examen1': '0',
#    'Examen2': '0',
#    'Practicas': '6.25',
#    'Practica Final': '0',
#    'Nota Final': 2.475},
#   {'Apellidos': 'Casariego GarcÃ\xada',
#    'Nombre': 'RaÃºl',
#    'Asistencia': '98%',
#    'Parcial1': '4.25',
#    'Parcial2': '5.75',
#    'Examen1': '6',
#    'Examen2': '0',
#    'Practicas': '4',
#    'Practica Final': '5',
#    'Nota Final': 4.1},
#   {'Apellidos': 'Curbelo SÃ¡nchez',
#    'Nombre': 'Jorge',
#    'Asistencia': '75%',
#    'Parcial1': '6.75',
#    'Parcial2': '4.25',
#    'Examen1': '5',
#    'Examen2': '0',
#    'Practicas': '0',
# ...

# %% [markdown]
# Explicación: En la primer función separe los datos que necesitaba como llaves en una lista y elimine tanto el titulo como la lista que contenia las llaves para quedarme con los puros valores y por medio de un ciclo for crear un diccionario a la vez (uno por cada alumno) y metiendolos en la lista final. En la función 2 se itera en un ciclo for para acceder en cada iteración unicamente a los datos de cada alumno y extraer los datos para realizar los calculos y finalmente añadir el valor de nota final al diccionario de cada alumno. Finalmente en la ultima función se separa la lista en dos, pasando los diccionarios de cada alumno reprobado a una lista nueva y cada alumno aprobado en otra lista nueva, ambas listas son devueltas al final de la función.
