# %%
TAREA SEMANA 2 : FUNDAMENTOS DE PYTHON
Nombre : Jose Juan Razo Escamilla

# %%
#Ejercicio 1
#Las matemáticas financieras, resumidas en una frase, las podríamos definir como la rama de las matemáticas que estudia los flujos de dinero a través del tiempo. Básicamente se presupone que el dinero tiene menos valor en el futuro que en el presente, ya sea por un tema inflacionario o por la preferencia natural de las personas a priorizar el consumo presente.

#El valor futuro es el valor alcanzado por un determinado capital al final del período determinado (para el ejemplo usaremos la fórmula del interés compuesto). Para calcularlo se utiliza la siguiente fórmula
#VF=VA* ( 1+i )n

#El valor presente de una inversión es cuando calculamos el valor actual que tendrá una determinada cantidad que recibiremos o pagaremos en un futuro. Para calcularlo se utiliza la siguiente fórmula

#VA=VF( 1+i )n 

#Donde 
 #VF es el valor futuro, 
 #VA es el valor actual o inicial de la inversión, 
 #i es el tipo de interés y 
 #n es número de años de la inversión.

#Crear una función que reciba como entrada un capital, un tipo de interés y un número de años, y muestre por pantalla el valor futuro de la inversión cada año del periodo indicado.
#Crear una función que reciba como entrada un capital, un tipo de interés y un número de años, y muestre por pantalla el valor actual del capital cada año del periodo indicado.

# %%
print(f'para calcular valor futuro introduzca calculo_futuro, para valor presente calculo_presente, el interes introduzcalo en porcentaje')

def calculo_futuro(va,i,n):
    vf=va*(1+(i/100))**n
    print(f'el valor futuro con un capital de {va}, con un interes de {i} y en {n} años es de {vf}')

def calculo_presente(vf,i,n):
    va=vf/((1+(i/100))**n)
    print(f'el valor presente con un capital futuro de {vf}, con un interes de {i} y en {n} años es de {va}')

# %%
#Explicación: en este problema no tuve problema en el codigo, pero si en las formulas porque tuve que investigar si dichas expresiones
#ocupaban el interes representado en porcentaje o decimal. Por ello el programa pide ingresarlo en porcentaje al usar
#las funciones.

# %%
#Ejercicio 2
#El archivo cotización.csv (archivo adjunto ) contiene las cotizaciones de empresas con las siguientes columnas: 
#Nombre (nombre de la empresa), 
#Final (precio de la acción al cierre de bolsa), 
#Máximo (precio máximo de la acción durante la jornada), 
#Mínimo (precio mínimo de la acción durante la jornada), 
#Volumen (Volumen al cierre de bolsa), 
#Efectivo (capitalización al cierre en miles de euros).

#Construir una función reciba el fichero de cotizaciones y devuelva un diccionario con los datos del fichero por columnas.
#Construir una función que reciba el diccionario devuelto por la función anterior y cree un fichero en formato csv con el mínimo, el máximo y la media de cada columna.

# %%
import csv
import pandas as pd
import numpy as np
#def diccionario_csv():

with open("cotizacion.csv", 'r') as archivo: 
    for linea in csv.DictReader(archivo):
        print(linea)



#data=pd.read_csv("cotizacion.csv")
#print(data)
#print(data.Nombre)

lista=[]
header=[]
file=open("cotizacion.csv")
csvreader=csv.reader(file)
header=next(csvreader)
#print(header)
rows=[]

for row in csvreader:
    rows.append(row)
#print(rows)
lista_maximos=[]
lista_minimos=[]
lista_media=[]


for i in range(len(rows)):
    lista_maximos.append(float(rows[i][2]))
    lista_minimos.append(float(rows[i][3]))
    
lista_maximos=np.array((lista_maximos))
lista_minimos=np.array((lista_minimos))

lista_media=np.array(lista_media)
lista_media=(lista_maximos+lista_minimos)/2
new_header=[]
new_header.append(header[2])
new_header.append(header[3])
new_header.append('Media')

lista_maximos=list((lista_maximos))
lista_minimos=list((lista_minimos))
lista_media=list((lista_media))
lista_csv=[]
lista_csv=new_header+lista_maximos+lista_minimos

i=0
with open('nueva_cotizacion.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(new_header)
  
    
    for word in lista_maximos:
        writer.writerow([lista_maximos[i], lista_minimos[i], lista_media[i]])
        i=i+1

# %%
#Explicación: en este ejercicio tuve un monton de problemas. Desde saber que hace cada comando importado de csv hasta como utilizar la libreria
#numpy para la media. Sin embargo, lo más importante fue al momento de hacer el diccionario porque tenía muchos problemas 
#al leerlo, cuando quise hacer operaciones con Numpy me di cuenta que el formato del archivo cotizacion tenía muchos
#errores o mezcla de , con ., por ende primero limpié el csv haciendolo más homogeneo y de ahí todo fue más fácil

# %%
#Ejercicio 3
#Escribir un programa para gestionar un listado telefónico con los nombres y los teléfonos de los clientes de una empresa. 
#El programa debe crear el archivo TXT con la lista si no existe
#El programa debe  tener una función para consultar el teléfono de un cliente e imprimirlo en pantalla.
#El programa debe  tener una función para  añadir el teléfono de un nuevo cliente al archivo TXT.
#El programa debe tener una función que permita visualizar todo el listado telefónico
#El programa debe tener una función que guarde esta lista en un archivo CSV.

# %%
import csv
import pandas as pd
file = open("lista_numeros_clientes.txt", "w")
lista_clientes=[['Nombre cliente', 'Telefono' ],['Adriana Lopez', 1234567],['Julio Cesar', 567890],['Alejandro Magno',65432]]
#print(lista_clientes)
i=0
for word in lista_clientes:
    file.write(str(lista_clientes[i][0]))
    file.write('             ')
    file.write(str(lista_clientes[i][1]))
    file.write('\n')
    i=i+1
file.close()
#telefono=input(str('por favor, introduzca un numero a buscar: '))
#Funcion colsulta de telefono 
def buscar_telefono(telefono):
    comprobador=False

    for a in range(len(lista_clientes)):
        if str(telefono) in (str(lista_clientes[a][1])):
            comprobador=True
            cliente_telefono=lista_clientes[a][0]
        else:
            pass
    if comprobador:
        print(f'el telefono {telefono} le pertenece a {cliente_telefono}')
    else:
        print(f'el telefono {telefono} no le pertenece a ningun cliente')
#funcion añadir datos a lista      
def añadir_datos(nombre, telefono):
    nuevos_datos=[nombre,telefono]   
    lista_clientes.append(nuevos_datos)
    i=0
    file = open("lista_numeros_clientes.txt", "w")
    #print(lista_clientes)
    i=0
    for word in lista_clientes:
        file.write(str(lista_clientes[i][0]))
        file.write('             ')
        file.write(str(lista_clientes[i][1]))
        file.write('\n')
        i=i+1
    file.close()
#funcion de lectura de archivo    
def lectura_archivo():
    with open("lista_numeros_clientes.txt") as archivo:
        for linea in archivo:
            print(linea)
            
#Funcion para crear csv
def creacion_csv ():
    file = open("lista_numeros_clientes.csv", "w")
    i=0
    with open('lista_numeros_clientes.csv', 'w', newline='') as file:
        writer = csv.writer(file)  
        for word in lista_clientes:
            writer.writerow([lista_clientes[i][0], lista_clientes[i][1]])
            i=i+1
    print('nuevo archivo csv creado')
    data=pd.read_csv("lista_numeros_clientes.csv")
    print(data)

# %%
#Explicación: Hacer este ejercicio fue mas facil que el anterior porque ya tenía un poco más de conocimientos de como utilizar las herramientas
#import csv y pandas, además de que usar un archivo txt es mucho mas facil que csv. El hecho de crear los documentos desde
#cero y darles el formato propio contribuyó a la facilidad. Mi problema fue al añadir texto renglon por renglon
#pero gracias a este ejercicio comprendo lo que hace cada for 
#otro problema fue el de hacer doble indexacion al tener listas entre listas, especialmente dentro de los for´s
#porque me salía un error en Py que consistía en la no indezacion elementos lista, para ello tuve que convertir 
#datos de la misma lista en str

# %%
#Ejercicio 4
#El archivo calificaciones.csv (archivo adjunto ) contiene las calificaciones de un curso. Durante el curso se realizaron dos exámenes parciales de teoría y un examen de prácticas. Escribir un programa que contenga las siguientes funciones:

#Una función que reciba el archivo de calificaciones y devuelva una lista de diccionarios, donde cada diccionario contiene la información de los exámenes y la asistencia de un alumno. La lista tiene que estar ordenada por apellidos.
#Una función que reciba una lista de diccionarios como la que devuelve la función anterior y añada a cada diccionario una nueva llave con la nota final del curso.  Teniendo en cuenta los siguientes criterios de evaluación 
#Practicas 10 %
#Practica Final 30% 
#Promedio de Parciales 1 y 2  20%
#Promedio de Exámenes 1 y 2 40%
#Una función que reciba una lista de diccionarios como la que devuelve la función anterior y devuelva dos listas, una con los alumnos aprobados y otra con los alumnos suspensos. Para aprobar el curso
#La asistencia tiene que ser mayor o igual que el 75%
#La nota final debe ser mayor o igual a 8.0

# %%
import csv
import pandas as pd
import numpy as np
#esta parte es solo para ver la tabla con formato csv
data=pd.read_csv("calificaciones.csv", encoding='latin-1')
print(data)

        
#funcion para lista de diccionario con asistencia y examenes, inciso a
def inciso_a():
    lista_diccionario=[]
    with open('calificaciones.csv', encoding='latin-1') as csvfile:
        reader = csv.reader(csvfile, delimiter=',')
        #next(reader)
        dict1={}
        dict2={}
        dict3={}
        dict4={}
        for row in reader:
           dict1[row[0]] = row[1]
           dict2[row[1]] = row[2]
           dict3[row[2]] = row[5]
           dict4[row[5]] = row[6]
           lista_diccionario=[dict1,dict2,dict3,dict4]
    print(lista_diccionario)

#inciso b, creacion de nueva columna con nota final

with open('calificaciones.csv', 'r') as f:
         reader = csv.reader(f, delimiter=',')
         header=[]
         header=next(reader)
         header=[]
         header=next(reader)
         lista_parcial1=[]
         lista_parcial2=[]
         lista_examen1=[]
         lista_examen2=[]
         lista_practicas=[]
         lista_practicafinal=[]

         for row in reader:
            
             lista_parcial1.append(float(row[3]))
             lista_parcial2.append(float(row[4]))
             lista_examen1.append(float(row[5]))
             lista_examen2.append(float(row[6]))
             lista_practicas.append(float(row[7]))
             lista_practicafinal.append(float(row[8]))  
             
         lista_parcial1=np.array(lista_parcial1)
         lista_parcial2=np.array(lista_parcial2)
         lista_examen1=np.array(lista_examen1)
         lista_examen2=np.array(lista_examen2)
         lista_practicas=np.array(lista_practicas)
         lista_practicafinal=np.array(lista_practicafinal)
         lista_calificacion_final=(0.1*lista_practicas)+(0.3*lista_practicafinal)+(0.2*((lista_parcial1+lista_parcial2)/2))+(0.4*((lista_examen1+lista_examen2)/2))
print(lista_calificacion_final)
i=0
with open('calificaciones.csv', 'r', newline='') as archivo_csv, open('calificaciones_actualizado.csv', 'w', newline='') as archivo_actualizado:
    reader = csv.reader(archivo_csv)
    writer = csv.writer(archivo_actualizado)
   
    filas = []
    for fila in reader:
        filas.append(fila)
    print(len(filas))
    nueva_columna=[]
    for k in range(len(filas)):
        if k==0:
            nueva_columna.append(" ")
        elif k==1:
            nueva_columna.append("Nota final")
        else:
            nueva_columna.append(lista_calificacion_final[k-2])
            
    print(nueva_columna)
    for i in range(len(filas)):
        filas[i].insert(9, nueva_columna[i])

    for fila in filas:
       writer.writerow(fila)
       
#inciso c, determinacion de aprobados      
with open('calificaciones_actualizado.csv', encoding='latin-1') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    header=[]
    header=next(reader)
    header=[]
    header=next(reader)
    #next(reader)
    list_preaprobados_asistencia=[]
    list_preaprobados_nota=[]
    list_aprobados=[]
    list_alumnos=[]
    list_reprobados=[]
    z=0
    i=0
   
    for row in reader:
        list_alumnos.append([row[0], row[1]])
        if row[2]:
           
            if float(row[2])>=0.75:
                list_preaprobados_asistencia.append([row[0], row[1]])
            else:
                pass
            #
        if row[9]:
            if float(row[9])>=3:
                list_preaprobados_nota.append([row[0], row[1]])
            else:
               pass
    for i in range(len(list_preaprobados_asistencia)):
        if list_preaprobados_asistencia[i] in list_preaprobados_nota:
            list_aprobados.append(list_preaprobados_asistencia[i])
        else:
            pass
    for z in range(len(list_alumnos)):
        if not list_alumnos[z] in list_aprobados:
            list_reprobados.append(list_alumnos[z])
        else:
           pass
        
print(f'Los alumnos aprobados son: {list_aprobados}')
print(f'Los alumnos reprobados son: {list_reprobados}')

# %%
#Explicación: el utlimo ejercicio estuvo más complicado que el tercero porque pide muchas cosas: tanto leer archivos csv como editarlos
#para empezar, tuve problemas al leer el archivo por los acentos y formatos extraños, tuve que usar el encoding latin 
#para poder leerlos en Py. No tuve problemas para leer y extraer info del csv pero si tuve bastantes al querer agregarle una 
#nueva columna con las notas finales, en esta parte primero tuve que crear la lista de nota final a partir de operaciones 
#matematicas realizadas una vez extraida la info del csv original, luego tuve que aprender como insertar listas en un archivo 
#csv usando for, sin embargo, este metodo me trajo complicaciones de out of range porque tenia listas con diferentes tamaños
#(la diferencia de tamaño se debía a que al extraer data del csv, tenía que quitar renglones con texto para evitar errores
#al querer comparar con numeros)
#como se puede observar, este ultimo problema requirió resolver un monton de pequeños problemas que se generan al correr el código
#Otra observacion es que el inciso B y C deben de ejecutarse juntos (primero B y luego C) porque B le genera a C
#un nuevo documento que contiene la columna "nota final". El inciso A puede estar separado porque este solo devuelve
#parte de la info util para inciso B, por lo que es mejor extraer todo la info del documento original
