# %% [markdown]
# # Ejercicio 1
# Las matemáticas financieras, resumidas en una frase, las podríamos definir como la rama de las matemáticas que estudia los flujos de dinero a través del tiempo. Básicamente se presupone que el dinero tiene menos valor en el futuro que en el presente, ya sea por un tema inflacionario o por la preferencia natural de las personas a priorizar el consumo presente.
#
# El valor futuro es el valor alcanzado por un determinado capital al final del período determinado (para el ejemplo usaremos la fórmula del interés compuesto). Para calcularlo se utiliza la siguiente fórmula
# * VF=VA* ( 1+i )n
#
# El valor presente de una inversión es cuando calculamos el valor actual que tendrá una determinada cantidad que recibiremos o pagaremos en un futuro. Para calcularlo se utiliza la siguiente fórmula
#
# * VA=VF( 1+i )n
#
# Donde
#  VF es el valor futuro,
#  VA es el valor actual o inicial de la inversión,
#  i es el tipo de interés y
#  n es número de años de la inversión.
#
# * Crear una función que reciba como entrada un capital, un tipo de interés y un número de años, y muestre por pantalla el valor futuro de la inversión cada año del periodo indicado.
#
#
# * Crear una función que reciba como entrada un capital, un tipo de interés y un número de años, y muestre por pantalla el valor actual del capital cada año del periodo indicado.

# %%
def VF(cap,i,n):
    for iteracion in range(0,n+1):
        VF= cap*(1+i/100)**iteracion
        print(VF)
    return VF
cap= float(input('Ingresa un capital a invertir a 10 años con 10% de interes: '))
Inversion= VF(cap,10,10)
print('Tu retorno final sera el siguiente: ',Inversion)
# Out:
# Ingresa un capital a invertir a 10 años con 10% de interes: 10
# 10.0
# 11.0
# 12.100000000000001
# 13.310000000000004
# 14.641000000000004
# 16.105100000000007
# 17.71561000000001
# 19.48717100000001
# 21.435888100000014
# 23.579476910000018
# 25.937424601000025
# Tu retorno final sera el siguiente:  25.937424601000025

# %%
def VA(cap,i,n):
    lista = []
    for iteracion in range(0,n+1):
        VA= cap / (1+i/100)**iteracion
        print(VA)
    return VA
cap= float(input('Ingresa la cantidad a futuro que deseas obtener en 10 años a 10% de interes: '))
Futuro= VA(cap,10,10)
print(f'Lo que debes invertir hoy para en un futuro tener {cap} pesos es : ',Futuro)
# Out:
# Ingresa la cantidad a futuro que deseas obtener en 10 años a 10% de interes: 10
# 10.0
# 9.09090909090909
# 8.264462809917354
# 7.513148009015775
# 6.830134553650705
# 6.2092132305915495
# 5.644739300537772
# 5.131581182307064
# 4.66507380209733
# 4.240976183724846
# 3.855432894295314
# Lo que debes invertir hoy para en un futuro tener 10.0 pesos es :  3.855432894295314

# %% [markdown]
#  ### Explicacion
#  Como se trataba de imprimir el valor por cada año, se me ocurrio imprimir cada periodo, para ello utilice un ciclo for para ir calculando e ir imprimiendo
#
# De esta manera almacenaba empezando por el dia de Hoy n=0 hasta n=n, e igual el ciclo me ayudo ara calcular el valor de cada periodo.
#
# Tanto VA como VF me convergieron, ya que el VF[0] = 10 y VA[10] = 10 esto significa que ambas formulas son correctas, esta fue mi manera de verificar mi resultado.

# %% [markdown]
# # Ejercicio 2
# El archivo cotización.csv (archivo adjunto ) contiene las cotizaciones de empresas con las siguientes columnas:
# * Nombre (nombre de la empresa),
# * Final (precio de la acción al cierre de bolsa),
# * Máximo (precio máximo de la acción durante la jornada),
# * Mínimo (precio mínimo de la acción durante la jornada),
# * Volumen (Volumen al cierre de bolsa),
# * Efectivo (capitalización al cierre en miles de euros).
#
#
# \n
# * Construir una función reciba el fichero de cotizaciones y devuelva un diccionario con los datos del fichero por columnas.
# * Construir una función que reciba el diccionario devuelto por la función anterior y cree un fichero en formato csv con el mínimo, el máximo y la media de cada columna.

# %%
folder = '/Users\enriq\Desktop\Proyectos Python\Aletia\Python\ARCHIVOS'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def funcion1():
    import csv
    dic= {}
    filename = "cotizacion.csv"
    with open(filename, newline="") as csvfile:
        reader = csv.reader(csvfile, delimiter=";")
        lineas = list(reader)
        keys = lineas[0]

        for i in keys:
            dic[i] = [] #Parte del codigo donde creamos un diccionario con listas vacias del tamano keys

        for linea in lineas[1:]:
            dic[keys[0]].append(linea[0])

            for i in range(1, len(dic)):
                valor = linea[i].replace(",", ".") #Reemplazamos puntos por comas porque hay un dato que ya me cayo mal
                valor = valor.replace(".", "")  # Eliminamos los puntos como separadores de miles
                dic[keys[i]].append(valor)
        print(dic)
    return dic

# %%
def funcion2(dic, filename):
    import csv
    keys = list(dic.keys())
    with open(filename, mode="w", newline="") as csvfile:
        writer = csv.writer(csvfile, delimiter=";")
        writer.writerow(["Columna", "Mínimo", "Máximo", "Media"])
        for key in keys[1:]:
            valores = [float(val) for val in dic[key]]
            minimo = min(valores)
            maximo = max(valores)
            media = sum(valores) / len(valores)
            writer.writerow([key, minimo, maximo, media])

dic = funcion1()
filename = "resumen.csv"
funcion2(dic, filename)
# Out:
# {'Nombre': ['ACCIONA', 'ACERINOX', 'ACS', 'AENA', 'AMADEUS', 'ARCELORMIT.', 'BA.SABADELL', 'BA.SANTANDER', 'BANKIA', 'BANKINTER', 'BBVA', 'CAIXABANK', 'CELLNEX', 'CIE AUTOMOT.', 'ENAGAS', 'ENCE', 'ENDESA', 'FERROVIAL', 'GRIFOLS CL.A', 'IAG', 'IBERDROLA', 'INDITEX', 'INDRA A', 'INM.COLONIAL', 'MAPFRE', 'MEDIASET', 'MELIA HOTELS', 'MERLIN', 'NATURGY', 'R.E.C.', 'REPSOL', 'SIEMENS GAME', 'TEC.REUNIDAS', 'TELEFONICA', 'VISCOFAN'], 'Final': ['9595', '8668', '3728', '1671', '6996', '14152', '10165', '402', '2249', '656', '5024', '2763', '3017', '2344', '256', '3882', '2295', '2161', '233', '53', '845', '2493', '956', '9915', '2654', '6446', '814', '1208', '267', '19705', '14515', '1433', '23', '7204', '4846'], 'MÃ¡ximo': ['9675', '8672', '3766', '1675', '7064', '14318', '1033', '40675', '2262', '6604', '505', '2806', '307', '2374', '2566', '3974', '2303', '2172', '236', '546', '845', '2519', '9685', '9915', '2654', '6592', '819', '1208', '2677', '19875', '14605', '1439', '232', '7256', '4912'], 'MÃ\xadnimo': ['944', '8468', '3722', '1661', '6956', '1408', '10165', '401', '2224', '6522', '4969', '2762', '3017', '234', '2507', '3846', '2262', '2138', '2327', '5292', '8262', '2487', '9535', '9745', '262', '6446', '802', '1183', '2653', '19675', '1446', '14155', '2278', '7185', '4846'], 'Volumen': ['84962', '88599', '655982', '133738', '640476', '702841', '12358512', '36129692', '3024454', '1375976', '26447612', '13031097', '857237', '99506', '84254', '2099698', '1236799', '2065931', '719503', '2155081', '15637958', '2600144', '39206', '671753', '3045972', '2647557', '48021', '777543', '2100737', '1246171', '5046648', '1054847', '1221', '9913249', '6771'], 'Efectivo': ['816611', '763381', '2451729', '2233610', '4479547', '998965', '1263765', '14576544', '680354', '903020', '13256015', '3623922', '2596529', '234309', '2152477', '821983', '2823346', '4465605', '1678755', '1156195', '13142605', '6501292', '375557', '664038', '806313', '1727704', '391493', '935777', '5598654', '2458533', '7333378', '1508456', '280719', '7156499', '329543']}

# %% [markdown]
# #### Explicacion
# Fue un ejercicio bastante complicado, el obtener las keys y los datos fue sencillo, ya que la fila 0 contenia las keys, entonces dataset[1:] contenia todos los datos restantes, el problema empezo ya que varios datos estaban separados en otra notacion o algo por el estilo, y tuve que convertir los puntos por comas y luego quite todos los puntos como separadores ya que me estaban estorbando a la hora de ejecutar la funcion 2, decidi que era mas facil leerlo y corregirlo desde la lectura, especificamente desde "with open(filename, newline="") as csvfile:", pero no logre hacerlo, asi que lo hice en la parte donde inserte los valores. Honestamente fue un ejercicio muy retador.

# %% [markdown]
# # Ejercicio 3
# Escribir un programa para gestionar un listado telefónico con los nombres y los teléfonos de los clientes de una empresa.
# * El programa debe crear el archivo TXT con la lista si no existe
# * El programa debe  tener una función para consultar el teléfono de un cliente e imprimirlo en pantalla.
# * El programa debe  tener una función para  añadir el teléfono de un nuevo cliente al archivo TXT.
# * El programa debe tener una función que permita visualizar todo el listado telefónico
# * El programa debe tener una función que guarde esta lista en un archivo CSV.

# %%
filename = "appk4.txt"

def open_txt(filename):
    try:
        f = open(filename, "r")
        texto = f.read()
        texto= texto.split()
        f.close()
        return texto
    except:
        print(f"El archivo {filename} no puede ser leido o no se encuentra.")
        f= open(filename, "w")
        data= ['Kenia 8118908644\n','Roberto 909090909090\n','Enrique 907856489\n']
        f.writelines(data)
        f.close()
        return f
open_txt(filename)
# Out:
# ['Kenia',
#  '8118908644',
#  'Roberto',
#  '909090909090',
#  'Enrique',
#  '907856489',
#  'Karen',
#  '973664']

# %%
def cliente(nombre):
        f = open(filename, "r")
        texto = f.read()
        texto=texto.split()
        count=0
        for i in texto:
            count=count+1
            if i == nombre:
                break
        return texto[count]
cliente('Karen')
# Out:
# '973664'

# %%
def agregar():
    f = open(filename,'a') # Permite agregar nueva informacion al archivo
    data = str(input(' Ingresa a la Nueva persona, primero nombre y luego el telefono, separados por un " ": '))
    f.write(data +'\n')
    f.close()
    return 
agregar()
# Out:
#  Ingresa a la Nueva persona, primero nombre y luego el telefono, separados por un " ": Karen 973664

# %%
def visualizar():  
    fl = open(filename, "r")
    lines = fl.readlines()

    count = 0
    # Strips the newline character
    for line in lines:
      count += 1
      print("Cliente{}: {}".format(count, line.strip()))
    return 

visualizar()
# Out:
# Cliente1: Kenia 8118908644
# Cliente2: Roberto 909090909090
# Cliente3: Enrique 907856489
# Cliente4: Karen 973664

# %%
def guardar():
    with open('clientes.csv','w',newline='') as archivo_csv:
        escritor_csv = csv.writer(archivo_csv)
        fl = open(filename, "r")
        lines = fl.read()
        lines=lines.split()
        print(lines)
        for i in lines:
            escritor_csv.writerow(i)
    return archivo_csv
guardar()
# Out:
# ['Kenia', '8118908644', 'Roberto', '909090909090', 'Enrique', '907856489', 'Karen', '973664']
# <_io.TextIOWrapper name='clientes.csv' mode='w' encoding='cp1252'>

# %% [markdown]
# ### Explicacion
# Para este problema me encontre con varias situaciones, sobretodo en la parte en la que debiamos imprimir el numero telefonico de un cliente, para ello utilice un for y un contador, el cual el contador a pesar de iniciar en cero, el indice empezaba en 1 en la primera iteracion, con esto en mente si imprimir el contador, realmente estaba imprimiendo el indice +1 , asi que cuando detectaba el nombre de la persona y lo mandaba a imprimir, realmente estaba imprimiendo el numero telefonico.
#
# Queria pasarle como datos un diccionario, pero no supe como hacerlo, de todos modos utilice split para separar las palabras, aunque pienso que trabajar con diccionarios hubiera sido mas sencillo a la hora de mandar a llamar el numero de X cliente.

# %% [markdown]
# # Ejercicio 4
# El archivo calificaciones.csv (archivo adjunto ) contiene las calificaciones de un curso. Durante el curso se realizaron dos exámenes parciales de teoría y un examen de prácticas. Escribir un programa que contenga las siguientes funciones:
#
# * Una función que reciba el archivo de calificaciones y devuelva una lista de diccionarios, donde cada diccionario contiene la información de los exámenes y la asistencia de un alumno. La lista tiene que estar ordenada por apellidos.
# * Una función que reciba una lista de diccionarios como la que devuelve la función anterior y añada a cada diccionario una nueva llave con la nota final del curso.  Teniendo en cuenta los siguientes criterios de evaluación
# * Practicas 10 %
# * Practica Final 30%
# * Promedio de Parciales 1 y 2  20%
# * Promedio de Exámenes 1 y 2 40%
# * Una función que reciba una lista de diccionarios como la que devuelve la función anterior y devuelva dos listas, una con los alumnos aprobados y otra con los alumnos suspensos. Para aprobar el curso
# La asistencia tiene que ser mayor o igual que el 75%
# La nota final debe ser mayor o igual a 8.0

# %%
def funcion1():   
    import csv
    dic= {}
    lista = []
    filename = "calificaciones.csv"
    with open(filename, newline="") as csvfile:
        reader = csv.reader(csvfile, delimiter=";")
        lineas = list(reader)
        keys = lineas[1]
        for linea in lineas[2:]:
            dic = {}
            for i in range(len(keys)):
                dic[keys[i]] = linea[i]
            lista.append(dic)
    return lista   
funcion1()
# Out:
# [{'Apellidos,Nombre,Asistencia,Parcial1,Parcial2,Examen1,Examen2,Practicas,Practica Final': 'Anido Bonet,David,90%,5.5,2.75,0,5,0,0'},
#  {'Apellidos,Nombre,Asistencia,Parcial1,Parcial2,Examen1,Examen2,Practicas,Practica Final': 'Bueno Cerdeira,Patricia,95%,9.5,9,0,0,6.25,0'},
#  {'Apellidos,Nombre,Asistencia,Parcial1,Parcial2,Examen1,Examen2,Practicas,Practica Final': 'Casariego GarcÃ\xada,RaÃºl,98%,4.25,5.75,6,0,4,5'},
#  {'Apellidos,Nombre,Asistencia,Parcial1,Parcial2,Examen1,Examen2,Practicas,Practica Final': 'Curbelo SÃ¡nchez,Jorge,75%,6.75,4.25,5,0,0,6.5'},
#  {'Apellidos,Nombre,Asistencia,Parcial1,Parcial2,Examen1,Examen2,Practicas,Practica Final': 'DÃ\xadaz Souto,SofÃ\xada,82%,7,6.5,0,0,9,0'},
#  {'Apellidos,Nombre,Asistencia,Parcial1,Parcial2,Examen1,Examen2,Practicas,Practica Final': 'GarcÃ\xada Perez,Yaiza,85%,10,8,0,0,7.5,0'},
#  {'Apellidos,Nombre,Asistencia,Parcial1,Parcial2,Examen1,Examen2,Practicas,Practica Final': 'SÃ¡nchez JordÃ¡n,MarÃ\xada,92%,8.75,9,7,0,6.5,0'},
#  {'Apellidos,Nombre,Asistencia,Parcial1,Parcial2,Examen1,Examen2,Practicas,Practica Final': 'Lorenzo GarcÃ\xada,Jaime,100%,9.75,8.25,0,0,7.5,0'},
#  {'Apellidos,Nombre,Asistencia,Parcial1,Parcial2,Examen1,Examen2,Practicas,Practica Final': 'MartÃ\xadnez Lucas,Cecilia,86%,7,4,0,0,6.25,0'},
#  {'Apellidos,Nombre,Asistencia,Parcial1,Parcial2,Examen1,Examen2,Practicas,Practica Final': 'Mora PeÃ±aloza,Sandra,70%,5.25,2,0,4,6.5,0'},
#  {'Apellidos,Nombre,Asistencia,Parcial1,Parcial2,Examen1,Examen2,Practicas,Practica Final': 'Morillo Escudero,Ana,100%,9.5,10,3,0,8.75,0'},
#  {'Apellidos,Nombre,Asistencia,Parcial1,Parcial2,Examen1,Examen2,Practicas,Practica Final': 'MuÃ±oz GÃ³mez,Carolina,94%,7.75,6.5,0,0,4,0'},
#  {'Apellidos,Nombre,Asistencia,Parcial1,Parcial2,Examen1,Examen2,Practicas,Practica Final': 'Ramirez de la Puente,Raquel,75%,0,1,1,2.75,2.25,3.25'},
#  {'Apellidos,Nombre,Asistencia,Parcial1,Parcial2,Examen1,Examen2,Practicas,Practica Final': 'Riego Pizarro,Carlos,75%,4,2.5,5,3.75,0,0'},
#  {'Apellidos,Nombre,Asistencia,Parcial1,Parcial2,Examen1,Examen2,Practicas,Practica Final': 'RodrÃ\xadguez de Blas,Ignacio,80%,8.25,5.25,0,0,6.5,0'},
#  {'Apellidos,Nombre,Asistencia,Parcial1,Parcial2,Examen1,Examen2,Practicas,Practica Final': 'Moreno Angulo,Antonio,88%,9,6.75,4,0,5.25,0'}]

# %%
#No pude terminarlo

# %% [markdown]
# ### Explicacion
# Intente hacerle como el ejercicio numero 2, desde la funcion 2 ya no funciona de la misma manera.
