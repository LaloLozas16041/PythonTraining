# %% [markdown]
# TAREA SEMANA 2 : FUNDAMENTOS DE PYTHON
# Nombre : Ricardo Escalante

# %% [markdown]
# # Ejercicio 1
# Las matemáticas financieras, resumidas en una frase, las podríamos definir como la rama de las matemáticas que estudia los flujos de dinero a través del tiempo. Básicamente se presupone que el dinero tiene menos valor en el futuro que en el presente, ya sea por un tema inflacionario o por la preferencia natural de las personas a priorizar el consumo presente.
#
# El valor futuro es el valor alcanzado por un determinado capital al final del período determinado (para el ejemplo usaremos la fórmula del interés compuesto). Para calcularlo se utiliza la siguiente fórmula
# VF=VA* ( 1+i )n
#
# El valor presente de una inversión es cuando calculamos el valor actual que tendrá una determinada cantidad que recibiremos o pagaremos en un futuro. Para calcularlo se utiliza la siguiente fórmula
#
# VA=VF( 1+i )n
#
# Donde
#  VF es el valor futuro,
#  VA es el valor actual o inicial de la inversión,
#  i es el tipo de interés y
#  n es número de años de la inversión.
#
# Crear una función que reciba como entrada un capital, un tipo de interés y un número de años, y muestre por pantalla el valor futuro de la inversión cada año del periodo indicado.
# Crear una función que reciba como entrada un capital, un tipo de interés y un número de años, y muestre por pantalla el valor actual del capital cada año del periodo indicado.

# %%
def valor_futuro(capital, tasa_interes, num_anos):
    for _i in range(1, num_anos+1):
        _vf = capital * (1 + tasa_interes)**_i
        print(f"El valor futuro en el año {_i} es: ${_vf:.2f}")

def valor_actual(capital, tasa, años):
    for _i in range(1, años+1):
        _va = capital / ((1 + tasa)**_i)
        print(f"El valor actual en el año {_i}: ${_va:.2f}")

# %%
valor_futuro(1000, 0.05, 10)
valor_actual(1000, 0.05, 10)
# Out:
# El valor futuro en el año 1 es: $1050.00
# El valor futuro en el año 2 es: $1102.50
# El valor futuro en el año 3 es: $1157.63
# El valor futuro en el año 4 es: $1215.51
# El valor futuro en el año 5 es: $1276.28
# El valor futuro en el año 6 es: $1340.10
# El valor futuro en el año 7 es: $1407.10
# El valor futuro en el año 8 es: $1477.46
# El valor futuro en el año 9 es: $1551.33
# El valor futuro en el año 10 es: $1628.89
# El valor actual en el año 1: $952.38
# El valor actual en el año 2: $907.03
# El valor actual en el año 3: $863.84
# El valor actual en el año 4: $822.70
# El valor actual en el año 5: $783.53
# El valor actual en el año 6: $746.22
# El valor actual en el año 7: $710.68
# El valor actual en el año 8: $676.84
# El valor actual en el año 9: $644.61
# El valor actual en el año 10: $613.91

# %% [markdown]
# # Explicación:
# se van aplicando la formula n numero de veces al numero de años en ambas formulas y se aplica la formula correspondiente.

# %% [markdown]
# # Ejercicio 2
# El archivo cotización.csv (archivo adjunto ) contiene las cotizaciones de empresas con las siguientes columnas:
# Nombre (nombre de la empresa),
# Final (precio de la acción al cierre de bolsa),
# Máximo (precio máximo de la acción durante la jornada),
# Mínimo (precio mínimo de la acción durante la jornada),
# Volumen (Volumen al cierre de bolsa),
# Efectivo (capitalización al cierre en miles de euros).
#
# Construir una función reciba el fichero de cotizaciones y devuelva un diccionario con los datos del fichero por columnas.
# Construir una función que reciba el diccionario devuelto por la función anterior y cree un fichero en formato csv con el mínimo, el máximo y la media de cada columna.

# %%
import pandas as pd

def leer_cotizaciones(archivo):
    
    #_df = pd.read_csv(archivo, sep=";", decimal=",", thousands=".")
    #_df = pd.read_csv(archivo, sep=";", decimal=",")
    _df = pd.read_csv(archivo, sep=";", decimal=",", thousands=".", index_col="Nombre")
    # Convierte el DataFrame a un diccionario
    _datos = _df.to_dict(orient="list")

    return _datos

    
def resumen_cotizaciones(datos, columnas, archivo):
    _df = pd.DataFrame(datos)[columnas]
    _resumen = {"Maximo": df.max(), "Minimo": df.min(), "Media": df.mean()}
    _resumen = pd.DataFrame(resumen).round(2)
    _resumen.index.name = 'Columnas:'
    _resumen.to_csv(archivo, sep="|")
    
datos = leer_cotizaciones('cotizacion.csv')
datos
# Out:
# {'Final': [95.95,
#   8668.0,
#   37.28,
#   167.1,
#   69.96,
#   14152.0,
#   1.0165,
#   4.02,
#   2249.0,
#   6.56,
#   5024.0,
#   2763.0,
#   30.17,
#   23.44,
#   25.6,
#   3882.0,
#   22.95,
#   21.61,
#   23.3,
#   5.3,
#   8.45,
#   24.93,
#   9.56,
#   9915.0,
#   2654.0,
#   6446.0,
#   8.14,
#   12.08,
#   26.7,
#   19705.0,
#   14515.0,
#   14.33,
#   23.0,
#   7204.0,
#   48.46],
#  'Máximo': [96.75,
#   8672.0,
#   37.66,
#   167.5,
#   70.64,
#   14318.0,
#   1033.0,
#   4.0675,
#   2262.0,
#   6604.0,
#   5.05,
#   2806.0,
#   30.7,
#   23.74,
#   25.66,
#   3974.0,
#   23.03,
#   21.72,
#   23.6,
#   5.46,
#   8.45,
#   25.19,
#   9685.0,
#   9915.0,
#   2654.0,
#   6592.0,
#   8.19,
#   12.08,
#   26.77,
#   19875.0,
#   14605.0,
#   14.39,
#   23.2,
#   7256.0,
#   49.12],
#  'Mínimo': [94.4,
#   8468.0,
#   37.22,
#   166.1,
#   69.56,
#   14.08,
#   1.0165,
#   4.01,
#   2224.0,
#   6522.0,
#   4969.0,
#   2762.0,
#   30.17,
#   23.4,
#   25.07,
#   3846.0,
# ...

# %%
datos = leer_cotizaciones("cotizacion.csv")
columnas = ["Final", "Máximo", "Mínimo","Volumen","Efectivo"]
resumen_cotizaciones(datos, columnas, "resumen_cotizacion.csv")
#resumen_cotizaciones(datos,'Final', "resumen_cotizacion.csv")

# %% [markdown]
# # Explicación:
# Al leer los datos del archivo esta separado por ';' y en algunas columnas el decimal se identifica con coma ',' y la columna volumen usal el punto '.' como separador, existe manera de usar la funcion 'replace' para limpiar la data, pero en la misma funcion de pandas tiene parametros decimal="," y  thousands="." estos parametros indican que la coma se usa como separador decimal en algunas columnas. Además, el parámetro thousands=".", que indica que el punto se usa como separador de miles en algunas columnas.
# Para crear el archivo que con maximo, minimo y media de cada columna se creo primero una lista con las columnas a ser evaluadas y en la funcion recibe esta lista como parametro, y en pandas se castean en un DataFrame de Pandas

# %% [markdown]
# # Ejercicio 3
# Escribir un programa para gestionar un listado telefónico con los nombres y los teléfonos de los clientes de una empresa.
# El programa debe crear el archivo TXT con la lista si no existe
# El programa debe  tener una función para consultar el teléfono de un cliente e imprimirlo en pantalla.
# El programa debe  tener una función para  añadir el teléfono de un nuevo cliente al archivo TXT.
# El programa debe tener una función que permita visualizar todo el listado telefónico
# El programa debe tener una función que guarde esta lista en un archivo CSV.

# %%
import pandas as pd
import os


def crear_lista_telefonica(archivo):
    # Crea el DataFrame si el archivo no existe
    if not os.path.exists(archivo):
        _df = pd.DataFrame(columns=["Nombre", "Telefono"])
        _df.to_csv(archivo, sep=";", index=False)


def consultar_telefono(nombre, archivo):
    # Lee el archivo CSV y carga los datos en un DataFrame
    _df = pd.read_csv(archivo, sep=";")

    # _filtro = _df.loc[_df['Nombre'] == nombre]

    # Imprimir en pantalla el resultado de la búsqueda
    # print(_filtro)

    # Busca el teléfono del cliente por su nombre
    _telefono = _df.loc[_df["Nombre"] == nombre, "Telefono"].iloc[0]

    # Imprime el teléfono en pantalla
    print(f"El teléfono de {nombre} es {_telefono}")


def agregar_cliente(nombre, telefono, archivo):
    # Lee el archivo CSV y carga los datos en un DataFrame
    _df = pd.read_csv(archivo, sep=";")

    # Crea un nuevo DataFrame con los datos del nuevo cliente
    _nuevo_cliente = pd.DataFrame([[nombre, telefono]], columns=["Nombre", "Telefono"])

    # Agrega el nuevo cliente al DataFrame existente
    _df = _df._append(_nuevo_cliente, ignore_index=True)

    # Guarda el DataFrame actualizado en el archivo CSV
    _df.to_csv(archivo, sep=";", index=False)


def visualizar_listado(archivo):
    # Lee el archivo CSV y carga los datos en un DataFrame
    _df = pd.read_csv(archivo, sep=";")

    # Imprime el DataFrame en pantalla
    print(_df)


def guardar_en_csv(archivo):
    # Lee el archivo CSV y carga los datos en un DataFrame
    _df = pd.read_csv(archivo, sep=";")
    # Definir el nuevo nombre del archivo con la extensión .csv
    _nuevo_nombre_archivo = archivo.replace('.txt', '.csv')

    # Renombrar el archivo
    # os.rename(nombre_archivo, _nuevo_nombre_archivo)
    # Crea un nuevo archivo CSV con el mismo contenido
    _df.to_csv(_nuevo_nombre_archivo, sep=",", index=False)

# %%
crear_lista_telefonica("listado_telefonico.txt")
agregar_cliente("Pedro Preciado", "555-1234", "listado_telefonico.txt")
agregar_cliente("Juan Soler", "888-3456", "listado_telefonico.txt")
agregar_cliente("Karla Hernandez", "222-1256", "listado_telefonico.txt")
agregar_cliente("Nadia Comaneci", "333-9632", "listado_telefonico.txt")
consultar_telefono("Karla Hernandez", "listado_telefonico.txt")
visualizar_listado("listado_telefonico.txt")
guardar_en_csv("listado_telefonico.txt")
visualizar_listado("listado_telefonico.txt")
# Out:
# El teléfono de Karla Hernandez es 222-1256
#             Nombre  Telefono
# 0   Pedro Preciado  555-1234
# 1       Juan Soler  888-3456
# 2  Karla Hernandez  222-1256
# 3   Nadia Comaneci  333-9632
#             Nombre  Telefono
# 0   Pedro Preciado  555-1234
# 1       Juan Soler  888-3456
# 2  Karla Hernandez  222-1256
# 3   Nadia Comaneci  333-9632

# %% [markdown]
# Explicación: siguiendo las instrucciones se crea el archivo y se procede a agregar registros, se puede buscar por el nombre de un registro, y se muestra el listado, además que se puede exportar a un CSV. La parte más complicada es buscar registros en un archivo ya que las variaciones pueden ser muchas y hay que considerar muchos casos.

# %% [markdown]
# # Ejercicio 4
# El archivo calificaciones.csv (archivo adjunto ) contiene las calificaciones de un curso. Durante el curso se realizaron dos exámenes parciales de teoría y un examen de prácticas. Escribir un programa que contenga las siguientes funciones:
#
# Una función que reciba el archivo de calificaciones y devuelva una lista de diccionarios, donde cada diccionario contiene la información de los exámenes y la asistencia de un alumno. La lista tiene que estar ordenada por apellidos.
# Una función que reciba una lista de diccionarios como la que devuelve la función anterior y añada a cada diccionario una nueva llave con la nota final del curso.  Teniendo en cuenta los siguientes criterios de evaluación
# Practicas 10 %
# Practica Final 30%
# Promedio de Parciales 1 y 2  20%
# Promedio de Exámenes 1 y 2 40%
# Una función que reciba una lista de diccionarios como la que devuelve la función anterior y devuelva dos listas, una con los alumnos aprobados y otra con los alumnos suspensos. Para aprobar el curso
# La asistencia tiene que ser mayor o igual que el 75%
# La nota final debe ser mayor o igual a 8.0

# %%
def leer_calificaciones(nombre_archivo):
    #_tabla = pd.read_csv(nombre_archivo)
    _tabla = pd.read_csv(nombre_archivo,skiprows=1)
    _tabla = _tabla.sort_values(by=["Apellidos", "Nombre"])
    _alumnos = []
    for _i, _fila in _tabla.iterrows():
        _alumno = {}
        _alumno["Apellidos"] = _fila["Apellidos"]
        _alumno["Nombre"] = _fila["Nombre"]
        _alumno["Asistencia"] = _fila["Asistencia"]
        _alumno["Parcial1"] = _fila["Parcial1"]
        _alumno["Parcial2"] = _fila["Parcial2"]
        _alumno["Examen1"] = _fila["Examen1"]
        _alumno["Examen2"] = _fila["Examen2"]
        _alumno["Practicas"] = _fila["Practicas"]
        _alumno["Practica Final"] = _fila["Practica Final"]
        _alumnos.append(_alumno)
    return _alumnos

def calcular_nota_final(alumnos):
    for _alumno in alumnos:
        _promedio_parciales = (_alumno["Parcial1"] + _alumno["Parcial2"]) / 2
        _promedio_examenes = (_alumno["Examen1"] + _alumno["Examen2"]) / 2
        _nota_final = (_promedio_parciales * 0.2) + (_promedio_examenes * 0.4) + (_alumno["Practicas"] * 0.1) + (_alumno["Practica Final"] * 0.3)
        _alumno["Nota Final"] = _nota_final.__round__(2)
    alumnos.append(_alumno)
    return alumnos

def clasificar_alumnos(calificaciones):
    _aprobados = []
    _suspensos = []
    for _alumno in calificaciones:
        _asistencia = float(_alumno['Asistencia'].replace('%', ''))
        _nota_final = _alumno['Nota Final']
        if _asistencia >= 75 and _nota_final >= 8:
            _aprobados.append(_alumno)
        else:
            _suspensos.append(_alumno)
    return _aprobados, _suspensos

# %%
alumnos = leer_calificaciones('calificaciones.csv')
# print(alumnos)
mi_lista = calcular_nota_final(alumnos)
#print(mi_lista)
_aprobados, _suspensos = clasificar_alumnos(mi_lista)
print(f'''Aprobados: {_aprobados}, 
      Suspenso:{_suspensos}''')
# Out:
# Aprobados: [],
# ...

# %% [markdown]
# # Explicación:
# Al leer el archivo CSV tenia una leyenda adiciona en el primer renglos, para ignorar el primer renglón, podemos usar el parámetro skiprows de la función pd.read_csv(), que nos permite indicar cuántas filas queremos saltar al leer el archivo.
# Se utiliza la funcion sort_values para ordenar por apellidos u nombre, se crea la lista con los alumnos, y al crear la se va creando un diccionario nuevo por registro que se añade a la lista alumnos.
# Para el calculo se recorre la cada diccinario dentro de la lista de alumnos y se saca la Nota Final
# para la calificacion se filtran por el porcentaje el cual se tuvo que limpiar o remplazar el signo '%' para hacer el calculo.
# La data muestra un grupo muy inconsitente o desmotivado por la materia que la mayoria de los alunos no hizo o paso la practica la cual es un importante porcentaje de la materia.
