# %% [markdown]
# # TAREA SEMANA 3 : FUNDAMENTOS DE PYTHON
# ## Nombre : Gerardo Figueroa Golarte

# %% [markdown]
# ## Ejercicio 1
# Escribir dos funciones que simulan una calculadora científica que permita calcular el seno, coseno, tangente, exponencial y logaritmo neperiano o natural (logaritmo en base euler).

# %% [markdown]
# ### Inciso A
# La función uno preguntará al usuario el intervalo donde quiere aplicar la función matemática y la función a aplicar, y mostrará por pantalla una tabla donde la primera columna será los valores del intervalo dado (x) y la columna 2 tendrá los resultados de el resultado de aplicar la función a este intervalo (y).

# %%
import pandas as pd
import numpy as np

def tabfun(interval, func):
    
    x = np.linspace(interval[0], interval[1], 100)
    
    y = func(x)
    
    df = pd.DataFrame({'x': x, 'y': y})
    
    return df

df = tabfun((1, 10), np.sin)
df
# Out:
#             x         y
# 0    1.000000  0.841471
# 1    1.090909  0.887047
# 2    1.181818  0.925297
# 3    1.272727  0.955905
# 4    1.363636  0.978619
# ..        ...       ...
# 95   9.636364 -0.210010
# 96   9.727273 -0.297903
# 97   9.818182 -0.383334
# 98   9.909091 -0.465600
# 99  10.000000 -0.544021
#
# [100 rows x 2 columns]

# %% [markdown]
# #### Explicacion:
#  - Asigné linspace para definir el espacio entre los valores introducidos a la función.
#  - Asigné estos valores a x y luego asigné a y la función aplicada a x. Uní "x" y "y" con Dataframe().

# %% [markdown]
# ### Inciso B
# La función dos graficará con matplotlib el resultado de función anterior y la mostrará en pantalla. Recuerden poner los títulos ejes y demás configuraciones de las gráficas para que queden de la mejor manera posible.

# %%
import matplotlib.pyplot as plt

df = tabfun((1, 10), np.log)
df

def tab2graph(df):
    x = df['x']
    y = df['y']
    plt.plot(x,y)
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.show()
#    df.plot(x='x', y='y').set(xlabel='x',ylabel='y')
#    plt.show()
    
tab2graph(df)

# %% [markdown]
# #### Explicación:
#  - Dentro de una función que toma el argumento df.
#  - Se crearon las variables "X" y "Y" para asignarles los valores de las columnas "x" y "y" del dataframe del argumento.
#  - Utilizando estas variables se aplicó la función plot para crear el gráfico.

# %% [markdown]
# ## Ejercicio 2
# Escribir un programa para ver los beneficios de una empresa en un periodo de años.
# El programa debe cumplir los siguientes requisitos:

# %% [markdown]
# ### Inciso A
# El programa tiene que preguntar al usuario por un año inicial y otro final, y después preguntar por los ingresos y egresos de cada año desde el año inicial hasta el año final.
# Debe garantizar que por lo menos haya 5 años entre el año inicial y el final.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

def balxaño():
    
    añoin = int(input("Ingresa el año inicial: "))
    añofin = int(input("Ingresa el año final: "))

    if (añofin - añoin) >= 5:
                
        numaños = añofin - añoin + 1

        ingreso = []
        egreso = []
        for i in range(numaños):
            ingreso.append(float(input(f"Introduce el ingreso del año {añoin + i}: ")))
            egreso.append(float(input(f"Introduce el egreso del año {añoin + i}: ")))

        return df
    
    else:
        print("Ingresad un intervalo mayor a 5 años")
        
df = balxaño()
df

# %% [markdown]
# #### Explicación:
#  - Pedí los datos necesarios para evaluar la condición (intervalo >= 5)
#  - Continué la función dentro de la condición.
#  - Creé un rango para un loop donde se pidiera el ingreso y egreso de cada año.
#  - Creé listas para que se les fuera agregando cada ingreso y egreso.

# %% [markdown]
# ### Inciso B
# Con los datos introducidos se deben crear un dataframe, con las columnas fecha, ingresos y egresos.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

def tablbal():
    
    añoin = int(input("Ingresa el año inicial: "))
    añofin = int(input("Ingresa el año final: "))

    if (añofin - añoin) >= 5:
                
        
        numaños = añofin - añoin + 1

        
        ingreso = []
        egreso = []
        for i in range(numaños):
            ingreso.append(float(input(f"Introduce el ingreso del año {añoin + i}: ")))
            egreso.append(float(input(f"Introduce el egreso del año {añoin + i}: ")))

        interval = np.array(range(añoin, añofin+1))

        df = pd.DataFrame({'Fecha': interval, 'Ingreso': ingreso, 'Egreso': egreso})
        return df
    else:
        print("Ingresad un intervalo mayor a 5 años")
        
df = tablbal()
df

# %% [markdown]
# #### Explicación:
#  - Retomé la función desde el bucle.
#  - Utilicé un array para utilizarlo en el dataframe como indicador
#  - Creé un intervalo para asignarlo a la tabla como eje para los años.

# %% [markdown]
# ### Inciso C
# El programa debe generar otra columna con el beneficio de cada año (ingresos menos egresos) y mostrarla por pantalla.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

def tablbal():
    
    añoin = int(input("Ingresa el año inicial: "))
    añofin = int(input("Ingresa el año final: "))

    if (añofin - añoin) >= 5:
                
        
        numaños = añofin - añoin + 1

        
        ingreso = []
        egreso = []
        for i in range(numaños):
            ingreso.append(float(input(f"Introduce el ingreso del año {añoin + i}: ")))
            egreso.append(float(input(f"Introduce el egreso del año {añoin + i}: ")))

        ganancias = []
        for i in range(numaños):
            ganancias.append(ingreso[i]-egreso[i])
        
        interval = np.array(range(añoin, añofin+1))
        
        

        df = pd.DataFrame({'Fecha': interval, 'Ingreso': ingreso, 'Egreso': egreso, 'Ganancias': ganancias})
        return df
    else:
        print("Ingresad un intervalo mayor a 5 años")
        
df = tablbal()
df

# %% [markdown]
# ### Explicación:
#  - Creé la variable ganancias en cero.
#  - Establecí un bucle con el mismo rango que el pasado para que pasara por cada año pero ahora restando el egreso del ingreso y añadiendo cada valor a la lista vacía.
#   - Incluí en el dataframe el valor "Ganancias" para que sea incluido en la tabla.

# %% [markdown]
# ### Inciso D
# El programa debe crear otra columna llamada ganancia la cuál indique para cada año si ha habido beneficios o no de manera booleana y mostrarla por pantalla.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

def tablbal():
    
    añoin = int(input("Ingresa el año inicial: "))
    añofin = int(input("Ingresa el año final: "))

    if (añofin - añoin) >= 5:
                
        
        numaños = añofin - añoin + 1

        
        ingreso = []
        egreso = []
        for i in range(numaños):
            ingreso.append(float(input(f"Introduce el ingreso del año {añoin + i}: ")))
            egreso.append(float(input(f"Introduce el egreso del año {añoin + i}: ")))

        ganancias = []
        for i in range(numaños):
            if ingreso[i] > egreso[i]:
                ganancias.append(ingreso[i]-egreso[i])
            else:
                ganancias.append(0)
                
        gananciasino = []
        for i in range(numaños):
            gananciasino.append(ingreso[i] > egreso[i])
            
        interval = np.array(range(añoin, añofin+1))
        
        

        df = pd.DataFrame({'Fecha': interval, 'Ingreso': ingreso, 'Egreso': egreso, 'Ganancias': ganancias, 'Hubo Ganancia': gananciasino})
        return df
    else:
        print("Ingresad un intervalo mayor a 5 años")
        
df = tablbal()
df

# %% [markdown]
# #### Explicación:
# - Creé la variable gananciasino en ceros.
# - Establecí un bucle con el mismo rango que el pasado para que pasara por cada año pero ahora con la declaración ingreso es mayor a egreso y añadiendo cada valor a la lista vacía.
# - Incluí en el dataframe el valor "Hubo Ganancias" para que fuera incluido en la tabla.

# %% [markdown]
# ### Inciso E
# Finalmente el programa debe mostrar por pantalla la lista de los años con pérdidas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

def tablbal():
    
    añoin = int(input("Ingresa el año inicial: "))
    añofin = int(input("Ingresa el año final: "))

    if (añofin - añoin) >= 5:
                
        
        numaños = añofin - añoin + 1

        
        ingreso = []
        egreso = []
        for i in range(numaños):
            ingreso.append(float(input(f"Introduce el ingreso del año {añoin + i}: ")))
            egreso.append(float(input(f"Introduce el egreso del año {añoin + i}: ")))

        ganancias = []
        for i in range(numaños):
            if ingreso[i] > egreso[i]:
                ganancias.append(ingreso[i]-egreso[i])
            else:
                ganancias.append(0)
                
        perdidas = []
        for i in range(numaños):
            if ingreso[i] < egreso[i]:
                perdidas.append(egreso[i]-ingreso[i])
            else:
                perdidas.append(0)
        
        
        gananciasino = []
        for i in range(numaños):
            gananciasino.append(ingreso[i] > egreso[i])
            
        interval = np.array(range(añoin, añofin+1))
        
        

        df = pd.DataFrame({'Fecha': interval, 'Ingreso': ingreso, 'Egreso': egreso, 'Utilidad': ganancias, 'Perdidas': perdidas, 'Ganancia': gananciasino})
        return df
    else:
        print("Ingresad un intervalo mayor a 5 años")
        
df = tablbal()
df

# %% [markdown]
# #### Explicación:
#  - Agregué una condicional en el bucle de ganancias para que añadiera el resultado de la suma solo si el ingreso era mayor.
#  - Creé una lista "perdidas" a la cual un bucle le va agregando valores si el egreso es mayor al ingreso si no, le agrega un cero.
#  - Incluí la columna "Perdidas" en el dataframe.

# %% [markdown]
# ## Ejercicio 3
# El fichero horas-trabajo.csv contiene el número de horas mensuales trabajadas por los empleados de una empresa durante el primer cuatrimestre. Crear un programa que realice las siguientes operaciones utilizando la librería Pandas:

# %% [markdown]
# ### Inciso A
# Crea una columna con el número total de horas trabajadas para cada operador

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

file = "horas-trabajo.csv"
df = pd.read_csv(file, sep=';')

df = df.fillna(0)

df['Total de Horas'] = df['Enero'] + df['Febrero'] + df['Marzo'] + df['Abril']
df

# %% [markdown]
# #### Explicación:
# Este ejercicio me pareció sencillo.
#  - Leí el archivo indicando el separador y luego llené los espacios vacíos con ceros.
#  - Creé una nueva columna declarandola con los corchetes y asignadole la suma de las columnas que representan las horas por mes.

# %% [markdown]
# ### Inciso B
# Muestra cual es el promedio de horas trabajadas en total en la empresa durante el mes Marzo

# %%
marzomed = df['Marzo'].mean()
marzomed
# Out:
# 114.44444444444444

# %% [markdown]
# #### Explicación:
# - Seleccioné la columna Marzo y le apliqué la función "mean()" para sacar el promedio.

# %% [markdown]
# ### Inciso C
# Muestra cuántos operadores hay por cada departamento de la empresa.

# %%
numxdep = df.groupby('Departamento')['Id'].count()
numxdep
# Out:
# Departamento
# IT             2
# Marketing      1
# Proveedores    2
# Ventas         4
# Name: Id, dtype: int64

# %% [markdown]
# #### Explicación:
# Este ejercecio también fue sencillo.
#  - En una nueva variable, asigné el dataframe aplicándole la función groupby a la columna departamento y
#  - especificando que se incluyera el conteo de ID

# %% [markdown]
# ### Inciso D
# Muestra el número de empleados que han trabajado todos los meses, es decir, que tienen un número de horas todos los meses del cuatrimestre.

# %%
file = "horas-trabajo.csv"
df1 = pd.read_csv(file, sep=';')

df1 = df1.dropna()
df1['Id']
# Out:
# 0     OP1
# 2     OP3
# 3     OP5
# 5     OP7
# 6     OP8
# 7     OP9
# 8    OP10
# Name: Id, dtype: object

# %% [markdown]
# #### Explicación:
#  - Apliqué dropna sin especificidad para elminar cualquier columna con un NaN.

# %% [markdown]
# ## Ejercicio 4
# Crear un programa utilizando la librería Pandas y Matplotlib que realice lo siguiente:

# %% [markdown]
# ### Inciso A
# Crear el siguiente DataFrame indexado:
#
# Dia
# Calorias
# Tiempo
# Lunes
# 420
# 60
# Martes
# 380
# 40
# Miercoles
# 390
# 75
# Jueves
# 490
# 55
# Viernes
# 300
# 45

# %%
df = pd.DataFrame({'Día': ['Lunes', 'Martes', 'Miercoles', 'Jueves', 'Viernes'], 'Calorias': [420, 380, 390, 490, 300], 'Tiempo': [60, 40, 75, 55, 45]})
df = df.set_index('Día')
df
# Out:
#            Calorias  Tiempo
# Día
# Lunes           420      60
# Martes          380      40
# Miercoles       390      75
# Jueves          490      55
# Viernes         300      45

# %% [markdown]
# #### Explicación:
#  - Creé una variable para asignarle el dataframe.
#  - Dentro de la función dataframe() tecleé directamente una lista de diccionarios asociando el atributo a la lista de valores que la componen.

# %% [markdown]
# ### Inciso B
# Calcular la media, mediana y desviación típica de ambas columnas.

# %%
stats = df.describe()
stats = pd.DataFrame({'Media': stats.loc['mean'],'Mediana': stats.loc['50%'], 'Desviación Típica': stats.loc['std']})
stats
# Out:
#           Media  Mediana  Desviación Típica
# Calorias  396.0    390.0          68.774995
# Tiempo     55.0     55.0          13.693064

# %% [markdown]
# #### Explicación:
# - Calculé los valores solicidatos con la función describe().
# - Creé un nuevo dataframe tomando de describe() solo la media, mediana y desviación típica.

# %% [markdown]
# ### Inciso C
# Añadir otra columna booleana al DataFrame para ver si se ha cumplido el reto de quemar más de 400 calorías por hora. La nueva columna debe generarse aplicando una fórmula a las otras columnas.

# %%
df = pd.DataFrame({'Día': ['Lunes', 'Martes', 'Miercoles', 'Jueves', 'Viernes'], 'Calorias': [420, 380, 390, 490, 300], 'Tiempo': [60, 40, 75, 55, 45]})

df['Reto Cumplido'] = ( (df['Calorias'] / df['Tiempo']) > (400/60) ) 
# & (df['Calorias'] > 400)
df
# Out:
#          Día  Calorias  Tiempo  Reto Cumplido
# 0      Lunes       420      60           True
# 1     Martes       380      40           True
# 2  Miercoles       390      75          False
# 3     Jueves       490      55           True
# 4    Viernes       300      45          False

# %% [markdown]
# #### Explicación:
# - Establecí el marco de datos de nuevo.
# - Declaré una nueva columna con una condicional para que agregara un valor booleano dependiendo de si las calorías por hora eran mas de cuatrocientas.
# - No sabía si agregar la condición de que fueran más de 400 calorías por día así que la dejé oculta.

# %% [markdown]
# ### Inciso D
# Filtrar el DataFrame y devolver otro DataFrame con las filas pares que cumplan que el número de calorías es mayor de 400.

# %%
filaspares = df.index % 2 == 0
dfiltrado = df.loc[filaspares & (df['Calorias'] > 400)]

dfiltrado
# Out:
#      Día  Calorias  Tiempo  Reto Cumplido
# 0  Lunes       420      60           True

# %% [markdown]
# #### Explicación:
# - Creé una máscara de números pares para el índice.
# - En nuevo marco de datos incluí la mascara aplicada y la condición de "mayor a 400" a los valores de la columna 'Calorías'.

# %% [markdown]
# ### Inciso E
# Añadir otra columna con los porcentajes de días que se ha conseguido el reto y los que no.

# %%
df['% Calorias Reto'] = (df['Calorias'] / 400) * 100

df

# %% [markdown]
# #### Explicación:
# - Declaré una nueva columna incluyendo las calorías respectivas divididas entre cuatrocientos y multiplicadas por cien para obtener el procentaje que se cumplió del reto.

# %% [markdown]
# ### Inciso F
# Crear un gráfico donde se  muestre la progresión de las calorías y tiempo durante la semana.

# %%
plt.scatter(df['Calorias'], df['Tiempo'])
plt.title('Calorias vs Tiempo')
plt.xlabel('Calorias')
plt.ylabel('Tiempo')

for i, row in df.iterrows():
    plt.text(row['Calorias'], row['Tiempo'], row['Día'])

plt.show()

# %% [markdown]
# #### Explicación:
# - Elegí el scatter plot ya que me pareció ideal establecer calorias y tiempo como ejes.
# - Agregué los labels
# - Busque como poder etiquetar cada uno de los datos con el valor que lo identifica.

# %% [markdown]
# ## Ejercicio 5
# El fichero coches.csv contiene información sobre los modelos de coches vendidos en USA durante un determinado año. Se pide:

# %% [markdown]
# ### Inciso A
# Crear un DataFrame a partir del fichero anterior.

# %%
import pandas as pd
file = 'coches.csv'
df = pd.read_csv(file, sep=';')
df
# Out:
#      Marca                   Modelo   Tipo  Potencia   Precio
# 0    Acura                      MDX    SUV     265.0  33337.0
# 1    Acura           RSX Type S 2dr  Sedan     200.0  21761.0
# 2    Acura                  TSX 4dr  Sedan     200.0  24647.0
# 3    Acura                   TL 4dr  Sedan     270.0  30299.0
# 4    Acura               3.5 RL 4dr  Sedan     225.0  39014.0
# ..     ...                      ...    ...       ...      ...
# 423  Volvo  C70 LPT convertible 2dr  Sedan     197.0  38203.0
# 424  Volvo  C70 HPT convertible 2dr  Sedan     242.0  40083.0
# 425  Volvo               S80 T6 4dr  Sedan     268.0  42573.0
# 426  Volvo                      V40  Wagon     170.0  24641.0
# 427  Volvo                     XC70  Wagon     208.0  33112.0
#
# [428 rows x 5 columns]

# %% [markdown]
# #### Explicación:
# - Importé pandas.
# - Asigné a una variable la lectura del archivo para crear el marco de datos.
# - Llamé al marco de datos para visualizarlo.

# %% [markdown]
# ### Inciso B
# Eliminar las filas con valores desconocidos y mostrar el número de filas del DataFrame resultante.

# %%
dfdrop = df.dropna()
dfdrop
# Out:
#      Marca                   Modelo   Tipo  Potencia   Precio
# 0    Acura                      MDX    SUV     265.0  33337.0
# 1    Acura           RSX Type S 2dr  Sedan     200.0  21761.0
# 2    Acura                  TSX 4dr  Sedan     200.0  24647.0
# 3    Acura                   TL 4dr  Sedan     270.0  30299.0
# 4    Acura               3.5 RL 4dr  Sedan     225.0  39014.0
# ..     ...                      ...    ...       ...      ...
# 423  Volvo  C70 LPT convertible 2dr  Sedan     197.0  38203.0
# 424  Volvo  C70 HPT convertible 2dr  Sedan     242.0  40083.0
# 425  Volvo               S80 T6 4dr  Sedan     268.0  42573.0
# 426  Volvo                      V40  Wagon     170.0  24641.0
# 427  Volvo                     XC70  Wagon     208.0  33112.0
#
# [421 rows x 5 columns]

# %% [markdown]
# #### Explicación:
# - Declaré un nuevo marco de datos aplicándole la función "dropna()" al marco original.
# - Utilicé otra variable para poder utilizar el marco original en caso de ser necesario.

# %% [markdown]
# ### Inciso C
# Crear una columna con el precio en euros (cambio 1$ = 0.94€)

# %%
dfdrop.loc[:, 'Euros'] = dfdrop['Precio'] * 0.94
dfdrop
# Out:
#      Marca                   Modelo   Tipo  Potencia   Precio     Euros
# 0    Acura                      MDX    SUV     265.0  33337.0  31336.78
# 1    Acura           RSX Type S 2dr  Sedan     200.0  21761.0  20455.34
# 2    Acura                  TSX 4dr  Sedan     200.0  24647.0  23168.18
# 3    Acura                   TL 4dr  Sedan     270.0  30299.0  28481.06
# 4    Acura               3.5 RL 4dr  Sedan     225.0  39014.0  36673.16
# ..     ...                      ...    ...       ...      ...       ...
# 423  Volvo  C70 LPT convertible 2dr  Sedan     197.0  38203.0  35910.82
# 424  Volvo  C70 HPT convertible 2dr  Sedan     242.0  40083.0  37678.02
# 425  Volvo               S80 T6 4dr  Sedan     268.0  42573.0  40018.62
# 426  Volvo                      V40  Wagon     170.0  24641.0  23162.54
# 427  Volvo                     XC70  Wagon     208.0  33112.0  31125.28
#
# [421 rows x 6 columns]

# %% [markdown]
# #### Explicación:
# - Intenté crear la columna declarando "dfdrop['Euros']" pero me marcó error sugieriendo que utilizará el "loc".
# - Lo apliqué y funcionó como esperado.

# %% [markdown]
# ### Inciso D
# Mostrar las 10 últimas filas del DataFrame.

# %%
dfdrop.tail(10)
# Out:
#      Marca                   Modelo   Tipo  Potencia   Precio     Euros
# 418  Volvo              S60 2.5 4dr  Sedan     208.0  29916.0  28121.04
# 419  Volvo               S60 T5 4dr  Sedan     247.0  32902.0  30927.88
# 420  Volvo                S60 R 4dr  Sedan     300.0  35382.0  33259.08
# 421  Volvo              S80 2.9 4dr  Sedan     208.0  35542.0  33409.48
# 422  Volvo             S80 2.5T 4dr  Sedan     194.0  35688.0  33546.72
# 423  Volvo  C70 LPT convertible 2dr  Sedan     197.0  38203.0  35910.82
# 424  Volvo  C70 HPT convertible 2dr  Sedan     242.0  40083.0  37678.02
# 425  Volvo               S80 T6 4dr  Sedan     268.0  42573.0  40018.62
# 426  Volvo                      V40  Wagon     170.0  24641.0  23162.54
# 427  Volvo                     XC70  Wagon     208.0  33112.0  31125.28

# %% [markdown]
# #### Explicación:
# - Le apliqué la función "tail()" al marco de datos incluyendo el 10 como argumento.

# %% [markdown]
# ### Inciso E
# Mostrar el número de marcas de coches que contiene el DataFrame.

# %%
# nummaralf = dfdrop.groupby('Marca')['Marca'].count()
# nummardes = dfdrop['Marca'].value_counts()
nummar = dfdrop['Marca'].nunique()
nummar
# Out:
# 38

# %% [markdown]
# #### Explicación:
# - Primero pensé que era el número de carros por marca.
# - Luego rectifiqué y busqué el número de marcas. Dejé ambas.

# %% [markdown]
# ### Inciso F
# Mostrar el número de modelos de cada marca que hay en el DataFrame, de mayor a menor frecuencia.

# %%
modelosxmarca = dfdrop.groupby('Marca')['Modelo'].nunique().sort_values(ascending=False).reset_index(name='Número de Modelos')
#modelosxmarca = dfdrop.groupby('Marca')['Tipo'].nunique().sort_values(ascending=False).reset_index(name='Tipo por Marca')

modelosxmarca
# Out:
#             Marca  Número de Modelos
# 0          Toyota                 28
# 1       Chevrolet                 27
# 2   Mercedes-Benz                 24
# 3            Ford                 23
# 4             BMW                 19
# 5            Audi                 19
# 6          Nissan                 17
# 7           Honda                 16
# 8      Volkswagen                 15
# 9        Chrysler                 14
# 10          Dodge                 13
# 11     Mitsubishi                 13
# 12          Volvo                 12
# 13        Hyundai                 12
# 14         Jaguar                 12
# 15            Kia                 11
# 16          Mazda                 11
# 17        Pontiac                 10
# 18         Subaru                 10
# 19          Lexus                 10
# 20        Lincoln                  9
# 21          Buick                  9
# 22        Mercury                  9
# 23       Cadillac                  8
# ...

# %% [markdown]
# #### Explicación:
# - Estuve mucho tiempo confundido entre modelo y tipo.
# - Estaba pensando en que deberían ser muchos menos carros por cada marca ya que los tipos eran pocos. Pero estaba contando por modelo.
# - Me pareció extraño ya en el vistazo que di no vi ningún modelo repetido pero el tipo sí se repetía así que deje el tipo también listo.

# %% [markdown]
# ### Inciso G
# Mostrar cuál es la marca y el modelo del coche más caro

# %%
mascaro = dfdrop.loc[df['Precio'] == df['Precio'].max(), ['Marca', 'Modelo']]
mascaro
# Out:
#        Marca       Modelo
# 334  Porsche  911 GT2 2dr

# %% [markdown]
# #### Explicación:
# - Con la función loc puse la condición de mostrar las filas cuyo valor precio fuera igual al maximo. En el segundo argumento seleccione que columnas mostrar las filas que cumplieran la condición.

# %% [markdown]
# ### Inciso H
# Mostrar el precio medio en euros de los coches agrupando por marca y ordenando de menor a mayor precio

# %%
euromed = dfdrop.groupby('Marca')['Euros'].mean().sort_values().reset_index()
euromed
# Out:
#             Marca         Euros
# 0           Scion  12135.400000
# 1             Kia  13996.941818
# 2          Suzuki  14937.775000
# 3         Hyundai  15073.213333
# 4          Saturn  15103.920000
# 5            MINI  15779.780000
# 6           Honda  18773.092500
# 7           Mazda  18980.907273
# 8          Toyota  19078.172857
# 9            Jeep  19856.560000
# 10     Oldsmobile  20444.060000
# 11     Mitsubishi  20524.683077
# 12           Ford  20635.820000
# 13        Pontiac  20878.528000
# 14         Subaru  21351.442000
# 15         Nissan  21617.622353
# 16      Chevrolet  22617.165926
# 17          Dodge  22710.472308
# 18          Isuzu  23141.860000
# 19       Chrysler  23778.105714
# 20        Mercury  24118.102222
# 21            GMC  24712.012500
# 22          Buick  26183.595556
# 23     Volkswagen  27901.706667
# 24       Infiniti  30907.200000
# 25          Volvo  32163.196667
# 26           Saab  33483.068571
# 27          Acura  36275.405714
# ...

# %% [markdown]
# #### Explicación:
# - Agrupe por marca y a la columna "Euros" le aplique "mean()", después apliqué "sort_values()" con ascending en default.
# - Usé "reset_index()" para que se imprimiera con el formato estilizado.

# %% [markdown]
# ### Inciso I
# Gráfica el diagrama de barras del porcentaje de modelos de cada marca.

# %%
import pandas as pd
import matplotlib.pyplot as plt

conteo_marca = dfdrop.groupby('Marca')['Modelo'].value_counts()

porcentajexmarca = conteo_marca.groupby(level=0).apply(lambda x: x / float(x.sum())*100)

ax = porcentajexmarca.unstack().plot(kind='bar', stacked=True)

ax.legend().remove()

ax.set_xlabel('Marca')
ax.set_ylabel('Porcentaje')
ax.set_title('Porcentaje de modelos por marca')

plt.show()

# %% [markdown]
# #### Explicación:
# -  Este ejercicio fue difícil.
# - Conteo los moodelos de cada marca.
# - Les saqué el porcentaje dividiéndolos por la suma de todos los modelos de la marca y multipliqué por cien.
# - Convertí de serie a marco de datos para graficar e hice un gráfica de barras apiladas.
# - Quité la leyenda de los modelos puesto que era excesivamente grande.
# - Aún me preguntó si la instrucción debía decir "tipo "en vez de "modelo" ya que los tipos caben facilmente y hay grupos variados por marca cuando los modelos son 1 de cada uno por marca.

# %% [markdown]
# ### Inciso J
# Gráfica el diagrama de dispersión de la potencia y el precio.

# %%
plt.scatter(dfdrop['Potencia'], dfdrop['Precio'])

plt.xlabel('Potencia')
plt.ylabel('Precio')
plt.title('Potencia y Precio')

plt.show()

# %% [markdown]
# #### Explicación:
# - Este gráfico fue más fácil.
# - Apliqué scatter() tomando como ejes "Precio" y "Potencia".
# - Definí las etiquetas y el título.
