# %% [markdown]
# TAREA SEMANA 1 : FUNDAMENTOS DE PYTHON

# %% [markdown]
# Nombre : Ortiz Mira Pedro Fernando

# %% [markdown]
# Ejercicio 1

# %% [markdown]
# 1.-Crea un programa que tome un número ingresado por el usuario y determine si es par o impar

# %%
print("type a number to check if its odd or even")
number = input()
if int(number) % 2 == 0:
  print('the number is even')
else:
  print('the number is odd')
# Out:
# type a number to check if its odd or even
# 8
# the number is even

# %% [markdown]
# Explicacion:
# the firts error i got was "not all arguments converted during string formatting" which meant my number variable was a string so i just added the int(var) function to convert it and then my program worked.

# %% [markdown]
# Ejercicio 2

# %% [markdown]
# 2.-Escribe un programa que convierta una cadena de texto en mayúsculas.

# %%
print("type the string to convert into uppercase")
str = input()
print(str.upper())
# Out:
# type the string to convert into uppercase
# hello world
# HELLO WORLD

# %% [markdown]
# Explicacion:
# este estuvo facil, solo busque que metodo de python convertia una string a uppercase y pues lo aplique a la string guardada en mi variable

# %% [markdown]
# Ejercicio 3

# %% [markdown]
# 3.-Crea un programa que lea una cadena de texto ingresada por el usuario y que cuente cuántas veces aparece una letra específica en ella.

# %%
print("write the string:")
str = input()
print("which value you want to know the number of times appears in the string?")
val = input()
print(str.count(val))
# Out:
# write the string:
# hello world
# which value you want to know the number of times appears in the string?
# l
# 3

# %% [markdown]
# Explicacion:
# aqui tampoco tuve mayor problema, solo fue cuestion de bustar en los string functions cual contaba un caracter que se encontrara en la string e imprimirlo, igual tuve que hacerlo dinamico para que tanto la string como el caracter a contar fueran dados por el usuario.

# %% [markdown]
# Ejercicio 4

# %% [markdown]
# 4.-Escribe un programa que determine si un número es primo o no.

# %%
number = input("type the number to check if its prime or not: ")
number = int(number)
if number > 1:
	
	for n in range(2, int(number/2)+1):
		
		if (number % n) == 0:
			print(number, "is not a prime number")
			break
	else:
		print(number, "is a prime number")
else:
	print(number, "is not a prime number")
# Out:
# type the number to check if its prime or not: 9
# 9 is not a prime number

# %% [markdown]
# Explicacion:
# lo primero fue definirme que un numero primo es aque que solo puede dividirse entre 1 y entre si mismo, el problema fue cuando llegue al 9 que no es primo pero pero podria entrar en la regla ya que si se divide entre 2 no sale 0 de residuo pero entre 3 si, y eso rompe la regla de los numero primos y no iba a poner una infinidad de tests para ver que se cumpliera la regla asi que tuve que buscar la forma de commprobar que todos mis tests fueran probados de la forma correcta, despues de un tiempo de pensar me di cuenta que este tipo de teoremas habian sido postulados por matematicos con maestria en el area y que yo de solo pensarlo no iba a llegar a la solucion asi que busque teoremas y encontre el Miller-Rabin test y me costo trabajo pero pude pasar sus calculos a python y pues al parecer funciono bien, ah y tambien me di cuenta que en el input puedo poner la string para pedirle datos al usuario en vez de primero hacer un print y luego el input asi me ahorro una linea de codigo

# %% [markdown]
# Ejercicio 5

# %% [markdown]
# 5.-Crea un programa que calcule el área de un triángulo a partir de la base y la altura ingresadas por el usuario.

# %%
base = input("ingresa la base del triangulo: ")
base = int(base)
altura = input("ingresa la altura del triangulo: ")
altura = int(altura)
area = (base * altura) / 2
print(area)
# Out:
# ingresa la base del triangulo: 8
# ingresa la altura del triangulo: 3
# 12.0

# %% [markdown]
# Explicacion:
# este estuvo muy sencillo base por altura sobre 2 y listo, sin mucho problema.

# %% [markdown]
# Ejercicio 6

# %% [markdown]
# 6.-Escribe un programa que tome una lista de números y devuelva la suma de todos ellos.

# %%
list_num = [1,2,3,4,5,6]
res = 0

for n in list_num:
  res = res + n

print(res)
# Out:
# 21

# %% [markdown]
# Explicacion:
# este ejercicio ya lo habia hecho antes cuando aprendi a programar asi que fue bastante sencillo, solo sumamos cada value dentro de cada indice de nuestra lista y presto!, ademas no pidio que el user metiera los numeros de la lista asi que eso hizo que fuera mucho mas sencillo, si no habria tenido que loopear el input hasta que el user quisiera y luego ya iterar sobre esa lista.

# %% [markdown]
# Ejercicio 7

# %% [markdown]
# 7.-Crea un programa que reciba una lista de nombres y que imprima solo aquellos que comiencen con una letra específica dada por el usuario.

# %%
add =  True
name_list = []
while add == True:
  name = input("type a name: ")
  name_list.append(name)
  answer = input("want to add another name? write yes or no")
  if answer == "no":
    add = False
  elif answer != "yes":
    print("invalid answer type yes or no")

print (name_list)
letter = input("which letter you want to check to print the list: ")

for i in name_list:
  if not i.find(letter):
    print (i)

# %% [markdown]
# Explicacion
# estuvo laborioso pero la logica fue facil, solo tuve que buscar la forma de hacer que el usuario metiera nombres hasta que quisiera y una vez con eso ya ver la forma de checar que hubiera coincidencia entre el caracter ingresado por el usuario y cada uno de los values dentro de los indices de la lista, pense que con find solo me iba a retornar la posicion de la coincidencia pero creo que resolvi bien el como imprimir el value dentro del index y no solo la posicion

# %% [markdown]
# Ejercicio 8

# %% [markdown]
# 8.-Escribe un programa que determine si una cadena de texto es un palíndromo o no

# %%
str = input("write a string to check if its a palindrome or not:")
#'Was it a car or a cat I saw'

str = str.lower().replace(' ', '')
rev_str = ''.join(reversed(str))
if str == rev_str:
  print("the string was a palindrome")
else:
  print("the string was not a palindrome")
# Out:
# write a string to check if its a palindrome or not:Was it a car or a cat I saws
# the string was not a palindrome

# %% [markdown]
# Explicacion:
#
# primero cheque bien el concepto de palindromo y quiere decir que es una oracion o palabra que dice exactamente lo mismo leida de izquierda a derecha o de derecha a izquierda, entonces primero tome la string y la hice lower por si el user pone mayusculas, despues quite todos los espacios para tener una string grande en caso de que ponga una oracion en vez de una palabra, despues use el metodo reverse para voltear la string y por ultimo compare que la string original sin espacios y lowercased fuera exactamente igual a la string reversed.

# %% [markdown]
# Ejercicio 9

# %% [markdown]
# 9.-Crea un programa que tome una lista de números y elimine todos los duplicados.

# %%
listt = [1,1,2,1,3,4,1,2,3,4]
dup_listt = list()

for n in listt:
    if n not in dup_listt:
        dup_listt.append(n)

print(dup_listt)
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# Explicacion
# simplemente busque la forma de iterar en todos los elementos de la lista, cree una lista vacia para ahi meter los numeros que no se repitieran, entonces mi programa dice itera en todos los indices de mi lista, luego checa si el valor del iterador esta en mi lista vacia, si no esta entonces lo metemos, por ejemplo la primer vuelta checo el indice 0 que tiene el uno, no esta en la lista vacia?, no, entonces lo metemos, para la segunda vuelta en el indice 1 el value es otro 1 y checa si esta en mi lista dup_list pero ya hay un 1 ahi entonces no lo mete y sigue con el siguiente value.

# %% [markdown]
# Eejercicio 10

# %% [markdown]
# 10.-Escribe un programa que tome una lista de números y devuelva el valor máximo.

# %%
nums = [1,3,5,6,8,2,4,9]

max = 0

for num in nums:
    if (num > max):
        max = num

print('max value:', max)
# Out:
# Maximum value: 9

# %% [markdown]
# Explicacion
# aqui solo fue cuestion de iterar sobre la lista e ir viendo que el current value fuera mas grande que el value storeado en mi variable max y asi iba guardando en max el valor mas grande y lo comparaba con el siguiente en la lista hasta terminar de recorrer toda la lista

# %% [markdown]
# Ejercicio 11

# %% [markdown]
# 11.-Crea un programa que solicite al usuario su edad y que determine en que etapa de la vida se encuentra:
# Primera Infancia (0-5 años)
# Infancia (6 - 11 años)
# Adolescencia (12 - 18 años)
# Juventud (14 - 26 años)
# Adultez (27- 59 años)
# Persona Mayor (60 años o más).

# %%
age = input("ingresa tu edad: ")
age = int(age)

if (age <= 5):
  print('primera infancia')
elif (age > 5 and age <= 11):
  print("infancia")
elif (age > 11 and age <= 13):
  print("adolecencia")
elif (age >= 14 and age <= 18):
  print("adolecencia y juventud")
elif (age > 18 and age <= 26):
  print("juventud")
elif(age > 26 and age <= 59):
  print("adultez")
elif(age >= 60):
  print("persona mayor")
# Out:
# ingresa tu edad: 19
# juventud

# %% [markdown]
# Explicacion:
# estuvo un tanto engañoso la parte de adolecencia y juventud pero solo era cuestion de aislar a que edad poner que etapa de la vida se encuentra el user, fuera de eso ps eran puros comparadores de mayor que y menor que.

# %% [markdown]
# Ejercicio 12

# %% [markdown]
# 12.-Escribe un programa que tome una cadena de texto y que la divida en palabras, eliminando los espacios en blanco.

# %%
strg = "Escribe un programa que tome una cadena de texto"

new_str = strg.replace(" ", ",")

print(new_str)

# %% [markdown]
# Explicacion:
#
# La verdad no entendi muy bien como funcionaria este programa pero por lo que entendi dice que tomemos una string, que la dividamos en palabras y que eliminemos los espacios en blanco asi que se me ocurrio usar la funcion replace y quite los espacios en blanco y puse comas por que no se me ocurre de que otra forma dividir en palabras una string

# %% [markdown]
# Ejercicio 13

# %% [markdown]
# 13.-Crea un programa que tome dos listas de números y que devuelva una tercera lista con los elementos comunes a ambas.

# %%
list1 = [1, 3, 4, 55,90]
list2 = [90, 22,3,1]
list3 = [] 

for num in list1:
    if num in list2:
        list3.append(num)
 
print(list3)
# Out:
# [1, 3, 90]

# %% [markdown]
# Explicacion:
# al iterar en toda mi primer lista voy checando si el value del current index esta en la segunda lista con la keyword "in" si esta lo meto a mi tercer array y si no pues no, y al final ya sale el tercer array con los elementos donde hubo match

# %% [markdown]
# Ejercicio 14

# %% [markdown]
# 14.-Escribe un programa que tome una cadena de texto y que cuente cuántas palabras hay en ella.

# %%
string = "Escribe un programa que tome una cadena de texto y que cuente cuántas palabras hay en ella."
string = "HOLA"
count = 1

for i in string:
  if i==" ":
      count+=1

print(count)
# Out:
# 1

# %% [markdown]
# Explicacion
#
# como saber que hay palabras en una string?, con los " " asi sabemos que una palabra termino y otra va a empezar, entonces contamos cuantos espacios en blanco hay y le añadimos uno por que al inicio minimo habra una palabra, y ya nadamas le sumamos el resto de espacios en blanco.

# %% [markdown]
# Ejercicio 15

# %% [markdown]
# 15.-Crea un programa que calcule el área de un círculo a partir del radio ingresado por el usuario.

# %%
radio = input("enter the radieishon: ")
radio = int(radio)

pi = 3.1416

area = pi * (radio * radio)

print(area)
# Out:
# enter the radieishon: 3
# 28.2744

# %% [markdown]
# Explicacion
# pi por radio al cuadraro, simplemente pasar eso a codigo muy facil.

# %% [markdown]
# Ejercicio 16

# %% [markdown]
# 16.-Escribe un programa que tome una lista de números y que devuelva la media aritmética.

# %%
nums = [1, 3, 4, 55,90]
nums_len = len(nums)
sum = 0

for num in nums:
  sum += num

media = sum / nums_len

print(media)
# Out:
# 30.6

# %% [markdown]
# Explicacion:
# para sacar el promedio hay que sumar todos los numeros de una lista y luego dividir ese valor entre el total de numeros que se sumaron solo pase eso a codigo, para saber cuantos numeros tiene la lista use la funcion len que cuenta el length de la lista y con un for itere entre todos los numeros de mi lista y los fui sumando a mi variable sum y sha.

# %% [markdown]
# Ejercicio 17

# %% [markdown]
# 17.-Crea un programa que reciba dos números ingresados por el usuario y que devuelva su producto

# %%
num1 = input("escribe un numereishon: ")
num1 = int(num1)

num2 = input("escribe otro numereishon: ")
num2 = int(num2)

prod = num1 * num2

print("El producteishon es:",prod)
# Out:
# escribe un numereishon: 5
# escribe otro numereishon: 5
# El producteishon es: 25

# %% [markdown]
# Explicacion:
#
# la verdad tuve que buscar que es producto xD por que tenia mucho que no uso ese termino, pero ps era una simple multiplicacion y sha.

# %% [markdown]
# Ejercicio 18

# %% [markdown]
# 18.-Escribe un programa que tome una lista de palabras y que devuelva una lista con todas las palabras en mayúsculas.

# %%
palabras = ["palabra1", "palabra2", "palabra3", "palabra4", "palabra5"]
palabrasupp = []
for palabra in palabras:
  palabrasupp.append(palabra.upper())

print(palabrasupp)
# Out:
# ['PALABRA1', 'PALABRA2', 'PALABRA3', 'PALABRA4', 'PALABRA5']

# %% [markdown]
# Explicacion
#
# solo tome la lista de palabras y use el metodo upper para hacer que toda la palabra fuera mayuscula e itere en la lista con un forsito :3 .

# %% [markdown]
# Ejercicio 19

# %% [markdown]
# 19.-Crea un programa que tome una lista de números y que devuelva la suma de aquellos que son mayores a un valor específico ingresado por el usuario.

# %%
num_list = [1, 3, 4, 5,5]

valor_específico_ingresado_por_el_usuario = input("ingresa el valor especifico:")
valor_específico_ingresado_por_el_usuario = int(valor_específico_ingresado_por_el_usuario)

sum = 0 

for num in num_list:
  if num > valor_específico_ingresado_por_el_usuario:
    sum += num

print(sum)
# Out:
# ingresa el valor especifico:4
# 10

# %% [markdown]
# Explicacion:
#
# pues aqui solo es cuestion de tomar el valor específico ingresado por el usuario y compararlo con cada numero de la lista y si es mayor lo sumamos a nuestra variable sum y si no pues no, y ya al final imprimimos la suma

# %% [markdown]
# Ejercicio 20

# %% [markdown]
# 20.-Escribe un programa que tome una cadena de texto y que devuelva una nueva cadena con todas las letras en mayúsculas excepto la primera letra de cada palabra, que debe ser en minúsculas.

# %%
string = "EXAMPLE"

first_lowercase = string[0].lower() + string[1:]

print(first_lowercase)
# Out:
# eXAMPLE

# %% [markdown]
# Explicacion
#
# este si estuvo complicado pense que habria un metodo inverso a capitalize pero no, asi que primero tomamos el primer indice de la string y ya solo le sumamos el resto de la string para concatenar todo.
