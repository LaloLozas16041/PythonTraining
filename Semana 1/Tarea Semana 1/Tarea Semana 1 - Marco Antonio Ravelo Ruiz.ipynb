# %%
TAREA SEMANA 1 : FUNDAMENTOS DE PYTHON
Nombre : Marco Antonio Ravelo Ruiz

# %%
EJERCICIO 1
1. Crea un programa que tome un número ingresado por el usuario y determine si es par o impar.

# %%
pregunta = int(input("Ingresa un numero"))
if pregunta % 2 == 0:
    print("Es numero par")
else:
    print("Es numero impar")
# Out:
# Ingresa un numero3
# Es numero impar

# %%
# Explicación dificultad en ejercicio 1: Pues se me dificulto en el momento de saber cuando poner
# el tipo de dato antes del input y como funcionaba el operador %

# %%
EJERCICIO 2
2. Escribe un programa que convierta una cadena de texto en mayúsculas.

# %%
texto = "el arbol es gigante"
mayusculas = texto.upper()
print(mayusculas)
# Out:
# EL ARBOL ES GIGANTE

# %%
# Explicación dificultad en ejercicio 2: En este ejercicio no tuve dificultad

# %%
EJERCICIO 3
3. Crea un programa que lea una cadena de texto ingresada por el usuario
y que cuente cuántas veces aparece una letra específica en ella.

# %%
cadena_texto = str(input("Ingresa una cadena de texto"))
miLetra = "r"
x = 0
for letra in cadena_texto:
    if letra == miLetra:
        x += 1
print("La Letra" + miLetra + "se repite" + str(x) + " veces")
# Out:
# Ingresa una cadena de textoferrocarril
# La Letrarse repite4 veces

# %%
# Explicación dificultad en ejercicio 3: Se me dificulto hacer el bucle, e investigue
# que se puede hacer una especie de contador que en mi caso es x, y mas o menos asi lo hice

# %%
EJERCICIO 4
4. Escribe un programa que determine si un número es primo o no.

# %%
y = int(input("Ingresa un numero"))
a = 1
b = 0
while a <= y:
    if y%a == 0:
        b = b + 1
    a = a + 1
if b == 2:
    print("El numero",y,"es primo")
else:
    print("El numero",y,"no es primo")
# Out:
# Ingresa un numero11
# El numero 11 es primo

# %%
# Explicación dificultad en ejercicio 4:Se me dificulto el bucle while al hacerlo funcionar

# %%
EJERCICIO 5
5. Crea un programa que calcule el área de un triángulo a partir de la base
y la altura ingresadas por el usuario

# %%
base = int(input("Ingresa la cantidad de la base del triangulo"))
altura = int(input("Ingresa la cantidad de la altura del triangulo"))
area_triangulo = (base * altura)/2
print (area_triangulo)
# Out:
# Ingresa la cantidad de la base del triangulo8
# Ingresa la cantidad de la altura del triangulo4
# 16.0

# %%
# Explicación dificultad en ejercicio 5: En este ejercicio no tuve dificultad

# %%
EJERCICIO 6
6.Escribe un programa que tome una lista de números y devuelva la suma de todos ellos

# %%
lista = [1, 2, 3, 4, 5]
suma_lista = sum (lista)
print(suma_lista)
# Out:
# 15

# %%
# Explicación dificultad en ejercicio 6: En este ejercicio no tuve dificultad

# %%
EJERCICIO 7
7. Crea un programa que reciba una lista de nombres y que imprima solo aquellos
que comiencen con una letra específica dada por el usuario.

# %%
nombres = ["Ana", "Alma", "Pedro", "Susana", "Antonio", "Paloma"]
letra_espec = str(input("Ingresa una letra inicial del nombre"))
if letra_espec == "A":
    print("Ana", "Alma", "Antonio")
elif letra_espec == "P":
    print("Pedro")
elif letra_espec == "S":
    print ("Susana")
else:
    print("No existen nombres que coincidan con dicha letra inicial")
# Out:
# Ingresa una letra inicial del nombreA
# Ana Alma Antonio

# %%
# Explicación dificultad en ejercicio 7: En este ejercicio no tuve dificultad

# %%
EJERCICIO 8
8. Escribe un programa que determine si una cadena de texto es un palíndromo o no.

# %%
palabra = input()
if str(palabra) == str(palabra)[::-1] :
    print("Es palindromo")
else:
    print("No es palindromo")
# Out:
# reconocer
# Es palindromo

# %%
# Explicación dificultad en ejercicio 8: Se me dificulto entender la sintaxis [::]

# %%
EJERCICIO 9
9. Crea un programa que tome una lista de números y elimine todos los duplicados.

# %%
numeros = [1, 2, 2, 3, 4, 8, 95, 95, 8]
num_unicos = []
for num in numeros:
    if num not in num_unicos:
        num_unicos.append(num)
print(num_unicos)
# Out:
# [1, 2, 3, 4, 8, 95]

# %%
# Explicación dificultad en ejercicio 9: Al ocupar el .append debajo de la condicion no entendia como funciona,
# y como ocupar cajas vacias

# %%
EJERCICIO 10

# %%
10. Escribe un programa que tome una lista de números y devuelva el valor máximo.

# %%
numeros = [8, 10, 25, 89, 64, 100]
valor_maximo = None
for num in numeros:
    if(valor_maximo is None or num > valor_maximo):
        valor_maximo = num

print("El maximo valor es:", valor_maximo)
# Out:
# El maximo valor es: 100

# %%
# Explicación dificultad en ejercicio 10: Se me dificulta al usar las cajas vacias

# %%
EJERCICIO 11
11. Crea un programa que solicite al usuario su edad y que determine en que etapa de la vida se encuentra:
Primera Infancia (0-5 años)
Infancia (6 - 11 años)
Adolescencia (12 - 18 años)
Juventud (19 - 26 años)
Adultez (27- 59 años)
Persona Mayor (60 años o más).

# %%
edad = int(input("Ingrese su edad actual"))
if edad >= 0 and edad <= 5:
    print("Usted esta en la etapa de la vida de la Primera Infancia")
if edad >= 6 and edad <= 11:
    print("Usted esta en la etapa de la vida de la Infancia")
if edad >= 12 and edad <= 18:
    print("Usted esta en la etapa de la vida de la Primera Adolescencia")
if edad >= 19 and edad <= 26:
    print("Usted esta en la etapa de la vida de la Juventud")
if edad >= 27 and edad <= 59:
    print("Usted esta en la etapa de la vida de la Adultez")
if edad >= 60 and edad <= 200:
    print("Usted esta en la etapa de la vida de la Persona Mayor")
else:
    print("Ok")
# Out:
# Ingrese su edad actual26
# Usted esta en la etapa de la vida de la Juventud
# OK

# %%
# Explicación dificultad en ejercicio 11: En este ejercicio no tuve dificultad

# %%
EJERCICIO 12
12. Escribe un programa que tome una cadena de texto y que la divida en palabras,
eliminando los espacios en blanco.

# %%
cadena = ("   el arbol es gigante y con frutas jugosas  ")
sin_espacios = cadena.strip()
print(sin_espacios)
lista = cadena.split(" ")
print(cadena)
# Out:
# el arbol es gigante y con frutas jugosas
#    el arbol es gigante y con frutas jugosas

# %%
# Explicación dificultad en ejercicio 12: En este ejercicio no se como juntar ambos metodos de caracteres a la vez

# %%
EJERCICIO 13
13.Crea un programa que tome dos listas de números y que devuelva una tercera lista con los elementos comunes a ambas.

# %%
grupo1 = {1, 2, 3, 8, 9, 7}
grupo2 = {1, 2, 5, 10, 29, 7}
interseccion = grupo1 & grupo2
print(interseccion)
# Out:
# {1, 2, 7}

# %%
# Explicación dificultad en ejercicio 13: En este ejercicio no tuve dificultad

# %%
EJERCICIO 14
14.Escribe un programa que tome una cadena de texto y que cuente cuántas palabras hay en ella.

# %%
"tres tristes tigres tragaban trigo en un trigal y en un trigal tragaban tres tristes tigres".count("tragaban")
# Out:
# 2

# %%
# Explicación dificultad en ejercicio 14: En este ejercicio no tuve dificultad

# %%
EJERCICIO 15
15. Crea un programa que calcule el área de un círculo a partir del radio ingresado por el usuario.

# %%
r = int(input("Ingrese el radio del circulo"))
area_circulo =  3.14159 * (r**2)
print(area_circulo)
# Out:
# Ingrese el radio del circulo25
# 1963.49540625

# %%
# Explicación dificultad en ejercicio 15: En este ejercicio no tuve dificultad

# %%
EJERCICIO 16
16.Escribe un programa que tome una lista de números y que devuelva la media aritmética.

# %%
lista = [1, 2, 3, 6, 8, 10, 12]
n = len(lista)
media = sum (lista)/n
print(media)
# Out:
# 6.0

# %%
# Explicación dificultad en ejercicio 16: En este ejercicio no sabia sobre la funcion len, porque no venia
# en lo de la semana 1, investigue aparte

# %%
EJERCICIO 17
17.Crea un programa que reciba dos números ingresados por el usuario y que devuelva su producto.

# %%
numero1 = int(input("Ingresa el primer numero"))
numero2 = int(input("Ingresa el segundo numero"))
producto = numero1 * numero2
print(producto)
# Out:
# Ingresa el primer numero2
# Ingresa el segundo numero4
# 8

# %%
# Explicación dificultad en ejercicio 17: En este ejercicio no tuve dificultad

# %%
EJERCICIO 18
18.Escribe un programa que tome una lista de palabras y que devuelva una lista con todas las palabras en mayúsculas.

# %%
lista = ["arbol", "cacahuate", "verano", "manzana", "galaxia"]
for i in range(len(lista)):
    lista[i] = lista[i].upper()
print(lista)
# Out:
# ['ARBOL', 'CACAHUATE', 'VERANO', 'MANZANA', 'GALAXIA']

# %%
# Explicación dificultad en ejercicio 18: Se me dificulto entender la iteracion del bucle

# %%
EJERCICIO 19
19. Crea un programa que tome una lista de números y que devuelva la suma de aquellos
que son mayores a un valor específico ingresado por el usuario.

# %%
lista = [2, 4, 5, 6]
info = int(input("Ingresa un valor"))
if info == 2:
    print(4+5+6)
if info == 4:
    print(5+6)
else:
    print("OK")
# Out:
# Ingresa un valor4
# 11

# %%
# Explicación dificultad en ejercicio 19: A veces usar los bucles se me dificultan

# %%
EJERCICIO 20
20.Escribe un programa que tome una cadena de texto y que devuelva una nueva cadena con todas las letras en mayúsculas
excepto la primera letra de cada palabra, que debe ser en minúsculas

# %%
result = ("el arbol ES GrAnde ")


for p in result.split():
    result += p[0].lower() + p[1:5].upper() + ' '


print(result)
# Out:
# el arbol ES GrAnde eL aRBOL eS gRAND

# %%
# Explicación dificultad en ejercicio 20: Se me dificulta como separar la nueva cadena
