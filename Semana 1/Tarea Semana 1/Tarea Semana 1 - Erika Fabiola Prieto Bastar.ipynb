# %% [markdown]
# # TAREA SEMANA 1 : FUNDAMENTOS DE PYTHON
# ## Nombre : Erika Fabiola Prieto Bastar

# %% [markdown]
# ## Ejercicio 1

# %%
numero = int(input("Ingresa un número: "))
if numero % 2 == 0:
    print("El número es par")
else:
    print("El número es impar")
# Out:
# Ingresa un número: 6
# El número es par

# %% [markdown]
# #### La verdad es que programar siempre me ha dado un poco de miedo y me cuesta trabajo, pero es algo ue siempre he querido hacer, llegar a este resultado admito que me costo casi una hora, ademas que tenia 3 años que no programaba.

# %% [markdown]
# # Ejercicio 2

# %%
palabra ='hola como estas'
palabramayus = palabra.upper()
print (palabramayus)
# Out:
# HOLA COMO ESTAS

# %% [markdown]
# #### Estoy confundida porque recuerdo ue esta fucion no la vimos en clase pero fue una de las formas que encontre para convertir en mayuscula la acedna de texto, no se si es correcto esto.

# %% [markdown]
# # Ejercicio 3

# %%
cadenatexto = "Anita lava la tina"
ocurrencias = cadenatexto.count("a")
print(ocurrencias)
# Out:
# 5

# %% [markdown]
# #### Mi dislexia y el comemerme las letras se han hecho presente en toda las pruebas y se seguiran haciendo presentes.

# %%
numero= int(input("Ingresa un numero "))
valor= range(2,numero)
contador = 0
for n in valor:
  if numero % n == 0:
    contador +=1
    print("divisor:", n)
 
if contador > 0 :
  print("El número no es primo" )
else:
  print("El nÚmero es primo")
# Out:
# Ingresa un numero 7
# El nÚmero es primo

# %% [markdown]
# #### Espero sea valido este metodo lei que hay una funcion en especifico pero para iniciar a programar otra vez, es mejor este metodo, pero no creo acabar todos los ejercicios
