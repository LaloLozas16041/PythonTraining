# %% [markdown]
# # TAREA SEMANA 1: FUNDAMENTOS DE PHYTON

# %% [markdown]
# # #NOMBRE: LEONCIO EMMANUEL TORRES FLORES

# %% [markdown]
# ###Ejercicio 1 Listo
# Crea un programa que tome un número ingresado por el usuario y determine si es par o impar.

# %%
numero = int (input("ingrese un numero "))
residuo = numero%2
if residuo == 0:
    print ("Número par")
else:
    print ("Número impar")
# Out:
# ingrese un numero 99
# Número impar

# %% [markdown]
# ###Dificultades: Encontrar la operación para obtener el residuo de la división

# %% [markdown]
# ###Ejercicio 2 Listo
# Escribe un programa que convierta una cadena de texto en mayúsculas.

# %%
Cadena_de_texto = input("ingrese texto ")
Mayusculas = Cadena_de_texto.upper()
print (Mayusculas)
# Out:
# ingrese texto Código
# CÓDIGO

# %% [markdown]
# ###Dificultades: Ninguna

# %% [markdown]
# ###Ejercicio 3 Lista
# Crea un programa que lea una cadena de texto ingresada por el usuario y que cuente cuántas veces aparece una letra específica en ella.

# %%
cadena_de_texto = input ("ingrese texto ")
letra = input ("Ingrese letra ")
cuenta = cadena_de_texto.count(letra)
print (cuenta)
# Out:
# ingrese texto ingrese los caracteres
# Ingrese letra e
# 4

# %% [markdown]
# ###Dificultades: Ninguna

# %% [markdown]
# ###Ejercicio 4
# Escribe un programa que determine si un número es primo o no.

# %%
numero = int (input ("Escribe un numero"))
lista = [numero]
for cont in range(numero):
   print (cont)
# Out:
# Escribe un numero4
# 0
# 1
# 2
# 3

# %% [markdown]
# ###Dificultades: No me funciono el bucle for

# %% [markdown]
# ###Ejercicio 5 Listo
# Crea un programa que calcule el área de un triángulo a partir de la base y la altura ingresadas por el usuario.

# %%
base = float (input ("Ingrese la medida de la base ="))
altura = float (input ("Ingrese la medida de la altura ="))
area = ((base * altura)/2)
print (area)
# Out:
# Ingrese la medida de la base =10
# Ingrese la medida de la altura =2
# 10.0

# %% [markdown]
# ###Dificultades: Olvidé definir el tipo de dato que era el número ingresado y marcaba error

# %% [markdown]
# ###Ejercicio 6 Listo
# Escribe un programa que tome una lista de números y devuelva la suma de todos ellos.

# %%
numero1 = int(input("primer_numero "))
numero2 = int(input("segundo_numero "))
numero3 = int(input("tercer_numero "))
numero4 = int(input("cuarto_numero "))
numero5 = int(input("quinto_numero "))
lista = [numero1, numero2, numero3, numero4, numero5]
print (lista)
print ("Suma")
suma = lista[0]+lista[1]+lista[2]+lista[3]+lista[4]
print (suma)
# Out:
# primer_numero 1
# segundo_numero 2
# tercer_numero 3
# cuarto_numero 4
# quinto_numero 5
# [1, 2, 3, 4, 5]
# Suma
# 15

# %% [markdown]
# ### Dificultades: Ninguna

# %% [markdown]
# ###Ejercicio 7
# Crea un programa que reciba una lista de nombres y que imprima solo aquellos que comiencen con una letra específica dada por el usuario.

# %%
nombre1 = input("primer_nombre ")
nombre2 = input("segundo_nombre ")
nombre3 = input("tercer_nombre ")
nombre4 = input("cuarto_nombre ")
nombre5 = input("quinto_nombre ")
letra = input("letra ")
nombres = [nombre1, nombre2, nombre3, nombre4, nombre5]
print (nombres)
for nombre in nombres:
    if nombre.startswith(letra):
        print (nombre)
# Out:
# primer_nombre ana
# segundo_nombre ana
# tercer_nombre ana
# cuarto_nombre pe
# quinto_nombre ja
# letra a
# ['ana', 'ana', 'ana', 'pe', 'ja']
# ana
# ana
# ana

# %% [markdown]
# ###Dificultades: No me funciono, no imprime las que solo empiezan con cierta letra

# %% [markdown]
# ###Ejercicio 8 Listo
# Escribe un programa que determine si una cadena de texto es un palíndromo o no.

# %%
palabra = input ("Escribe una palabra ")
palabra_al_reves = palabra[::-1]
print (palabra)
print (palabra_al_reves)
if palabra == palabra_al_reves:
    print ("Palindromo")
else:
    print ("No es palindromo")
# Out:
# Escribe una palabra ama
# ama
# ama
# Palindromo

# %% [markdown]
# ###Dificultades: Ninguna

# %% [markdown]
# ###Ejercicio 9
# Crea un programa que tome una lista de números y elimine todos los duplicados.

# %%
numero1 = int(input("primer_numero "))
numero2 = int(input("segundo_numero "))
numero3 = int(input("tercer_numero "))
numero4 = int(input("cuarto_numero "))
numero5 = int(input("quinto_numero "))
lista = [numero1, numero2, numero3, numero4, numero5]
print (lista)

# %% [markdown]
# ###Dificultades: No encontre la forma de buscar los duplicados

# %% [markdown]
# ###Ejercicio 10
# Escribe un programa que tome una lista de números y devuelva el valor máximo.

# %%
numero1 = int(input("primer_numero "))
numero2 = int(input("segundo_numero "))
numero3 = int(input("tercer_numero "))
numero4 = int(input("cuarto_numero "))
numero5 = int(input("quinto_numero "))
lista = [numero1, numero2, numero3, numero4, numero5]
print (lista)
max1 = numero1>numero2 & numero1>numero3 & numero1>numero4
print (max1)
# Out:
# primer_numero 8
# segundo_numero 5
# tercer_numero 5
# cuarto_numero 5
# quinto_numero 5
# [8, 5, 5, 5, 5]
# False

# %% [markdown]
# ###Dificultades: Ninguna

# %% [markdown]
# ###Ejercicio 11 Listo
# Crea un programa que solicite al usuario su edad y que determine en que etapa de la vida se encuentra:
# Primera Infancia (0-5 años)
# Infancia (6 - 11 años)
# Adolescencia (12 - 18 años)
# Juventud (14 - 26 años)
# Adultez (27- 59 años)
# Persona Mayor (60 años o más).

# %%
edad = int (input ("Ingrese su edad= "))
primera_infancia = edad<=5
infancia = 6<=edad<=11
adolescencia = 12<=edad<=18
juventud = 14<=edad<=26
adultez = 27<=edad<=59
persona_mayor = edad>59
if primera_infancia == True:
    print ("Primera infancia")
elif infancia == True:
    print ("Infancia")
elif adolescencia == True:
    print ("Adolescencia")
elif juventud == True:
    print ("Juventud")
elif adultez == True:
    print ("Adultez")
else:
    print ("Persona mayor")
# Out:
# Ingrese su edad= 59
# Adultez

# %% [markdown]
# ###Dificultades: Escribí print a la misma altura que if y marcaba error, olvidé poner dos puntos después de los if y else, creo que pude haber comparado el valor e imprimir el resultado directamente, en este caso yo hago la comparación y la asigno a una variable y despues reviso si es True o False

# %% [markdown]
# ###Ejercicio 12 Listo
# Escribe un programa que tome una cadena de texto y que la divida en palabras, eliminando los espacios en blanco.

# %%
cadena_de_texto = input ("Ingrese texto ")
print (cadena_de_texto)
sin_espacios= cadena_de_texto.replace(" ", "")
print (sin_espacios)
# Out:
# Ingrese texto cadena de caracteres
# cadena de caracteres
# cadenadecaracteres

# %% [markdown]
# ###Dificultades: Ninguna

# %% [markdown]
# ###Ejercicio 13
# Crea un programa que tome dos listas de números y que devuelva una tercera lista con los elementos comunes a ambas.

# %%
code

# %% [markdown]
# ###Dificultades:

# %% [markdown]
# ###Ejercicio 14 Listo
# Escribe un programa que tome una cadena de texto y que cuente cuántas palabras hay en ella.

# %%
cadena_de_texto = input("Ingrese texto ")
palabras = cadena_de_texto.split()
numero = len(palabras)
print (numero)
# Out:
# Ingrese texto cadena de texto
# 3

# %% [markdown]
# ###Dificultades: Ninguna

# %% [markdown]
# ###Ejercicio 15 Lista
# Crea un programa que calcule el área de un círculo a partir del radio ingresado por el usuario.

# %%
radio = float(input("inserte el radio = "))
area = (2 * 3.1416 * radio * radio)
print (area)
# Out:
# inserte el radio = 1
# 6.2832

# %% [markdown]
# ###Dificultades: Ninguna

# %% [markdown]
# ###Ejercicio 16 Lista
# Escribe un programa que tome una lista de números y que devuelva la media aritmética.

# %%
numero1 = int(input("primer_numero "))
numero2 = int(input("segundo_numero "))
numero3 = int(input("tercer_numero "))
numero4 = int(input("cuarto_numero "))
numero5 = int(input("quinto_numero "))
lista = [numero1, numero2, numero3, numero4, numero5]
print (lista)
media = sum(lista)/5
print (media)
# Out:
# primer_numero 10
# segundo_numero 10
# tercer_numero 10
# cuarto_numero 10
# quinto_numero 10
# [10, 10, 10, 10, 10]
# 10.0

# %% [markdown]
# ###Ejercicio 17 Listo
# Crea un programa que reciba dos números ingresados por el usuario y que devuelva su producto.

# %%
numero_1 = int(input("Ingrese numero 1=  "))
numero_2 = int(input("Ingrese numero 2=  "))
producto = numero_1*numero_2
print (producto)
# Out:
# Ingrese numero 1=  3
# Ingrese numero 2=  4
# 12

# %% [markdown]
# ###Dificultades: Ninguna

# %% [markdown]
# ###Ejercicio 18
# Escribe un programa que tome una lista de palabras y que devuelva una lista con todas las palabras en mayúsculas.

# %%
code

# %% [markdown]
# ###Dificultades:

# %% [markdown]
# ###Ejercicio 19
# Crea un programa que tome una lista de números y que devuelva la suma de aquellos que son mayores a un valor específico ingresado por el usuario.

# %%
code

# %% [markdown]
# ###Dificultades:

# %% [markdown]
# ###Ejercicio 20
# Escribe un programa que tome una cadena de texto y que devuelva una nueva cadena con todas las letras en mayúsculas excepto la primera letra de cada palabra, que debe ser en minúsculas.

# %%
code

# %% [markdown]
# ###Dificultades:
