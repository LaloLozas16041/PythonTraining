# %%
#Tarea semana 1 FUNDAMENTOS DE PYTHON
#Nombre: Stefano Daniel Magaña Canchola

# %%
#Ejercicio 1
#Crea un programa que tome un número ingresado por el usuario y determine si es par o impar.

# %%
print ("Ingrese un numero")
numeroej1=input ()
residuoej1=(int(numeroej1))%2
if residuoej1 == 0:
    print("El numero",(numeroej1),"es Par")
else:
    print("El numero",(numeroej1),"es Impar")

# %%
#Explicacion:
#En este ejercicio el algoritmo esta ordenado de la siguiente manera:
#1er linea: Se imprime el string "Ingrese un numero".
#2da linea: Se genera un input para que el usuario ingrese un numero y lo guarda en la variable "numero".
#3er linea: Se saca el residuo de la variable "numero" usando el operador residuo al dividirlo entre 2,
#           y se guarda en la variable "residuo"
#4ta y 
#5ta linea: Se utiliza el condicional if para comparar si el "residuo" es igual a 0, si es afirmativo, mostrara el string 
            #"El numero es par" 
#6ta y 
#7a linea:  Se utiliza el condicional else para que si el residuo de la division es diferente a 0 imprima el siguiente String:
            #"El numero es Impar"

# %%
#Ejercicio 2
#Escribe un programa que convierta una cadena de texto en mayúsculas.

# %%
textoej1=("Sere un buen analista de datos")
print("Texto original:",(textoej1))
textoej1_en_mayusculas=textoej1.upper()
print("Texto en mayusculas:",(textoej1_en_mayusculas))

# %%
#Explicacion:
#En la primer linea se define la cadena de texto que fromara la variable "texto". 
#En la segunda linea imprime en pantalla la variable "texto". 
#En la tercer linea se utiliza la funcion upper para convertir toda la cadena de texto "texto" 
#y guardarla en la variable texto_en_mayusculas. Po ultimo en la cuarta linea se imprime en pantalla la 
#variable texto_en_mayusculas.

# %%
#Ejercicio 3
#Crea un programa que lea una cadena de texto ingresada por el usuario y que cuente cuántas veces aparece una letra 
#específica en ella.

# %%
print("Ingrese un texto")
textoej3=input()
print("¿Que letra desea buscar en el texto?")
letraesp=input()
repletra=0
for letra in textoej3:
    if letraesp==letra:
        repletra=repletra+1
if repletra > 0:
    print("La letra",(letraesp),"aparece",(repletra),"veces.")
else:
    print("La letra",(letraesp),"aparece 0 veces.")

# %%
#Explicacion:
#Ejercicio 3
#En la primera línea se imprime el texto “Ingrese el texto”
#En la segunda línea se genera un input el cual ingresara un texto y lo guardara en la variable textoej3 
#En la tercera línea se imprime “Que letra desea buscar en el texto”
#En la cuarta línea se genera un input el cual ingresara un texto y lo guardara en la variable letraesp3 
#En la quinta línea se genera una variable llamada repletra y se le asigna el numero 0
#En la sexta línea se genera un ciclo for el cual guardara la variable en letra basándose en textoej3 anteriormente 
#ingresada, dentro del for se genera un condicional if el cual compara si la letra esp ingresada en igual a la variable 
#letra en donde se encuentra el for, de forma que en la séptima línea sume 1 a la variable repletra. 
#La octava línea se genera un if fuera del for en la cual se compara si repletra es mayor a 0 y se imprime el texto con 
#la letra seguida de la variable letraesp, aparece texto seguido de la variable repletra, mas el número de veces que apareció 
#y el texto “veces”. 
#En la ultima línea se genera un else es decir que letra que es igual a 0 se imprimirá seguido de la variable 
#letraesp y el mensaje de “aparece 0 veces”

# %%
#Ejercicio 4
#Escribe un programa que determine si un número es primo o no.

# %%
print ("Ingrese un numero")
numeroej4=input ()
es_primo=(False)
noes_primo=(False)
for n in range(2, (int(numeroej4))):
    (residuoej4)=int(numeroej4)%n
    if residuoej4==0:
        noes_primo=True 
    elif residuoej4 > 0:
        es_primo=True 
if es_primo==True and noes_primo==False:
    print("El numero",(numeroej4),"es primo")
elif noes_primo==True:
    print("El numero",(numeroej4),"no es primo")

# %%
#Explicacion:
#Para determinar si un numero es primo o no es primo, primero se abre un input para ingresar el numero a analizar
#se asignan a variables, valores FALSES boleanos para inicializar las variables y utilizarlo mas adelante.
#con un for se saca el residuo de todos los numeros desde el 2 hasta uno antes del numero, 
#usando comparativos if, se compara si en algun numero el residuo es igual a cero, entonces se imprimira
#"el numero no es primo" y si por el contrario si en todos los numeros el residuo es diferente de 0
#entonces se imprimira "El numero es primo"

# %%
#Ejercicio 5
#Crea un programa que calcule el área de un triángulo a partir de la base y la altura ingresadas por el usuario.

# %%
print ("Calcularemos el area de un triangulo")
print ("Porfavor ingresa la longitud de la base")
baseej5=input()
print ("Porfavor ingresa la longitud de la altura")
alturaej5=input()
areaej5= (int(baseej5)*int(alturaej5)/2)
print("El area del triangulo es:",(areaej5))

# %%
#Explicacion:
#Para calcular el area de un triangulo primero pedimos mediante un input el valor de la variable base y altura, posteriormente
#transformamos estas variables a tipo entero para luego multiplicar base por altura y el resultado dividirlo entre dos y 
#guardarlo en la variable "area".
#por ultimo imprimimos la variable area

# %%
#Ejercicio 6
#Escribe un programa que tome una lista de números y devuelva la suma de todos ellos.

# %%
listaej6=[4,5,10,25]
sumej6=0
for numej6 in listaej6:
    sumej6=numej6+sumej6
print("El resultado de sumar los elementos de la lista es:",sumej6)

# %%
#Explicacion:
#Para este ejercicio primero definimos la lista con los numeros a sumar y los guardamos en la variable "listaej6"
#Posteriormente inicializamos la variable sumej6 donde guardaremos el resultado de la suma de los numeros y se una variable
#Global.
#Luego con un for recorremos los numero de la lista y los vamos sumando a sumej6 hasta que lleguemos a ultimo numero.
#Por ultimo imprimos el valor final de la variable "sumeej6"

# %%
#Ejercicio 7
#Crea un programa que reciba una lista de nombres y que imprima solo aquellos que comiencen con una 
#letra específica dada por el usuario.

# %%
listaej7=["Daniel","Mariana","Damian","Mario"]
print("Ingrese la letra con la que hara la busqueda de nombres")
letraej7=input()
letraej7=letraej7.lower()
letraej7=letraej7.strip()
nombresej7=[]
for n in listaej7:
    n2=n.strip()
    n2=n2.lower()
    if n2[0]==letraej7:
        nombresej7.append(n)
print(nombresej7)
# Out:
# Ingrese la letra con la que hara la busqueda de nombres
# d
# ['Daniel', 'Damian']

# %%
#Explicacion:
#Primero generamos la lista con los nombres a analisar y la guardamos en la variable listaej6.
#Luego generamos un input en el cual se ingrese la letra con la que deberan de empezar los nombres de la nueva lista
#en base a la primer lista.
#Hacemos miniscula la letra ingresadan con Lower para que este factor no importe.
#Creamos una lista vacia en donde se ingresaran los nombres de la lista que empiezen con la letra designada.
#luego con strip quitamos los espacios que pudiera haber al principio y al final
#Generamos un for para recorrer nombre por nombre los elementos de la primer lista.
#Usando la indexacion de string usamos el condicional para preguntar si la primer letra del string es igual a
#la letra de busqueda ingresada.
#Si es asi, usando append agragamos el nombre a la nueva lista.
#Por ultimo, imprimimos la nueva lista.
# Out:
#   Cell In[13], line 2
#     Primero generamos la lista con los nombres a analisar y la guardamos en la variable listaej6.
#             ^
# SyntaxError: invalid syntax

# %%
#Ejercicio 8    
#Escribe un programa que determine si una cadena de texto es un palíndromo o no.

# %%
print("ingrese la palabra a ser analizada")
palabraej8=input()
print ("La palabra","--",palabraej8,"--","es la palabra original")
palnospacej8=palabraej8.replace(" ","")
palnospacej8=palnospacej8.lower()
invert=("")
long=0
for cont1ej8 in palnospacej8:
    long=long+1
long2=long
for cont2ej8 in palnospacej8:
    letej8=palnospacej8[long2-1]
    invert=invert+letej8
    long2=long2-1
print ("La palabra","--",invert,"--","es la palabra invertida")
if palnospacej8==invert:
    print("La palabra","--",palabraej8,"--","es palindroma")
else:
    print("La palabra","--",palabraej8,"--","no es palindroma")
# Out:
# ingrese la palabra a ser analizada
# oSo
# La palabra -- oSo -- es la palabra original
# La palabra -- oso -- es la palabra invertida
# La palabra -- oSo -- es palindroma

# %%
#Explicacion:
#Ingresasmos la palabra a evaluar mediante un input y la guardamos en una variable, usamos replace para quitarle los espacios
#a la palabra o frase, generamos una cadena vacia para agregar las letras de la palabra invertida,genramos variables cont1 
# y cont2 para identificar el numero de indexacion de la variable. generamos un for con el caul recorreremos letra por letra 
#la frase, tomamos la letra y con otro for ingresamos la letra usando el cont2 que corre en sentido inverso a cont1
#para ingresarla en el index contrario al que estaba originalmente.
#por ultimo comparamos con if la palabra invertida generada con la palabra sin espacios y si son iguales
#imprimimos "Es palindroma" y si no "No es palindroma"

# %%
#Ejercicio 9
#Crea un programa que tome una lista de números y elimine todos los duplicados.

# %%
listaej9=[5,5,5,2,43,23,2]
print("La lista original es:",listaej9)
cont1ej9=0
cont2ej9=0
listaelim=[]
for nej9 in listaej9:
    cont1ej9=cont1ej9+1
    cont2ej9=0
    for n2ej9 in listaej9:
        cont2ej9=cont2ej9+1
        if cont1ej9==cont2ej9:
            pass
        else:
            if nej9==n2ej9:
                elim=listaej9.pop(cont1ej9-1)
                listaelim.append(elim)
print("Los elementos duplicados eliminados son:",listaelim)
print("La lista sin duplicados queda:",listaej9)
# Out:
# La lista original es: [5, 5, 5, 2, 43, 23, 2]
# Los elementos duplicados eliminados son: [5, 5, 2]
# La lista sin duplicados queda: [5, 2, 43, 23]

# %%
#Explicacion:
#Generamos la lista a ser analizada, generamos cont1 y cont2 que nos ayudaran a llevar el conteo del recorrdio 
#de numeros y compararlos, generamos la lista vacia en la cual se agregaran los numeros eliminados para mostrarlos luego 
#con un for recorremos los numeros de la lista, guardamos el primer numero a comparar y con cont llevamos un conteo ascendente
#hasta el ultimo elemento.
#Luego Con otro for dentro del primero, recorremos de nuevo los numeros de la lista llevamos un conteo decendente y 
#guardamos la segunda variable a comparar. Con comparadores if preguntamos si
#el cont1 es igaul a con2, si es asi, signfifica que es el mismo elemento de la lista y no se debe comparar, usamos pass
#para saltar esa parte del for. Si los contadores no son iguales entonces con otro if comparamos ambas variables y eliminamos 
#la una de ellas si son iguales.
#Asi hasta que solo queden numeros sin duplicar.
#Por ultimo imprimimos la lista con los numeros resultantes y la lista con las variables eliminadas
#
#

# %%
#Ejercicio 10
#Escribe un programa que tome una lista de números y devuelva el valor máximo.

# %%
listaej10=[5,4,5,2,43,23,2]
print("La lista es:",listaej10)
cont1ej10=0
cont2ej10=0
elimej10=()
for nej10 in listaej10:
    cont1ej10=cont1ej10+1
    cont2ej10=0
    for n2ej10 in listaej10:
        cont2ej10=cont2ej10+1
        if cont1ej10==cont2ej10:
            pass
        else:
            if nej10>n2ej10:
                elimej10=listaej10.pop(cont1ej10)
print("El numero mayor de la lista es:",listaej10)
# Out:
# La lista es: [5, 4, 5, 2, 43, 23, 2]
# El numero mayor de la lista es: [5, 43]

# %%
#Explicacion:
#Generamos la lista a ser analizada, generamos cont1 y cont2 que nos ayudaran a llevar el conteo del recorrdio 
#de numeros y compararlos, generamos la lista vacia en la cual se agregaran los numeros eliminados para mostrarlos luego 
#con un for recorremos los numeros de la lista, guardamos el primer numero a comparar y con cont llevamos un conteo ascendente
#hasta el ultimo elemento.
#Luego Con otro for dentro del primero, recorremos de nuevo los numeros de la lista llevamos un conteo decendente y 
#guardamos la segunda variable a comparar. Con comparadores if preguntamos si
#el cont1 es igaul a con2, si es asi, signfifica que es el mismo elemento de la lista y no se debe comparar, usamos pass
#para saltar esa parte del for. Si los contadores no son iguales entonces con otro if comparamos ambas variables y eliminamos 
#la que sea menor.
#Asi hasta que solo quede el numero mayor.
#Por ultimo imprimimos la lista con el numero mayor y la lista con las variables eliminadas
#
#

# %%
#Ejercicio 11
#Crea un programa que solicite al usuario su edad y que determine en que etapa de la vida se encuentra:
#Primera Infancia (0-5 años)
#Infancia (6 - 11 años)
#Adolescencia (12 - 18 años)
#Juventud (14 - 26 años)
#Adultez (27- 59 años)
#Persona Mayor (60 años o más).

# %%
print("Ingrese su edad")
edad=input()
if int(edad) > -1:
    if int(edad) < 6:
        print("Usted esta en la Primera infancia")
if int(edad) > 5:
    if int(edad) < 12:
        print("Usted esta en la Infancia")
if int(edad) > 11:
    if int(edad) < 19:
        print("Usted esta en la adolescencia")
if int(edad) > 13:
    if int(edad) < 27:
        print("Usted esta en la Juventud")
if int(edad) > 26:
    if int(edad) < 60:
        print("Usted esta en la Adultez")
if int(edad) > 59:
    print("Usted esta en la edad de Persona Mayor")

# %%
#Explicacion:
#Ingresamos el numero de la edad a analizar y la convertimos en int 
#usando condicionales generamos todas las opciones que hay para catalogar la edad, por ejemplo: si la edad esta entre
#0 y 6 años entonces imprimiria "Usted esta en la infancia"

# %%
#Ejercicio 12
#Escribe un programa que tome una cadena de texto y que la divida en palabras, eliminando los espacios en blanco.

# %%
print("Ingrese el texto a dividir")
textoej12=input()
listej12=[]
textdivej12=textoej12.split()
for strej12 in textdivej12:
    textnospace=strej12.strip()
    listej12.append(textnospace)
print(listej12)

# %%
#Explicacion:
#Ingresamos el texto a procesar, generamos una lista vacia en la que se agregaras las palabras por separado del texto a
#analizar.con la funcion Split separamos las palabras del texto utilizando los espacios con separador,
#Usamos un For recorremos los elementos de la lista generada por split, utilizamos strip para quitar los espacios al 
#principio y al final, y la agregamos a la nueva lista
#Por ultimo imprimimos la nueva lista.
#

# %%
#Ejercicio 13
#Crea un programa que tome dos listas de números y que devuelva una tercera lista con los elementos comunes a ambas.

# %%
lista1ej13=[2,5,3,4,6,44,12,11,25,354,233,111]
lista2ej13=[3,1,10,6,25,33,44,55]
lista3ej13=[]
print("La lista 1 es:",lista1ej13)
print("La lista 2 es:",lista2ej13)
for nej13 in lista1ej13:
    for n2ej13 in lista2ej13:
        if nej13==n2ej13:
            lista3ej13.append(nej13)
        else:
            pass
print("Los elementos comunes de las listas son:",lista3ej13)
# Out:
# La lista 1 es: [2, 5, 3, 4, 6, 44, 12, 11, 25, 354, 233, 111]
# La lista 2 es: [3, 1, 10, 6, 25, 33, 44, 55]
# Los elementos comunes de las listas son: [3, 6, 44, 25]

# %%
#Explicacion:
#Genramos las listas con los numeros a comparar
#Generamos una 3ra lista vacia en la que se agregaran los numeros en comun. Con un For recorremos los elementos de la lista 1 
#y guardamos la primer variable a comparar. Con otro for dentro de ese mismo For, recorremos los numeros del segundo for y 
#guardamos la segunda variable a comparar.
#Usando condicionales If, preguntamos si las dos variables son iguales, si es asi, la agregamos a la 3er lista con append
#y si no pasamos al siguiente caso con pass
#
#

# %%
#Ejercicio 14
#Escribe un programa que tome una cadena de texto y que cuente cuántas palabras hay en ella.

# %%
textoej14=("habia una vez un barco chiquito")
palabrasej14=textoej14.split()
contej14=0
for palab in palabrasej14:
    contej14=contej14+1
print("La cadena de texto","--",textoej14,"--","tiene",contej14,"palabras")

# %%
#Explicacion:Se crea la cadena analizada, con split se separara la cadena 
#en palabras usando como separador el espacio
#se genera una variable cont para llevar el conteo de palabras 
#con un for se recorre palabra por palabra de la lista generada con split
#y se suma 1 al contador para que se cuenten 
#por ultimo se impirme el valor final del contador

# %%
#Ejercicio 15
#Crea un programa que calcule el área de un círculo a partir del radio ingresado por el usuario.

# %%
print("Calculemos el area de un circulo")
print("Ingrese el radio del circulo")
radioej15=input()
areaej15= 3.141592*((int(radioej15)**2))
print("El area del circulo es:",areaej15)

# %%
#Explicacion: Se ingresa el raio del circulo mediante un input 
#se calcula el area del circulo convirtiendo en entero el valor del radio 
#elevandolo al cuadrado y multiplicandolo por pi y se guarda en la variable area
#se imprime la variable area

# %%
#Ejercicio 16
#Escribe un programa que tome una lista de números y que devuelva la media aritmética.

# %%
listej16=(5,4,54,3,1,18)
sumej16=0
contej16=0
for numej16 in listej16:
    sumej16=numej16+sumej16
    contej16=contej16+1
promej16=sumej16/contej16
print("La media Aritmetica de los numeros en la lista es:",promej16)

# %%
#Explicacion:Se genera la lista con los numeros a analizar 
#se genera la variable del contador en 0 y la variable donde se guardara la suma
#con un for recorremos uno a uno los numeros de la lista y lo sumamos a la variable suma, le sumamos 1 al contador
#Calculamos el promedio con el reesuktado final de la suma dividido entre el valor final del contador 
#se imprime el promedio

# %%
#Ejercicio 17
#Crea un programa que reciba dos números ingresados por el usuario y que devuelva su producto.

# %%
print("Saquemos el producto de dos numeros")
print("Ingrese el primer numero a multiplicar")
num1ej17=input()
print("Ingrese el segundo numero a multiplicar")
num2ej17=input()
multej17=(int(num1ej17))* (int(num2ej17))
print("El producto de los dos numeros ingresados es:",multej17)

# %%
#Explicacion:Se ingresa el primer numero mediante un input y se guarda en una variable 
#se hace los mismo con el segundo numero 
#Se convierten a enteros los numeros y se usa el modulo multiplicar para que ambos sean multiplicados
#Se guarda el producto en una variable y se imprime

# %%
#Ejercicio 18
#Escribe un programa que tome una lista de palabras y que devuelva una lista con todas las palabras en mayúsculas.

# %%
listej18=("pikachu","charmander","Bulbasoor","toGGepi")
listmayej18=[]
for wordej18 in listej18:
    wordmayej18=wordej18.upper()
    listmayej18.append(wordmayej18)
print("La lista en mayusculas es:",listmayej18)
# Out:
# La lista en mayusculas es: ['PIKACHU', 'CHARMANDER', 'BULBASOOR', 'TOGGEPI']

# %%
#Explicacion: Se genera una lista con palabras por procesar
#Se genera otra lista vacia en la cual se guardara las palabras en mayuscula
#usando un fro recorremos palabra por palabra de la lista y usamos la funcion 
#upper para hacerla mayuscula
#Agregamos la palabra en mayuscula a la nueva lista y al terminar se imprime la lista

# %%
#Ejercicio 19
#Crea un programa que tome una lista de números y que devuelva la suma de aquellos que son mayores a un 
#valor específico ingresado por el usuario.
print("Vamos a sumar los numeros en una lista que sean mayores al numero que tu definas..")
listej19=(3,1,16,9,12,5)
print("¿A que numero tienen que ser mayores los numeros a sumar?")
numespej19=input()
sumej19=0
nummayej19=0
for numej19 in listej19:
    if numej19 > int(numespej19):
        nummayej19=numej19
        sumej19=nummayej19+sumej19
    else:
        pass
print("La suma de los numeros en la lista mayores a:",numespej19,"es:",sumej19)

# %%
#Explicacion:
#Se genera la lista con los numeros a analizar, se genera un input para ingresar el valor a sobrepasar para sumar.
#generamos una variable suma vacia para guardar el resultado de la suma
#con un for, recorremos uno a uno los numeros de la lista y usando comparadores if comparamos primero si el numero es mayor 
#al numero definido anteriormente y si es asi, sumamos el numero a la variable suma.
#Hacemos un pass para seguir el for en caso de no ser mayor el numero.
#al terminar imprimimos la suma.
#

# %%
#Ejercicio 20
#Escribe un programa que tome una cadena de texto y que devuelva una nueva cadena con todas las letras en mayúsculas 
#excepto la primera letra de cada palabra, que debe ser en minúsculas.

# %%
textej20=("habia una vez un barquitoo")
contej20=1
newtextej20=("")
for letej20 in textej20:
    if contej20 == 1:
        letminej20=letej20.lower()
        newtextej20=newtextej20+letminej20
        contej20=contej20+1
    else:
        letmayej20=letej20.upper()
        newtextej20=newtextej20+letmayej20
        contej20=contej20+1
print(newtextej20)
# Out:
# hABIA UNA VEZ UN BARQUITOO

# %%
#Explicacion:
#Se genera una lista con palabras por procesar
#se genera un contador inicializado en 1 para identificar en que numero de variable se esta
#Se genera una cadena vacia en la cual se guardara las palabras en mayuscula
#usando un for recorremos palabra por palabra de la lista y usamos condicionales if para preguntar si el contador va en 1
#Es decir, es la primer letra, si es asi usamos la funcion lower para hacer minuscula la letra, si no es asi usamos
#upper para hacerla mayuscula
#Agregamos la palabra en mayuscula a la nueva variable, le sumamos 1 al contador y al terminar se imprime la variable.
