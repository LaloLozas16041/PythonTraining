# %% [markdown]
# # TAREA SEMANA 1 : FUNDAMENTOS DE PYTHON
# ## Nombre : Salvador Trejo Espinosa

# %% [markdown]
# ### Ejercicio 1
# Crea un programa que tome un número ingresado por el usuario y determine si es par o impar.

# %%
numero = int(input("ingrese un numero:"))  

if numero  % 2 == 0:    
    print(numero, "el numero ingresado es par")  
else:
    print(numero, "el numero ingresado es impar")
# Out:
# ingrese un numero:5
# 5 el numero ingresado es impar

# %% [markdown]
# **Explicacion:**
# no sabia que el simbolo de % se usaba para hacer la division de un numero y ver si tenia residuo.
# otra solucion fue pensar en dividir el numero entre dos y ver si el resultado tiene punto decimal o no.

# %% [markdown]
# ### Ejercicio 2
# Escribe un programa que convierta una cadena de texto en mayúsculas

# %%
string = input("ingrese una frase: ")   
string = string.upper()

print("frase en mayusculas:", string)
# Out:
# ingrese una frase: hola como esta
# frase en mayusculas: HOLA COMO ESTA

# %% [markdown]
# **Explicacion:**
# tuve que buscar una funcion para hacer las letras mayusculas

# %% [markdown]
# ### Ejercicio 3
# Crea un programa que lea una cadena de texto ingresada por el usuario y que cuente cuántas veces aparece una letra específica en ella.

# %%
texto = input("Ingrese una cadena de texto: ")
letra = input("igrese la letra que quiere contar: ")
count = 0
for char in texto:
    if char == letra:
        count += 1
print("la letra", letra,  "aparece",count, "veces")
# Out:
# Ingrese una cadena de texto: que haces
# igrese la letra que quiere contar: q
# la letra q aparece 1 veces

# %% [markdown]
# **Explicacion:**
# lo dificil es encontrar la funcion char y hacer la suma de la cuenta

# %% [markdown]
# ### Ejercicio 4
# Escribe un programa que determine si un número es primo o no.

# %%
num = int(input("Ingresa el numero: "))

if num > 1:
    for i in range
# Out:
#   File "C:\Users\Chava\AppData\Local\Temp\ipykernel_804\1759654186.py", line 4
#     for i in range
#                   ^
# SyntaxError: invalid syntax

# %% [markdown]
# **Explicacion:**
# no pude hacerlo no entiendo como declarar el for aqui

# %% [markdown]
# ### Ejercicio 5
# Crea un programa que calcule el área de un triángulo a partir de la base y la altura ingresadas por el usuario.

# %%
base = float(input("Ingrese la base del triangulo: "))
altura = float(input("Ingrese la altura del triangulo: "))

area =  (base * height)/2

print("El area del triangulo es:", area)
# Out:
# Ingrese la base del triangulo: 4
# Ingrese la altura del triangulo: 6
# El area del triangulo es: 12.0

# %% [markdown]
# **Explicacion:**
# no tuve dificultad para este

# %% [markdown]
# ### Ejercicio 6
# Escribe un programa que tome una lista de números y devuelva la suma de todos ellos.

# %%
lista_de_numeros = [2, 5, 2, 10, 25]

suma = 0

for num in lista_de_numeros:
    suma += num

print("la suma de los numeros es:", suma)
# Out:
# la suma de los numeros es: 44

# %% [markdown]
# **Explicacion:**
# Tuve que buscar la funcion para hacer la suma

# %% [markdown]
# ### Ejercicio 7
# Crea un programa que reciba una lista de nombres y que imprima solo aquellos que comiencen con una letra específica dada por el usuario.

# %%
name = []

n = int(input("Ingrese la cantidad de nombres que quiere agregar a la lista: "))

for i in range(n): 
    name = input("escriba el nombre: ")
    names.append(name)

letter = input("ingrese la letra de los nombres que quiere imprimir: ")
print ("los nombres son:",names.append(name))
# Out:
# Ingrese la cantidad de nombres que quiere agregar a la lista: 2
# escriba el nombre: mario
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3844\130505794.py in <module>
#       5 for i in range(n):
#       6     name = input("escriba el nombre: ")
# ----> 7     names.append(name)
#       8
#       9 letter = input("ingrese la letra de los nombres que quiere imprimir: ")
#
# NameError: name 'names' is not defined

# %% [markdown]
# **Explicacion:**
# no se como imprimir los nombres

# %% [markdown]
# ### Ejercicio 8
# Escribe un programa que determine si una cadena de texto es un palíndromo o no.

# %%
def is_palindrome(s):
    # Convert the string to lowercase and remove non-alphanumeric characters
    s = ''.join(c for c in s if c.isalnum()).lower()
    # Check if the string is equal to its reverse
    return s == s[::-1]

# Ask the user to enter a string
s = input("Enter a string: ")

# Check if the string is a palindrome
if is_palindrome(s):
    print(s, "is a palindrome")
else:
    print(s, "is not a palindrome")
# Out:
# Enter a string: anita lava la tino
# anita lava la tino is not a palindrome

# %% [markdown]
# **Explicacion:**
# la verdad es que no entendí como hacerlo, encontre este codigo pero no funciona y no se como funciona :(

# %% [markdown]
# ### Ejercicio 9
# Crea un programa que tome una lista de números y elimine todos los duplicados.

# %%
nums = [1, 2, 3, 2, 4, 3, 5, 6, 2, 7]

def remove_duplicates(nums):
    return list(set(nums))

unique_nums = remove_duplicates(nums)
print(unique_nums)
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %% [markdown]
# **Explicacion:**
# lo dificil es saber usar la funcion remove_duplicates

# %% [markdown]
# ### Ejercicio 10
# Escriba un programa que tome una lista de números y devuelva el valor máximo.

# %%
nums = [1, 2, 9, 2, 4, 3, 7, 6, 1]  # definimos los numero a analizar

def find_max(nums):  # define una función que toma una lista de números como entrada
    max_num = nums[0]  # inicializa el número máximo para que sea el primer número de la lista
    for num in nums:  # analiza entre el resto de los numeros
        if num > max_num:  # comprueba si el número actual es mayor que el máximo actual
            max_num = num  # entonces si lo es, actualiza el máximo para que sea el número actual
    return max_num  # y nos regresa el numero maximo


max_num = find_max(nums)  # llama a la función find_max en la lista de números y asigna el resultado a max_num
print(max_num)  # imprimimos el maximo
# Out:
# 9

# %% [markdown]
# **Explicacion:**
# lo dificil aqui es encontrar las funciones que hacen el programa

# %% [markdown]
# ### Ejercicio 11
# Crea un programa que solicite al usuario su edad y que determine en que etapa de la vida se encuentra:
#
# Primera Infancia (0-5 años).
#
# Infancia (6 - 11 años).
#
# Adolescencia (12 - 18 años).
#
# Juventud (14 - 26 años).
#
# Adultez (27- 59 años).
#
# Persona Mayor (60 años o más).

# %%
edad = int(input("Ingrese la edad de la persona: "))
if edad <= 5:
    print("la persona se encuntra en la etapa de primera infancia ")
elif edad <= 11:
    print("la persona se encuntra en la etapa de infancia")
elif edad <= 18:
    print("la persona se encuntra en la etapa de Adolescencia")
elif edad <= 26:
    print("la persona se encuntra en la etapa de Juventud")
elif edad <= 59:
    print("la persona se encuntra en la etapa de Adultez")
else :
    print("la persona es mayor")
# Out:
# Ingrese la edad de la persona: 14
# la persona se encuntra en la etapa de Adolescencia

# %% [markdown]
# **Explicacion:**
# esta mal definido el problema en este caso para definir edad entre adolescencia y juventud! o no se si se puede hacer de otra manera, creo que tambien se podia hacer definiendo los rangos exactos de edad pero seria la misma problematica

# %% [markdown]
# ### Ejercicio 12
# Escribe un programa que tome una cadena de texto y que la divida en palabras, eliminando los espacios en blanco.

# %%
frase = input("ingresa una frase u oracion: ") # pedimos ingresar una oracion

letras = frase.split() #con esta funcion dividimos el texto en letras

nuevo_texto = "".join(letras) # con join unimos las palabras indicando entre comillas que sin espacio

print("la frase u oracion sin espacios es:", nuevo_texto)# imprimos la oracion sin espacios
# Out:
# ingresa una frase u oracion: hola como estas
# la frase u oracion sin espacios es: holacomoestas

# %% [markdown]
# **Explicacion:**
# se me difilcuto en que no me se la funcion la busque en internet

# %% [markdown]
# ### Ejercicio 13
# Crea un programa que tome dos listas de números y que devuelva una tercera lista con los elementos comunes a ambas.

# %%
 #definimos las listas
list1 = [1, 6, 3, 4, 5]
list2 = [3, 4, 5, 6, 7]

# creamos la nueva lista que va a tener los elementos comunes
common_elements = []

# analizamos los elementos de la pimera lista 
for element in list1:
    # luego con el if vemos si ese elemento en lista 1 esta en lsita 2
    if element in list2:
        # si el elemento esta  en la lista 2 añadimos el elementos a la variable common_elements mediante el .append
        common_elements.append(element)

# imprimimos las listas y los elementos comunes
print("List 1:", list1)
print("List 2:", list2)
print("Common elements:", common_elements)
# Out:
# List 1: [1, 6, 3, 4, 5]
# List 2: [3, 4, 5, 6, 7]
# Common elements: [6, 3, 4, 5]

# %% [markdown]
# **Explicacion:**
# lo dificil es como se agragaban los elementos comunes a la lista y pues esta la funcion append que lo hace

# %% [markdown]
# ### Ejercicio 14
# Escribe un programa que tome una cadena de texto y que cuente cuántas palabras hay en ella.

# %%
# pedimos que se agrege la cadena de texto
text = input("ingresa una cadena de texto (una frase): ")

# creamos una nueva variable que va a guardar la cadena de texto en palabras, covirtiendo el texto en palabras con la funcion split
words = text.split()

# contamos el numero de palabras que ahora estan en words con la funcion len y las guardamos en la nueva variable
num_words = len(words)

# imprimimos entonces la nueva cantidad que se guarda en num_words
print("numero de palabras:", num_words)
# Out:
# ingresa una cadena de texto (una frase): hola que haces? como estas?
# numero de palabras: 5

# %% [markdown]
# **Explicacion:**
# lo dificil es como se agragaban los elementos comunes a la lista y pues esta la funcion append que lo hace

# %% [markdown]
# ### Ejercicio 15
# Crea un programa que calcule el área de un círculo a partir del radio ingresado por el usuario.

# %%
# pedimos que se ingrese el radio, como flotante poque puede tener decimales y lo guardamos en una variable
radio = float(input("ingrese el radio del circulo: "))

# calculamos el area del circulo con la formula A = pi*r^2 definiendo lo que vale pi redondeado 
area = 3.14159 * (radio ** 2)

# imprimimos el area
print("el area del circulo es:", area)
# Out:
# ingrese el radio del circulo: 5
# el area del circulo es: 78.53975

# %% [markdown]
# **Explicacion:**
# aqui no tuve dificultad

# %% [markdown]
# ### Ejercicio 16
# Escribe un programa que tome una lista de números y que devuelva la media aritmética.

# %%
# definimos la lista de numero
num_list = [3, 5, 7, 8, 10]

# creamos una nueva variable para guarda la suma de los elemetos de la lista con la funcion sum
sum_list = sum(num_list)

# calculamos el numero de elementos en la lista contandolos con la funcion len y los guardamos en una nueva variable
num_elements = len(num_list)

# calculamos la media aritmetica que es el promedio 
media = sum_list / num_elements

# imprimimos la media
print("The arithmetic mean is:", media)
# Out:
# The arithmetic mean is: 6.6

# %% [markdown]
# **Explicacion:**
# con las funciones sum y len no es complicado, creo que otra forma es usando un for para con contar y para sumar cada elemento pero creo que igual tendriamos que usar las funciones len y sum

# %% [markdown]
# ### Ejercicio 17
# Crea un programa que reciba dos números ingresados por el usuario y que devuelva su producto.

# %%
# pedimos ingresar el primero numero los definimos como flotantes si desea usar numeros con decimales
num1 = float(input("ingrese el primer numero: "))

# pedimos ingresar el segundo numero
num2 = float(input("Enter the second number: "))

# hacemos el producto guardandolo en una nueva variable
product = num1 * num2

# imprimimos el producto
print("el producto es:", product)
# Out:
# ingrese el primer numero: 5
# Enter the second number: 2.2
# el producto es: 11.0

# %% [markdown]
# **Explicacion:**
# no tuve problemas

# %% [markdown]
# ### Ejercicio 18
# Escribe un programa que tome una lista de palabras y que devuelva una lista con todas las palabras en mayúsculas

# %%
# ingresamos la lista de palabras.
words_list = ["HOLA", "MUNDO", "Perro", "robot", "CARRO"]
#definimos la variable donde guardaremos la nueva lista
uppercase_words = []
#empezamos a revisar  cada palabra de la lista 
for word in words_list:
    if word.isupper(): #con la funcion.isuppeer verificamos que cada pabara sea en mayusculas
          uppercase_words.append(word)# con el .append le decimos que las agregue si son mayusculas a la nueva lista
 #   return uppercase_words # le decimos que nos nos de la nueva lista de palabras en mayusculas
print(uppercase_words)#imprimimos la nueva lista
# Out:
# ['HOLA', 'MUNDO', 'CARRO']

# %% [markdown]
# **Explicacion:**
# no entiendo por que el codigo asi no funciona encontre la solucion en internet pero es con otras funciones, es con la funcion
# def get_all_uppercase_words(words_list):

# %% [markdown]
# ### Ejercicio 19
# Crea un programa que tome una lista de números y que devuelva la suma de aquellos que son mayores a un valor específico ingresado por el usuario.

# %%
numbers = input("ingrese una lista de numeros separadas por espacio: ").split()
# definimos la variable de numeros y con la funcion .split para convertirla en una lista

specified_value = int(input("ingresa un valor especifico "))
# pedimos se agregue un valor especifico .

total_sum = 0
# creamos una variable para hacer la suma y la inicializamos en 0 para evitar errores.

for number in numbers:# creamos un ciclo donde  le decimos que revise sobre cada numero de la lista
    if int(number) > specified_value:# le indicamos que si el numero es mayor al valor especifico entonces haga a suma
        total_sum += int(number) #aqui hace la suma total de cada elemnto que es mayor 

print("la suma de los valores mas altos al valor especificado es", total_sum) #imprimimos la suma
# Out:
# ingrese una lista de numeros separadas por espacio: 1 2 3 4 5 6
# ingresa un valor especifico 3
# la suma de los valores mas altos al valor especificado es 15

# %% [markdown]
# **Explicacion:**
# no tuve problemas con este

# %% [markdown]
# ### Ejercicio 20
# Escribe un programa que tome una cadena de texto y que devuelva una nueva cadena con todas las letras en mayúsculas excepto la primera letra de cada palabra, que debe ser en minúsculas.

# %%
text = input("ingresa un texto: ")
# pedimos ingresar un texto y lo guardamso en la variable'.

words = text.split()
# convertimos el texto ingresado en una lista con la funcion .split. y la guardamos en una nueva variable
# Out:
# ingresa un texto:  hola como esta

# %% [markdown]
# **Explicacion:**
# no entiendo como hacer esta parte
